# %% [markdown]
# Import the necessary libraries
# - To make an API request
# - To decode JSON
# - To save data to a dataframe
# - To interact with an SQL database

# %%
# import package to make API requests  
import requests 

#import json package to decode JSON 
import json

# to save data to a dataframe 
import pandas as pd 

# to interact with an SQL database 
from sqlalchemy import create_engine

# %% [markdown]
# ### Make a single API request and save the results to the nyt_article table

# %% [markdown]
# Set a variable to store the API endpoint URL

# %%
api_url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
city = 'los angeles'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Search string: los angeles, ca

# %%
# get keys
rapid_api_key = 'API_KEY'

# %% [markdown]
# Set a dict of parameters to pass to the API endpoint URL

# %%
params = {"location":search_str,
          'home_type': 'Houses', 
          'minPrice': '1000000', 
          'minPrice': '4000000', 
          'sqftMin': '1000'}

# %%
headers = {'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
           'x-rapidapi-key': rapid_api_key}

# %% [markdown]
# Make an API GET request with the defined API endpoint URL and the dict of parameters

# %%
api_request = requests.get(api_url, headers=headers, params=params)

# %% [markdown]
# Confirm the API request received a 200 HTTP status code

# %%
api_request
# Out:
# <Response [200]>

# %% [markdown]
# View the text in the API request result

# %%
api_request.text
# Out:
# '{"props":[{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":1.0293,"address":"10979 Chalon Rd, Los Angeles, CA 90077","daysOnZillow":-1,"price":68500000,"listingDateTime":null,"longitude":-118.460014,"latitude":34.084206,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"20529055","listingSubType":{"is_newHome":true},"imgSrc":"https:\\/\\/photos.zillowstatic.com\\/fp\\/eb6ddce04132f5c94645490d49aff717-p_e.jpg","livingArea":32000000,"bathrooms":24,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":12,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":4.6017,"address":"594 S Mapleton Dr, Los Angeles, CA 90024","daysOnZillow":-1,"price":165000000,"listingDateTime":null,"longitude":-118.42822,"latitude":34.073273,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"20524417","listingSubType":{"is_FSBA":true},"imgSrc":"https:\\/\\/photos.zillowstatic.com\\/fp\\/72841ccc93683fee2ef678adf0cfa234-p_e.jpg","livingArea":56500,"bathrooms":27,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":14,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.50955004591368,"address":"4565 Encino Ave, Encino, CA 91316","daysOnZillow":-1,"price":12995000,"listingDateTime":null,"longitude":-118.51448,"latitude":34.152878,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"19994023","listingSubType":{"is_newHome":true},"imgSrc":"https:\\/\\/photos.zillowstatic.com\\/fp\\/08012f3e82b1ec27f6b710e0a0b1c839-p_e.jpg","livingArea":12300,"bathrooms":14,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":8,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":1.1639,"address":"9570 Hidden Valley Rd, Beverly Hills, CA 90210","daysOnZillow":-1,"price":19475000,"listingDateTime":null,"longitude":-118.40509,"latitude":34.120075,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"20533724","listingSubType":{"is_FSBA":true},"imgSrc":"https:\\/\\/photos.zillowstatic.com\\/fp\\/512350e1bcdea9435e08097021e41b11-p_e.jpg","livingArea":5427,"bathrooms":6,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":5,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":36.7309,"address":"9650 Cedarbrook Dr, Beverly Hills, CA 90210","daysOnZillow":-1,"price":250000000,"listingDateTime":null,"longitude":-118.40625,"latitude":34.107742,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"20533813","listingSubType":{"is_newHome":true},"imgSrc":"https:\\/\\/photos.zillowstatic.com\\/fp\\/a3765c761a11c25ca43439d2fe9d7664-p_e.jpg","livingArea":78000,"bathrooms":33,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":19,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":7278.876,"address":"5531 Red Oak Dr, Los Angeles, CA 90068","daysOnZillow":-1,"price":4599000,"listingDateTime":null,"longitude":-118.31004,"latitude":34.11318,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"20808079","listingSubType":{"is_FSBA":true,"is_openHouse":true},"imgSrc":"https:\\/\\/photos.zillowstatic.com\\/fp\\/ba5a726e6fc1e4294b2db2b88f210e75-p_e.jpg","livingArea":3960,"bathrooms":6,"lotAreaUnit":"sqft","country":"USA","currency":"USD","bedrooms":4,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.4496,"address":"441 N Bristol Ave, Los Angeles, CA 90049","daysOnZillow":-1,"price":23500000,"listingDateTime":null,"longitude":-118.489075,"latitude":34.0636,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"20538342","listingSubType":{"is_FSBA":true},"imgSrc":"https:\\/\\/photos.zillowstatic.com\\/fp\\/aed3febe0b535eafbc97421687da09d1-p_e.jpg","livingArea":9385,"bathrooms":8,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":6,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.33434343434343,"address":"4050 Contera Rd, Encino, CA 91 ...

# %% [markdown]
# Decode the API result text as JSON

# %%
json.loads(api_request.text)
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.0293,
#    'address': '10979 Chalon Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 68500000,
#    'listingDateTime': None,
#    'longitude': -118.460014,
#    'latitude': 34.084206,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20529055',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/eb6ddce04132f5c94645490d49aff717-p_e.jpg',
#    'livingArea': 32000000,
#    'bathrooms': 24,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 12,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4.6017,
#    'address': '594 S Mapleton Dr, Los Angeles, CA 90024',
#    'daysOnZillow': -1,
#    'price': 165000000,
#    'listingDateTime': None,
#    'longitude': -118.42822,
#    'latitude': 34.073273,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20524417',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/72841ccc93683fee2ef678adf0cfa234-p_e.jpg',
#    'livingArea': 56500,
#    'bathrooms': 27,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 14,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.50955004591368,
#    'address': '4565 Encino Ave, Encino, CA 91316',
#    'daysOnZillow': -1,
#    'price': 12995000,
#    'listingDateTime': None,
#    'longitude': -118.51448,
#    'latitude': 34.152878,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19994023',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/08012f3e82b1ec27f6b710e0a0b1c839-p_e.jpg',
#    'livingArea': 12300,
#    'bathrooms': 14,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.1639,
#    'address': '9570 Hidden Valley Rd, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 19475000,
#    'listingDateTime': None,
#    'longitude': -118.40509,
#    'latitude': 34.120075,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20533724',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/512350e1bcdea9435e08097021e41b11-p_e.jpg',
#    'livingArea': 5427,
#    'bathrooms': 6,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 36.7309,
#    'address': '9650 Cedarbrook Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 250000000,
#    'listingDateTime': None,
#    'longitude': -118.40625,
#    'latitude': 34.107742,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20533813',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a3765c761a11c25ca43439d2fe9d7664-p_e.jpg',
#    'livingArea': 78000,
#    'bathrooms': 33,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 19,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7278.876,
#    'address': '5531 Red Oak Dr, Los Angeles, CA 90068',
#    'daysOnZillow': -1,
#    'price': 4599000,
#    'listingDateTime': None,
#    'longitude': -118.31004,
#    'latitude': 34.11318,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20808079',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ba5a726e6fc1e4294b2db2b88f210e75-p_e.jpg',
#    'livingArea': 3960,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4496,
#    'address': '441 N Bristol Ave, Los Angeles, CA 90049',
#    'daysOnZillow': -1,
#    'price': 23500000,
#    'listingDateTime': None,
#    'longitude': -118.489075,
#    'latitude': 34.0636,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20538342',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aed3febe0b535eafbc97421687da09d1-p_e.jpg',
#    'livingArea': 9385,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.33434343434343,
#    'address': '4050 Contera Rd, Encino, CA 91436',
#    'daysOnZillow': -1,
#    'price': 6479000,
#    'listingDateTime': None,
#    'longitude': -118.48811,
#    'latitude': 34.14539,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19992358',
#    'listingSubType': {'is_newHome': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/37c83ed8a8f6415985f36bc2ebfe94ae-p_e.jpg',
#    'livingArea': 6297,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5.2,
#    'address': '2571 Wallingford Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 85000000,
#    'listingDateTime': None,
#    'longitude': -118.43405,
#    'latitude': 34.118523,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20532066',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/91c728e37be622a4f5d1cda4486d747d-p_e.jpg',
#    'livingArea': 38000,
#    'bathrooms': 24,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 12,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9356.688,
#    'address': '746 S Westholme Ave, Los Angeles, CA 90024',
#    'daysOnZillow': -1,
#    'price': 6750000,
#    'listingDateTime': None,
#    'longitude': -118.43627,
#    'latitude': 34.06756,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2065445515',
#    'listingSubType': {'is_newHome': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7fda379cc45739f949ccf2f2db7af33b-p_e.jpg',
#    'livingArea': 4504,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4001,
#    'address': '1332 Laurel Way, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 28950000,
#    'listingDateTime': None,
#    'longitude': -118.41735,
#    'latitude': 34.09508,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20523381',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/857ea163543728bc2e3b391a2699c600-p_e.jpg',
#    'livingArea': 11220,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9909.9,
#    'address': '9332 Hazen Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 5995000,
#    'listingDateTime': None,
#    'longitude': -118.397026,
#    'latitude': 34.1144,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20534215',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5dbccc7b5a6b255c0a4e1794e532728c-p_e.jpg',
#    'livingArea': 5183,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6926.04,
#    'address': '101 S Larchmont Blvd, Los Angeles, CA 90004',
#    'daysOnZillow': -1,
#    'price': 4195000,
#    'listingDateTime': None,
#    'longitude': -118.32402,
#    'latitude': 34.07288,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20779473',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/22cb80a0cac5293f6646e808a0cf31a0-p_e.jpg',
#    'livingArea': 3180,
#    'bathrooms': 5,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3.6007,
#    'address': '10066 Cielo Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 85000000,
#    'listingDateTime': None,
#    'longitude': -118.432365,
#    'latitude': 34.09407,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '243990393',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2f242911746503fd47ce4c2010c94ba6-p_e.jpg',
#    'livingArea': 21000,
#    'bathrooms': 18,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 9,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4288,
#    'address': '1369 Londonderry Pl, Los Angeles, CA 90069',
#    'daysOnZillow': -1,
#    'price': 37995000,
#    'listingDateTime': None,
#    'longitude': -118.38032,
#    'latitude': 34.094875,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20798985',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/141d9903c1fd7ca5078f9472fcb9118d-p_e.jpg',
#    'livingArea': 14000,
#    'bathrooms': 10,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3489,
#    'address': '16366 Sloan Dr, Los Angeles, CA 90049',
#    'daysOnZillow': -1,
#    'price': 5199000,
#    'listingDateTime': None,
#    'longitude': -118.489456,
#    'latitude': 34.129414,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20558300',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aa1a2860894a28f7bd349020617522be-p_e.jpg',
#    'livingArea': 4600,
#    'bathrooms': 5,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3163,
#    'address': '2235 Hercules Dr, Los Angeles, CA 90046',
#    'daysOnZillow': -1,
#    'price': 7995000,
#    'listingDateTime': None,
#    'longitude': -118.36498,
#    'latitude': 34.111244,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20801921',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d742490c4ffdcdbc90328bbf44347c8b-p_e.jpg',
#    'livingArea': 6162,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.6344,
#    'address': '4838 Calderon Rd, Woodland Hills, CA 91364',
#    'daysOnZillow': -1,
#    'price': 12999000,
#    'listingDateTime': None,
#    'longitude': -118.61996,
#    'latitude': 34.158237,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '246045609',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b3a915a5ecfe21fa246bafd583dae836-p_e.jpg',
#    'livingArea': 13379,
#    'bathrooms': 13,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 12,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2.8137,
#    'address': '10250 W Sunset Blvd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 75000000,
#    'listingDateTime': None,
#    'longitude': -118.43153,
#    'latitude': 34.081066,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20524392',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f252dde3252ce90dc4fbec6d041c49a3-p_e.jpg',
#    'livingArea': 30000,
#    'bathrooms': 25,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 17,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7.8,
#    'address': '1420 Davies Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 87000000,
#    'listingDateTime': None,
#    'longitude': -118.43307,
#    'latitude': 34.09855,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20523735',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7da78f9eb6d4c5eb208ad2e5e6750ec5-p_e.jpg',
#    'livingArea': 21800,
#    'bathrooms': 14,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.2706,
#    'address': '643 Radcliffe Ave, Pacific Palisades, CA 90272',
#    'daysOnZillow': -1,
#    'price': 5395000,
#    'listingDateTime': None,
#    'longitude': -118.531265,
#    'latitude': 34.04225,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20541063',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f28d3ca8257fe165b0971dc5042d588c-p_e.jpg',
#    'livingArea': 3677,
#    'bathrooms': 4,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.9821,
#    'address': '1640 Stradella Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 14995000,
#    'listingDateTime': None,
#    'longitude': -118.45942,
#    'latitude': 34.10128,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20530495',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e9f19395f0d84561ec58cb7850ff412a-p_e.jpg',
#    'livingArea': 9246,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4592,
#    'address': '10480 W Sunset Blvd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 19995000,
#    'listingDateTime': None,
#    'longitude': -118.43849,
#    'latitude': 34.07834,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20524140',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1adf669872672644f4a6c458d9f6e8b5-p_e.jpg',
#    'livingArea': 13000,
#    'bathrooms': 11,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.67063820018365,
#    'address': '19333 Rosita St, Tarzana, CA 91356',
#    'daysOnZillow': -1,
#    'price': 7495000,
#    'listingDateTime': None,
#    'longitude': -118.55433,
#    'latitude': 34.157433,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19946370',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/90c3aab7aaa422f4fee201a1d13f951d-p_e.jpg',
#    'livingArea': 9738,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4.7716,
#    'address': '1714 Stone Canyon Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 20800000,
#    'listingDateTime': None,
#    'longitude': -118.45991,
#    'latitude': 34.104496,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20529440',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a1e1a051137a8ef98e77af37cad03445-p_e.jpg',
#    'livingArea': 17415,
#    'bathrooms': 13,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.0116,
#    'address': '4453 Balboa Ave, Encino, CA 91316',
#    'daysOnZillow': -1,
#    'price': 6795000,
#    'listingDateTime': None,
#    'longitude': -118.505104,
#    'latitude': 34.152798,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19993421',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4fd2497a6e59a36e69f7a053e2d1211b-p_e.jpg',
#    'livingArea': 7500,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.696,
#    'address': '315 S Hudson Ave, Los Angeles, CA 90020',
#    'daysOnZillow': -1,
#    'price': 21950000,
#    'listingDateTime': None,
#    'longitude': -118.33294,
#    'latitude': 34.068405,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20774974',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c333c3e8a550c31938b0e3f71e0a096a-p_e.jpg',
#    'livingArea': 13240,
#    'bathrooms': 11,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3973,
#    'address': '1945 Linda Flora Dr, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 10999988,
#    'listingDateTime': None,
#    'longitude': -118.4665,
#    'latitude': 34.10535,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20529997',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e638864e44b1bc822518b565df74351a-p_e.jpg',
#    'livingArea': 7640,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.7758,
#    'address': '15000 Corona Del Mar, Pacific Palisades, CA 90272',
#    'daysOnZillow': -1,
#    'price': 29995000,
#    'listingDateTime': None,
#    'longitude': -118.5231,
#    'latitude': 34.031147,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20540657',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aa87eb42e0f49fd63d5158cd21d33296-p_e.jpg',
#    'livingArea': 6673,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.1949,
#    'address': '10771 Bellagio Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 65000000,
#    'listingDateTime': None,
#    'longitude': -118.45104,
#    'latitude': 34.08036,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20526732',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7966cc6c4def4234ebeda314950add51-p_e.jpg',
#    'livingArea': 19721,
#    'bathrooms': 17,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 10,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.47288797061524,
#    'address': '15321 Kingswood Ln, Sherman Oaks, CA 91403',
#    'daysOnZillow': -1,
#    'price': 8995000,
#    'listingDateTime': None,
#    'longitude': -118.467064,
#    'latitude': 34.143307,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19990977',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/602436eef8f2d1f16f5843c70df10d47-p_e.jpg',
#    'livingArea': 9075,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.7725,
#    'address': '9814 Curwood Pl, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 12868000,
#    'listingDateTime': None,
#    'longitude': -118.4249,
#    'latitude': 34.106976,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20533023',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ebe1fcf5685526f1aafde034320e043b-p_e.jpg',
#    'livingArea': 9500,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8376.588,
#    'address': '2189 Sunset Plaza Dr, Los Angeles, CA 90069',
#    'daysOnZillow': -1,
#    'price': 11000000,
#    'listingDateTime': None,
#    'longitude': -118.386,
#    'latitude': 34.105453,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20800086',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/94704fc06d17740fa124ffd6a22195c3-p_e.jpg',
#    'livingArea': 5332,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.335,
#    'address': '846 S Longwood Ave, Los Angeles, CA 90005',
#    'daysOnZillow': -1,
#    'price': 5999000,
#    'listingDateTime': None,
#    'longitude': -118.33777,
#    'latitude': 34.059044,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20610686',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/162c8c27151989273be5dee6f5958406-p_e.jpg',
#    'livingArea': 4508,
#    'bathrooms': 6,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.265,
#    'address': '16041 Woodvale Rd, Encino, CA 91436',
#    'daysOnZillow': -1,
#    'price': 26000000,
#    'listingDateTime': None,
#    'longitude': -118.48233,
#    'latitude': 34.14837,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19992265',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/78641e88fd41957267be75817a1239f8-p_e.jpg',
#    'livingArea': 19500,
#    'bathrooms': 13,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 9,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.8604,
#    'address': '4546 White Oak Ave, Encino, CA 91316',
#    'daysOnZillow': -1,
#    'price': 7995000,
#    'listingDateTime': None,
#    'longitude': -118.51469,
#    'latitude': 34.15358,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19994050',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d3896738c9ae1bd82d7e49fb198fb6dc-p_e.jpg',
#    'livingArea': 8689,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.31593204775023,
#    'address': '2358 Kimridge Rd, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 7495000,
#    'listingDateTime': None,
#    'longitude': -118.39961,
#    'latitude': 34.114742,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '95664753',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/acd80efed11f42204ea91db0b0e80686-p_e.jpg',
#    'livingArea': 6646,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.938,
#    'address': '1699 Woods Dr, Los Angeles, CA 90069',
#    'daysOnZillow': -1,
#    'price': 5995000,
#    'listingDateTime': None,
#    'longitude': -118.37021,
#    'latitude': 34.103554,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '145643446',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/947e23084324076eba7f2e6790d1878c-p_e.jpg',
#    'livingArea': 3102,
#    'bathrooms': 4,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.2935,
#    'address': '4048 Sunnyslope Ave, Sherman Oaks, CA 91423',
#    'daysOnZillow': -1,
#    'price': 5499000,
#    'listingDateTime': None,
#    'longitude': -118.426476,
#    'latitude': 34.1434,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20028666',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/95ec729e3750d632498483df5069820a-p_e.jpg',
#    'livingArea': 5405,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.48553719008264,
#    'address': '161 Ashdale Pl, Los Angeles, CA 90049',
#    'daysOnZillow': -1,
#    'price': 11950000,
#    'listingDateTime': None,
#    'longitude': -118.46175,
#    'latitude': 34.07463,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20527825',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/229854fbc49ca93846affe5a3b1e4738-p_e.jpg',
#    'livingArea': 6545,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True}],
#  'resultsPerPage': 40,
#  'totalResultCount': 296,
#  'totalPages': 8}

# %% [markdown]
# Assign the decoded API request JSON result to a variable

# %%
api_response = json.loads(api_request.text)

# %% [markdown]
# Print out the dictionary value for the key containing the list of articles in the decoded API request JSON result

# %%
type(api_response)
# Out:
# dict

# %%
api_response
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.0293,
#    'address': '10979 Chalon Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 68500000,
#    'listingDateTime': None,
#    'longitude': -118.460014,
#    'latitude': 34.084206,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20529055',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/eb6ddce04132f5c94645490d49aff717-p_e.jpg',
#    'livingArea': 32000000,
#    'bathrooms': 24,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 12,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4.6017,
#    'address': '594 S Mapleton Dr, Los Angeles, CA 90024',
#    'daysOnZillow': -1,
#    'price': 165000000,
#    'listingDateTime': None,
#    'longitude': -118.42822,
#    'latitude': 34.073273,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20524417',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/72841ccc93683fee2ef678adf0cfa234-p_e.jpg',
#    'livingArea': 56500,
#    'bathrooms': 27,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 14,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.50955004591368,
#    'address': '4565 Encino Ave, Encino, CA 91316',
#    'daysOnZillow': -1,
#    'price': 12995000,
#    'listingDateTime': None,
#    'longitude': -118.51448,
#    'latitude': 34.152878,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19994023',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/08012f3e82b1ec27f6b710e0a0b1c839-p_e.jpg',
#    'livingArea': 12300,
#    'bathrooms': 14,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.1639,
#    'address': '9570 Hidden Valley Rd, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 19475000,
#    'listingDateTime': None,
#    'longitude': -118.40509,
#    'latitude': 34.120075,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20533724',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/512350e1bcdea9435e08097021e41b11-p_e.jpg',
#    'livingArea': 5427,
#    'bathrooms': 6,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 36.7309,
#    'address': '9650 Cedarbrook Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 250000000,
#    'listingDateTime': None,
#    'longitude': -118.40625,
#    'latitude': 34.107742,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20533813',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a3765c761a11c25ca43439d2fe9d7664-p_e.jpg',
#    'livingArea': 78000,
#    'bathrooms': 33,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 19,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7278.876,
#    'address': '5531 Red Oak Dr, Los Angeles, CA 90068',
#    'daysOnZillow': -1,
#    'price': 4599000,
#    'listingDateTime': None,
#    'longitude': -118.31004,
#    'latitude': 34.11318,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20808079',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ba5a726e6fc1e4294b2db2b88f210e75-p_e.jpg',
#    'livingArea': 3960,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4496,
#    'address': '441 N Bristol Ave, Los Angeles, CA 90049',
#    'daysOnZillow': -1,
#    'price': 23500000,
#    'listingDateTime': None,
#    'longitude': -118.489075,
#    'latitude': 34.0636,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20538342',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aed3febe0b535eafbc97421687da09d1-p_e.jpg',
#    'livingArea': 9385,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.33434343434343,
#    'address': '4050 Contera Rd, Encino, CA 91436',
#    'daysOnZillow': -1,
#    'price': 6479000,
#    'listingDateTime': None,
#    'longitude': -118.48811,
#    'latitude': 34.14539,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19992358',
#    'listingSubType': {'is_newHome': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/37c83ed8a8f6415985f36bc2ebfe94ae-p_e.jpg',
#    'livingArea': 6297,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5.2,
#    'address': '2571 Wallingford Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 85000000,
#    'listingDateTime': None,
#    'longitude': -118.43405,
#    'latitude': 34.118523,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20532066',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/91c728e37be622a4f5d1cda4486d747d-p_e.jpg',
#    'livingArea': 38000,
#    'bathrooms': 24,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 12,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9356.688,
#    'address': '746 S Westholme Ave, Los Angeles, CA 90024',
#    'daysOnZillow': -1,
#    'price': 6750000,
#    'listingDateTime': None,
#    'longitude': -118.43627,
#    'latitude': 34.06756,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2065445515',
#    'listingSubType': {'is_newHome': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7fda379cc45739f949ccf2f2db7af33b-p_e.jpg',
#    'livingArea': 4504,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4001,
#    'address': '1332 Laurel Way, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 28950000,
#    'listingDateTime': None,
#    'longitude': -118.41735,
#    'latitude': 34.09508,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20523381',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/857ea163543728bc2e3b391a2699c600-p_e.jpg',
#    'livingArea': 11220,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9909.9,
#    'address': '9332 Hazen Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 5995000,
#    'listingDateTime': None,
#    'longitude': -118.397026,
#    'latitude': 34.1144,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20534215',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5dbccc7b5a6b255c0a4e1794e532728c-p_e.jpg',
#    'livingArea': 5183,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6926.04,
#    'address': '101 S Larchmont Blvd, Los Angeles, CA 90004',
#    'daysOnZillow': -1,
#    'price': 4195000,
#    'listingDateTime': None,
#    'longitude': -118.32402,
#    'latitude': 34.07288,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20779473',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/22cb80a0cac5293f6646e808a0cf31a0-p_e.jpg',
#    'livingArea': 3180,
#    'bathrooms': 5,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3.6007,
#    'address': '10066 Cielo Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 85000000,
#    'listingDateTime': None,
#    'longitude': -118.432365,
#    'latitude': 34.09407,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '243990393',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2f242911746503fd47ce4c2010c94ba6-p_e.jpg',
#    'livingArea': 21000,
#    'bathrooms': 18,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 9,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4288,
#    'address': '1369 Londonderry Pl, Los Angeles, CA 90069',
#    'daysOnZillow': -1,
#    'price': 37995000,
#    'listingDateTime': None,
#    'longitude': -118.38032,
#    'latitude': 34.094875,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20798985',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/141d9903c1fd7ca5078f9472fcb9118d-p_e.jpg',
#    'livingArea': 14000,
#    'bathrooms': 10,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3489,
#    'address': '16366 Sloan Dr, Los Angeles, CA 90049',
#    'daysOnZillow': -1,
#    'price': 5199000,
#    'listingDateTime': None,
#    'longitude': -118.489456,
#    'latitude': 34.129414,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20558300',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aa1a2860894a28f7bd349020617522be-p_e.jpg',
#    'livingArea': 4600,
#    'bathrooms': 5,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3163,
#    'address': '2235 Hercules Dr, Los Angeles, CA 90046',
#    'daysOnZillow': -1,
#    'price': 7995000,
#    'listingDateTime': None,
#    'longitude': -118.36498,
#    'latitude': 34.111244,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20801921',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d742490c4ffdcdbc90328bbf44347c8b-p_e.jpg',
#    'livingArea': 6162,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.6344,
#    'address': '4838 Calderon Rd, Woodland Hills, CA 91364',
#    'daysOnZillow': -1,
#    'price': 12999000,
#    'listingDateTime': None,
#    'longitude': -118.61996,
#    'latitude': 34.158237,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '246045609',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b3a915a5ecfe21fa246bafd583dae836-p_e.jpg',
#    'livingArea': 13379,
#    'bathrooms': 13,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 12,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2.8137,
#    'address': '10250 W Sunset Blvd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 75000000,
#    'listingDateTime': None,
#    'longitude': -118.43153,
#    'latitude': 34.081066,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20524392',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f252dde3252ce90dc4fbec6d041c49a3-p_e.jpg',
#    'livingArea': 30000,
#    'bathrooms': 25,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 17,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7.8,
#    'address': '1420 Davies Dr, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 87000000,
#    'listingDateTime': None,
#    'longitude': -118.43307,
#    'latitude': 34.09855,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20523735',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7da78f9eb6d4c5eb208ad2e5e6750ec5-p_e.jpg',
#    'livingArea': 21800,
#    'bathrooms': 14,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.2706,
#    'address': '643 Radcliffe Ave, Pacific Palisades, CA 90272',
#    'daysOnZillow': -1,
#    'price': 5395000,
#    'listingDateTime': None,
#    'longitude': -118.531265,
#    'latitude': 34.04225,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20541063',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f28d3ca8257fe165b0971dc5042d588c-p_e.jpg',
#    'livingArea': 3677,
#    'bathrooms': 4,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.9821,
#    'address': '1640 Stradella Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 14995000,
#    'listingDateTime': None,
#    'longitude': -118.45942,
#    'latitude': 34.10128,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20530495',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e9f19395f0d84561ec58cb7850ff412a-p_e.jpg',
#    'livingArea': 9246,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4592,
#    'address': '10480 W Sunset Blvd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 19995000,
#    'listingDateTime': None,
#    'longitude': -118.43849,
#    'latitude': 34.07834,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20524140',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1adf669872672644f4a6c458d9f6e8b5-p_e.jpg',
#    'livingArea': 13000,
#    'bathrooms': 11,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.67063820018365,
#    'address': '19333 Rosita St, Tarzana, CA 91356',
#    'daysOnZillow': -1,
#    'price': 7495000,
#    'listingDateTime': None,
#    'longitude': -118.55433,
#    'latitude': 34.157433,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19946370',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/90c3aab7aaa422f4fee201a1d13f951d-p_e.jpg',
#    'livingArea': 9738,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4.7716,
#    'address': '1714 Stone Canyon Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 20800000,
#    'listingDateTime': None,
#    'longitude': -118.45991,
#    'latitude': 34.104496,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20529440',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a1e1a051137a8ef98e77af37cad03445-p_e.jpg',
#    'livingArea': 17415,
#    'bathrooms': 13,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 8,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.0116,
#    'address': '4453 Balboa Ave, Encino, CA 91316',
#    'daysOnZillow': -1,
#    'price': 6795000,
#    'listingDateTime': None,
#    'longitude': -118.505104,
#    'latitude': 34.152798,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19993421',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4fd2497a6e59a36e69f7a053e2d1211b-p_e.jpg',
#    'livingArea': 7500,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.696,
#    'address': '315 S Hudson Ave, Los Angeles, CA 90020',
#    'daysOnZillow': -1,
#    'price': 21950000,
#    'listingDateTime': None,
#    'longitude': -118.33294,
#    'latitude': 34.068405,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20774974',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c333c3e8a550c31938b0e3f71e0a096a-p_e.jpg',
#    'livingArea': 13240,
#    'bathrooms': 11,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3973,
#    'address': '1945 Linda Flora Dr, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 10999988,
#    'listingDateTime': None,
#    'longitude': -118.4665,
#    'latitude': 34.10535,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20529997',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e638864e44b1bc822518b565df74351a-p_e.jpg',
#    'livingArea': 7640,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.7758,
#    'address': '15000 Corona Del Mar, Pacific Palisades, CA 90272',
#    'daysOnZillow': -1,
#    'price': 29995000,
#    'listingDateTime': None,
#    'longitude': -118.5231,
#    'latitude': 34.031147,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20540657',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aa87eb42e0f49fd63d5158cd21d33296-p_e.jpg',
#    'livingArea': 6673,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.1949,
#    'address': '10771 Bellagio Rd, Los Angeles, CA 90077',
#    'daysOnZillow': -1,
#    'price': 65000000,
#    'listingDateTime': None,
#    'longitude': -118.45104,
#    'latitude': 34.08036,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20526732',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7966cc6c4def4234ebeda314950add51-p_e.jpg',
#    'livingArea': 19721,
#    'bathrooms': 17,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 10,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.47288797061524,
#    'address': '15321 Kingswood Ln, Sherman Oaks, CA 91403',
#    'daysOnZillow': -1,
#    'price': 8995000,
#    'listingDateTime': None,
#    'longitude': -118.467064,
#    'latitude': 34.143307,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19990977',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/602436eef8f2d1f16f5843c70df10d47-p_e.jpg',
#    'livingArea': 9075,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.7725,
#    'address': '9814 Curwood Pl, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 12868000,
#    'listingDateTime': None,
#    'longitude': -118.4249,
#    'latitude': 34.106976,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20533023',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ebe1fcf5685526f1aafde034320e043b-p_e.jpg',
#    'livingArea': 9500,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8376.588,
#    'address': '2189 Sunset Plaza Dr, Los Angeles, CA 90069',
#    'daysOnZillow': -1,
#    'price': 11000000,
#    'listingDateTime': None,
#    'longitude': -118.386,
#    'latitude': 34.105453,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20800086',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/94704fc06d17740fa124ffd6a22195c3-p_e.jpg',
#    'livingArea': 5332,
#    'bathrooms': 6,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.335,
#    'address': '846 S Longwood Ave, Los Angeles, CA 90005',
#    'daysOnZillow': -1,
#    'price': 5999000,
#    'listingDateTime': None,
#    'longitude': -118.33777,
#    'latitude': 34.059044,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20610686',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/162c8c27151989273be5dee6f5958406-p_e.jpg',
#    'livingArea': 4508,
#    'bathrooms': 6,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.265,
#    'address': '16041 Woodvale Rd, Encino, CA 91436',
#    'daysOnZillow': -1,
#    'price': 26000000,
#    'listingDateTime': None,
#    'longitude': -118.48233,
#    'latitude': 34.14837,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19992265',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/78641e88fd41957267be75817a1239f8-p_e.jpg',
#    'livingArea': 19500,
#    'bathrooms': 13,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 9,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.8604,
#    'address': '4546 White Oak Ave, Encino, CA 91316',
#    'daysOnZillow': -1,
#    'price': 7995000,
#    'listingDateTime': None,
#    'longitude': -118.51469,
#    'latitude': 34.15358,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '19994050',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d3896738c9ae1bd82d7e49fb198fb6dc-p_e.jpg',
#    'livingArea': 8689,
#    'bathrooms': 9,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.31593204775023,
#    'address': '2358 Kimridge Rd, Beverly Hills, CA 90210',
#    'daysOnZillow': -1,
#    'price': 7495000,
#    'listingDateTime': None,
#    'longitude': -118.39961,
#    'latitude': 34.114742,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '95664753',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/acd80efed11f42204ea91db0b0e80686-p_e.jpg',
#    'livingArea': 6646,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.938,
#    'address': '1699 Woods Dr, Los Angeles, CA 90069',
#    'daysOnZillow': -1,
#    'price': 5995000,
#    'listingDateTime': None,
#    'longitude': -118.37021,
#    'latitude': 34.103554,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '145643446',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/947e23084324076eba7f2e6790d1878c-p_e.jpg',
#    'livingArea': 3102,
#    'bathrooms': 4,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.2935,
#    'address': '4048 Sunnyslope Ave, Sherman Oaks, CA 91423',
#    'daysOnZillow': -1,
#    'price': 5499000,
#    'listingDateTime': None,
#    'longitude': -118.426476,
#    'latitude': 34.1434,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20028666',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/95ec729e3750d632498483df5069820a-p_e.jpg',
#    'livingArea': 5405,
#    'bathrooms': 8,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 6,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.48553719008264,
#    'address': '161 Ashdale Pl, Los Angeles, CA 90049',
#    'daysOnZillow': -1,
#    'price': 11950000,
#    'listingDateTime': None,
#    'longitude': -118.46175,
#    'latitude': 34.07463,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '20527825',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/229854fbc49ca93846affe5a3b1e4738-p_e.jpg',
#    'livingArea': 6545,
#    'bathrooms': 7,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 7,
#    'hasImage': True}],
#  'resultsPerPage': 40,
#  'totalResultCount': 296,
#  'totalPages': 8}

# %% [markdown]
# Assign the list of articles to a variable that will be later used to loop through

# %%
api_response['props']
# Out:
# [{'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 6926.04,
#   'address': '101 S Larchmont Blvd, Los Angeles, CA 90004',
#   'daysOnZillow': -1,
#   'price': 4195000,
#   'listingDateTime': None,
#   'longitude': -118.32402,
#   'latitude': 34.07288,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20779473',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/22cb80a0cac5293f6646e808a0cf31a0-p_e.jpg',
#   'livingArea': 3180,
#   'bathrooms': 5,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.938,
#   'address': '1699 Woods Dr, Los Angeles, CA 90069',
#   'daysOnZillow': -1,
#   'price': 5995000,
#   'listingDateTime': None,
#   'longitude': -118.37021,
#   'latitude': 34.103554,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '145643446',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/947e23084324076eba7f2e6790d1878c-p_e.jpg',
#   'livingArea': 3102,
#   'bathrooms': 4,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.2938,
#   'address': '11492 Thurston Cir, Los Angeles, CA 90049',
#   'daysOnZillow': -1,
#   'price': 4195000,
#   'listingDateTime': None,
#   'longitude': -118.465866,
#   'latitude': 34.076283,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20527850',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/06b61beae011d63a8207d2e2cac37017-p_e.jpg',
#   'livingArea': 2950,
#   'bathrooms': 4,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.2632,
#   'address': '1078 Villa Grove Dr, Pacific Palisades, CA 90272',
#   'daysOnZillow': -1,
#   'price': 4195000,
#   'listingDateTime': None,
#   'longitude': -118.51329,
#   'latitude': 34.0502,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20539383',
#   'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/9d515a018822fa752900bf2862764e4e-p_e.jpg',
#   'livingArea': 2283,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.2626,
#   'address': '8509 Hollywood Blvd, Los Angeles, CA 90069',
#   'daysOnZillow': -1,
#   'price': 4400000,
#   'listingDateTime': None,
#   'longitude': -118.37542,
#   'latitude': 34.099113,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20798390',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/0bbf7236b994ea0dda6168395f5f0cc4-p_e.jpg',
#   'livingArea': 2036,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.6173,
#   'address': '1303 Marinette Rd, Pacific Palisades, CA 90272',
#   'daysOnZillow': -1,
#   'price': 4395000,
#   'listingDateTime': None,
#   'longitude': -118.518715,
#   'latitude': 34.053112,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20544800',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/36c14ad92ced2f073cc47466c3d34644-p_e.jpg',
#   'livingArea': 3479,
#   'bathrooms': 4,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 2552.616,
#   'address': '524 Rialto Ave, Venice, CA 90291',
#   'daysOnZillow': -1,
#   'price': 5600000,
#   'listingDateTime': None,
#   'longitude': -118.46641,
#   'latitude': 33.98888,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '95552376',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/e7b38ac249fe72d3c52a71940cf76405-p_e.jpg',
#   'livingArea': 3400,
#   'bathrooms': 5,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 2221.56,
#   'address': '419 Rialto Ave, Venice, CA 90291',
#   'daysOnZillow': -1,
#   'price': 4995000,
#   'listingDateTime': None,
#   'longitude': -118.46848,
#   'latitude': 33.989185,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20450208',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1f5d47f0a4bdc4d9bcc3cabc0cc75883-p_e.jpg',
#   'livingArea': 1617,
#   'bathrooms': 2,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 3598,
#   'address': '929 Marco Pl, Venice, CA 90291',
#   'daysOnZillow': -1,
#   'price': 4895000,
#   'listingDateTime': None,
#   'longitude': -118.45789,
#   'latitude': 33.995052,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '2071334027',
#   'listingSubType': {'is_newHome': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/f162dff97349f2efe83cd6ea2360f781-p_e.jpg',
#   'livingArea': 2650,
#   'bathrooms': 5,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.4776,
#   'address': '591 Paseo Miramar, Pacific Palisades, CA 90272',
#   'daysOnZillow': -1,
#   'price': 4195000,
#   'listingDateTime': None,
#   'longitude': -118.55805,
#   'latitude': 34.04708,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20543024',
#   'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/97b18ade7d90faebbf55ff7efa37d503-p_e.jpg',
#   'livingArea': 2847,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 8921.088,
#   'address': '1551 Benedict Canyon Dr, Beverly Hills, CA 90210',
#   'daysOnZillow': -1,
#   'price': 4950000,
#   'listingDateTime': None,
#   'longitude': -118.4328,
#   'latitude': 34.09945,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20523724',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/49400abf0ddb71e8f12bf33769d10721-p_e.jpg',
#   'livingArea': 3126,
#   'bathrooms': 5,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 5,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.5066,
#   'address': '1444 Lachman Ln, Pacific Palisades, CA 90272',
#   'daysOnZillow': -1,
#   'price': 6495000,
#   'listingDateTime': None,
#   'longitude': -118.54918,
#   'latitude': 34.061512,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20544676',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/c30301eb6ae95b2517ba0dd4e4d7b5b2-p_e.jpg',
#   'livingArea': 3472,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 4.2259,
#   'address': '3140 Coldwater Canyon Ave, Studio City, CA 91604',
#   'daysOnZillow': -1,
#   'price': 6995000,
#   'listingDateTime': None,
#   'longitude': -118.40734,
#   'latitude': 34.130886,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '2065609799',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/72df7a7249d4b1a641149889674bee0c-p_e.jpg',
#   'livingArea': 2988,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 7183.044,
#   'address': '1377 Miller Pl, Los Angeles, CA 90069',
#   'daysOnZillow': -1,
#   'price': 5695000,
#   'listingDateTime': None,
#   'longitude': -118.37676,
#   'latitude': 34.095535,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20797266',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1b4f47630704d7fc7ab89af1e07dd3ff-p_e.jpg',
#   'livingArea': 3175,
#   'bathrooms': 4,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 1.3103,
#   'address': '1234 Stradella Rd, Los Angeles, CA 90077',
#   'daysOnZillow': -1,
#   'price': 4500000,
#   'listingDateTime': None,
#   'longitude': -118.454315,
#   'latitude': 34.09517,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20529427',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/b4a68590a5f025745754a862f4db1072-p_e.jpg',
#   'livingArea': 3131,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 3602.412,
#   'address': '927 Marco Pl, Venice, CA 90291',
#   'daysOnZillow': -1,
#   'price': 5250000,
#   'listingDateTime': None,
#   'longitude': -118.45774,
#   'latitude': 33.995274,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20452332',
#   'listingSubType': {'is_newHome': True, 'is_openHouse': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/4f054ed899228bc3e6d7bf3fd1b2e46d-p_e.jpg',
#   'livingArea': 2604,
#   'bathrooms': 4,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 2851,
#   'address': '218 Carroll Canal, Venice, CA 90291',
#   'daysOnZillow': -1,
#   'price': 5495000,
#   'listingDateTime': None,
#   'longitude': -118.467705,
#   'latitude': 33.984535,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '55822773',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/d003349d5b19b4aa7c57bc69c6c6ef29-p_e.jpg',
#   'livingArea': 3151,
#   'bathrooms': 4,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 1,
#   'address': '4705 Sophia Ave, Encino, CA 91436',
#   'daysOnZillow': -1,
#   'price': 4995000,
#   'listingDateTime': None,
#   'longitude': -118.48701,
#   'latitude': 34.154785,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '19991635',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/9c270ac5d57778b44ec7e1f9954cfa78-p_e.jpg',
#   'livingArea': 2313,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.7059,
#   'address': '1410 Stradella Rd, Los Angeles, CA 90077',
#   'daysOnZillow': -1,
#   'price': 4900000,
#   'listingDateTime': None,
#   'longitude': -118.45651,
#   'latitude': 34.09869,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20530481',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/80158e0aea00ae78e918b6806f1edf39-p_e.jpg',
#   'livingArea': 3271,
#   'bathrooms': 5,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.6114,
#   'address': '400 Vance St, Pacific Palisades, CA 90272',
#   'daysOnZillow': -1,
#   'price': 6995000,
#   'listingDateTime': None,
#   'longitude': -118.51869,
#   'latitude': 34.033443,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20540643',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/0f1b93428294d8f92a1e269716ee7676-p_e.jpg',
#   'livingArea': 2734,
#   'bathrooms': 4,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.3933,
#   'address': '645 Alma Real Dr, Pacific Palisades, CA 90272',
#   'daysOnZillow': -1,
#   'price': 10000000,
#   'listingDateTime': None,
#   'longitude': -118.524284,
#   'latitude': 34.039574,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20540195',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/4b89a0ee4ee960d376c729f105ce28fa-p_e.jpg',
#   'livingArea': 2367,
#   'bathrooms': 4,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.9696,
#   'address': '7200 La Presa Dr, Los Angeles, CA 90068',
#   'daysOnZillow': -1,
#   'price': 4795000,
#   'listingDateTime': None,
#   'longitude': -118.34502,
#   'latitude': 34.108006,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20793708',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/eb8d1a27ff2fed04c93732e41c9e18f4-p_e.jpg',
#   'livingArea': 3085,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 3,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 6560.136,
#   'address': '100 S Edinburgh Ave, Los Angeles, CA 90048',
#   'daysOnZillow': -1,
#   'price': 4950000,
#   'listingDateTime': None,
#   'longitude': -118.36337,
#   'latitude': 34.074158,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20777146',
#   'listingSubType': {'is_newHome': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3e4b3b2b78bd11faa0517951957382e1-p_e.jpg',
#   'livingArea': 3089,
#   'bathrooms': 6,
#   'lotAreaUnit': 'sqft',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 5,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 1.0317,
#   'address': '765 N Tigertail Rd, Los Angeles, CA 90049',
#   'daysOnZillow': -1,
#   'price': 8995000,
#   'listingDateTime': None,
#   'longitude': -118.4831,
#   'latitude': 34.074368,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20560093',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1192658d1103dc26cfdd35d7e2fc3ea4-p_e.jpg',
#   'livingArea': 2468,
#   'bathrooms': 3,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.3573,
#   'address': '1682 San Onofre Dr, Pacific Palisades, CA 90272',
#   'daysOnZillow': -1,
#   'price': 7100000,
#   'listingDateTime': None,
#   'longitude': -118.501976,
#   'latitude': 34.06242,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '20546184',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/3da6a8b52949498fab488246a2412b55-p_e.jpg',
#   'livingArea': 2915,
#   'bathrooms': 4,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True},
#  {'dateSold': None,
#   'propertyType': 'SINGLE_FAMILY',
#   'lotAreaValue': 0.3142,
#   'address': '1 Apollo Dr, Los Angeles, CA 90046',
#   'daysOnZillow': -1,
#   'price': 4999999,
#   'listingDateTime': None,
#   'longitude': None,
#   'latitude': None,
#   'contingentListingType': None,
#   'listingStatus': 'FOR_SALE',
#   'zpid': '2065508759',
#   'listingSubType': {'is_FSBA': True},
#   'imgSrc': 'https://photos.zillowstatic.com/fp/bffe015d92b86ca8d9dcd202a255263d-p_e.jpg',
#   'livingArea': 2854,
#   'bathrooms': 4,
#   'lotAreaUnit': 'acres',
#   'country': 'USA',
#   'currency': 'USD',
#   'bedrooms': 4,
#   'hasImage': True}]

# %%
api_response['props']

propsearch = api_response['props']

# %% [markdown]
# Confirm the type of variable for the list of articles variable

# %%
type(propsearch)
# Out:
# list

# %% [markdown]
# - Create a dictionary to hold the article details. Initialize the dictionary values to an empty list for each key.
#
#
# - Loop through the articles
#     - Assign the JSON values you will eventually store in a table to a variable
#     - Convert the pub_date to a [datetime format](https://www.geeksforgeeks.org/python-pandas-to_datetime/)
#     - Append the variable to the appropriate key for the dictionary initialized above
#     - Print out the variable value
#     - To delimit each article, print out a line of repeating non-alphanumeric characters of your choice

# %%
prop_data = {
    'address':[], 
    'price':[], 
    'livingArea':[],
    'lotAreaValue':[], 
    'daysOnZillow':[]   
}

# %% [markdown]
# Print out the contents of the article details dictionary

# %%
for house in propsearch: 
    
    address = house['address']
    prop_data['address'].append(address)
    print(address)
    
    price = house['price'] 
    prop_data['price'].append(price)
    print(price)
    
    livingArea = house['livingArea']
    prop_data['livingArea'].append(livingArea)
    print(livingArea)
    
    lotAreaValue = house['lotAreaValue']
    prop_data['lotAreaValue'].append(lotAreaValue)
    print(lotAreaValue)
    
    daysOnZillow = house['daysOnZillow']
    prop_data['daysOnZillow'].append(daysOnZillow)
    print(daysOnZillow)
    
    print('-'*75)
# Out:
# 594 S Mapleton Dr, Los Angeles, CA 90024
# 165000000
# 56500
# 4.6017
# -1
# ---------------------------------------------------------------------------
# 4050 Contera Rd, Encino, CA 91436
# 6479000
# 6297
# 0.33434343434343
# -1
# ---------------------------------------------------------------------------
# 9570 Hidden Valley Rd, Beverly Hills, CA 90210
# 19475000
# 5427
# 1.1639
# -1
# ---------------------------------------------------------------------------
# 1332 Laurel Way, Beverly Hills, CA 90210
# 28950000
# 11220
# 0.4001
# -1
# ---------------------------------------------------------------------------
# 10979 Chalon Rd, Los Angeles, CA 90077
# 68500000
# 32000000
# 1.0293
# -1
# ---------------------------------------------------------------------------
# 4565 Encino Ave, Encino, CA 91316
# 12995000
# 12300
# 0.50955004591368
# -1
# ---------------------------------------------------------------------------
# 9332 Hazen Dr, Beverly Hills, CA 90210
# 5995000
# 5183
# 9909.9
# -1
# ---------------------------------------------------------------------------
# 441 N Bristol Ave, Los Angeles, CA 90049
# 23500000
# 9385
# 0.4496
# -1
# ---------------------------------------------------------------------------
# 10066 Cielo Dr, Beverly Hills, CA 90210
# 85000000
# 21000
# 3.6007
# -1
# ---------------------------------------------------------------------------
# 4430 Hayvenhurst Ave, Encino, CA 91436
# 9480000
# 7829
# 0.7187
# -1
# ---------------------------------------------------------------------------
# 2235 Hercules Dr, Los Angeles, CA 90046
# 7995000
# 6162
# 0.3163
# -1
# ---------------------------------------------------------------------------
# 4838 Calderon Rd, Woodland Hills, CA 91364
# 12999000
# 13379
# 0.6344
# -1
# ---------------------------------------------------------------------------
# 2571 Wallingford Dr, Beverly Hills, CA 90210
# 85000000
# 38000
# 5.2
# -1
# ---------------------------------------------------------------------------
# 1369 Londonderry Pl, Los Angeles, CA 90069
# 37995000
# 14000
# 0.4288
# -1
# ---------------------------------------------------------------------------
# 101 S Larchmont Blvd, Los Angeles, CA 90004
# 4195000
# 3180
# 6926.04
# -1
# ---------------------------------------------------------------------------
# 1714 Stone Canyon Rd, Los Angeles, CA 90077
# 20800000
# 17415
# 4.7716
# -1
# ---------------------------------------------------------------------------
# 1120 Angelo Dr, Beverly Hills, CA 90210
# 5500000
# 5138
# 0.322
# -1
# ---------------------------------------------------------------------------
# 1420 Davies Dr, Beverly Hills, CA 90210
# 87000000
# 21800
# 7.8
# -1
# ---------------------------------------------------------------------------
# 10250 W Sunset Blvd, Los Angeles, CA 90077
# 75000000
# 30000
# 2.8137
# -1
# ---------------------------------------------------------------------------
# 643 Radcliffe Ave, Pacific Palisades, CA 90272
# 5395000
# 3677
# 0.2706
# -1
# ---------------------------------------------------------------------------
# 5531 Red Oak Dr, Los Angeles, CA 90068
# 4599000
# 3960
# 7278.876
# -1
# ---------------------------------------------------------------------------
# 10771 Bellagio Rd, Los Angeles, CA 90077
# 65000000
# 19721
# 1.1949
# -1
# ---------------------------------------------------------------------------
# 16366 Sloan Dr, Los Angeles, CA 90049
# 5199000
# 4600
# 0.3489
# -1
# ---------------------------------------------------------------------------
# 1945 Linda Flora Dr, Los Angeles, CA 90077
# 10999988
# 7640
# 0.3973
# -1
# ---------------------------------------------------------------------------
# 315 S Hudson Ave, Los Angeles, CA 90020
# 21950000
# 13240
# 0.696
# -1
# ---------------------------------------------------------------------------
# 846 S Longwood Ave, Los Angeles, CA 90005
# 5999000
# 4508
# 0.335
# -1
# ---------------------------------------------------------------------------
# 1640 Stradella Rd, Los Angeles, CA 90077
# 14995000
# 9246
# 0.9821
# -1
# ---------------------------------------------------------------------------
# 15321 Kingswood Ln, Sherman Oaks, CA 91403
# 8995000
# 9075
# 0.47288797061524
# -1
# ---------------------------------------------------------------------------
# 9650 Cedarbrook Dr, Beverly Hills, CA 90210
# 250000000
# 78000
# 36.7309
# -1
# ---------------------------------------------------------------------------
# 271 S Mapleton Dr, Los Angeles, CA 90024
# 64950000
# 31450
# 1.4021
# -1
# ---------------------------------------------------------------------------
# 15000 Corona Del Mar, Pacific Palisades, CA 90272
# 29995000
# 6673
# 0.7758
# -1
# ---------------------------------------------------------------------------
# 19200 Rosita St, Tarzana, CA 91356
# 5880000
# 5289
# 0.4549
# -1
# ---------------------------------------------------------------------------
# 4048 Sunnyslope Ave, Sherman Oaks, CA 91423
# 5499000
# 5405
# 0.2935
# -1
# ---------------------------------------------------------------------------
# 4453 Balboa Ave, Encino, CA 91316
# 6795000
# 7500
# 1.0116
# -1
# ---------------------------------------------------------------------------
# 746 S Westholme Ave, Los Angeles, CA 90024
# 6750000
# 4504
# 9356.688
# -1
# ---------------------------------------------------------------------------
# 4651 Louise Ave, Encino, CA 91316
# 6298500
# 6114
# 0.42371441689624
# -1
# ---------------------------------------------------------------------------
# 9814 Curwood Pl, Beverly Hills, CA 90210
# 12868000
# 9500
# 0.7725
# -1
# ---------------------------------------------------------------------------
# 9726 Hensal Rd, Beverly Hills, CA 90210
# 6495000
# 4768
# 0.292
# -1
# ---------------------------------------------------------------------------
# 16041 Woodvale Rd, Encino, CA 91436
# 26000000
# 19500
# 1.265
# -1
# ---------------------------------------------------------------------------
# 19333 Rosita St, Tarzana, CA 91356
# 7495000
# 9738
# 0.67063820018365
# -1
# ---------------------------------------------------------------------------

# %% [markdown]
# Assign the article details dictionary to a dataframe

# %%
df = pd.DataFrame(prop_data)

# %% [markdown]
# Print out the first 5 rows of the dataframe

# %%
df.head()
# Out:
#                                           address      price  livingArea  \
# 0        594 S Mapleton Dr, Los Angeles, CA 90024  165000000       56500
# 1               4050 Contera Rd, Encino, CA 91436    6479000        6297
# 2  9570 Hidden Valley Rd, Beverly Hills, CA 90210   19475000        5427
# 3        1332 Laurel Way, Beverly Hills, CA 90210   28950000       11220
# 4          10979 Chalon Rd, Los Angeles, CA 90077   68500000    32000000
#
#    lotAreaValue  daysOnZillow
# 0      4.601700            -1
# 1      0.334343            -1
# 2      1.163900            -1
# 3      0.400100            -1
# 4      1.029300            -1

# %%
df = df.rename(columns={"livingArea":"sqft", "lotAreaValue":"lot_area_value", "daysOnZillow":"days_on_zillow"})

# %%
#check Dataframe columns 

print("Dataframe columns:", df.columns)
# Out:
# Dataframe columns: Index(['address', 'price', 'sqft', 'lot_area_value', 'days_on_zillow'], dtype='object')

# %% [markdown]
# Establish a connection to your assignment_02 database.
#
# Append ?charset=utf8 to the database name to avoide codec errors.

# %%
# create DB Connection to assignment_02 database in AWS RDS zillow
engine = create_engine('mysql+mysqldb://admin:sql_2021@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project?charset=utf8')

# %% [markdown]
# Insert the dataframe contents to the zillow table you previously created.
#
# Ensure your variables in the articles for loop matches the table's column names.
#
# Set the if_exists argument to append to insert into the table you already created.
#
# Do not insert the dataframe's index column.

# %%
# Insert the dataframe into the zillow table
df.to_sql('zillow', engine, if_exists='append', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Clear out the table before proceeding.
# Run the following SQL in your database client:
#
# TRUNCATE TABLE zillow;

# %% [markdown]
# ---

# %% [markdown]
# ### Make requests to the API

# %%
for page_variable in range(20):
    print('Page:', page_variable+1)
    
    city = 'los angeles'
    state = 'ca'
    search_str = city + ', ' + state
    print('Search string:', search_str)
    
    rapid_api_key = 'API_KEY'
        
    api_url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"
    params = {"location":search_str,
              'home_type': 'Houses', 
              'minPrice': '1000000', 
              'minPrice': '4000000', 
              'sqftMin': '1000',  
              'page': page_variable+1}
    headers = {'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
               'x-rapidapi-key': rapid_api_key}
    
    api_request = requests.get(api_url, headers=headers, params=params)
    
    api_response = json.loads(api_request.text) 

    propsearch = api_response['props']

    prop_data = {
    'address':[], 
    'price':[], 
    'livingArea':[],
    'lotAreaValue':[], 
    'daysOnZillow':[]   
    }

    for house in propsearch: 
    
        address = house['address']
        prop_data['address'].append(address)
        print(address)

        price = house['price'] 
        prop_data['price'].append(price)
        print(price)

        livingArea = house['livingArea']
        prop_data['livingArea'].append(livingArea)
        print(livingArea)

        lotAreaValue = house['lotAreaValue']
        prop_data['lotAreaValue'].append(lotAreaValue)
        print(lotAreaValue)

        daysOnZillow = house['daysOnZillow']
        prop_data['daysOnZillow'].append(daysOnZillow)
        print(daysOnZillow)

        print('-'*75)
        
    df = pd.DataFrame(prop_data)
    
    df = df.rename(columns={"livingArea":"sqft", "lotAreaValue":"lot_area_value", "daysOnZillow":"days_on_zillow"})
    
    engine = create_engine('mysql+mysqldb://admin:sql_2021@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project?charset=utf8')
    df.to_sql('zillow', engine, if_exists='append', index=False)
# Out:
# Page: 1
# Search string: los angeles, ca
# 594 S Mapleton Dr, Los Angeles, CA 90024
# 165000000
# 56500
# 4.6017
# -1
# ---------------------------------------------------------------------------
# 4050 Contera Rd, Encino, CA 91436
# 6479000
# 6297
# 0.33434343434343
# -1
# ---------------------------------------------------------------------------
# 9570 Hidden Valley Rd, Beverly Hills, CA 90210
# 19475000
# 5427
# 1.1639
# -1
# ---------------------------------------------------------------------------
# 1332 Laurel Way, Beverly Hills, CA 90210
# 28950000
# 11220
# 0.4001
# -1
# ---------------------------------------------------------------------------
# 10979 Chalon Rd, Los Angeles, CA 90077
# 68500000
# 32000000
# 1.0293
# -1
# ---------------------------------------------------------------------------
# 4565 Encino Ave, Encino, CA 91316
# 12995000
# 12300
# 0.50955004591368
# -1
# ---------------------------------------------------------------------------
# 9332 Hazen Dr, Beverly Hills, CA 90210
# 5995000
# 5183
# 9909.9
# -1
# ---------------------------------------------------------------------------
# 441 N Bristol Ave, Los Angeles, CA 90049
# 23500000
# 9385
# 0.4496
# -1
# ---------------------------------------------------------------------------
# 10066 Cielo Dr, Beverly Hills, CA 90210
# 85000000
# 21000
# 3.6007
# -1
# ---------------------------------------------------------------------------
# 4430 Hayvenhurst Ave, Encino, CA 91436
# 9480000
# 7829
# 0.7187
# -1
# ---------------------------------------------------------------------------
# 2235 Hercules Dr, Los Angeles, CA 90046
# 7995000
# 6162
# 0.3163
# -1
# ---------------------------------------------------------------------------
# 4838 Calderon Rd, Woodland Hills, CA 91364
# 12999000
# 13379
# 0.6344
# -1
# ---------------------------------------------------------------------------
# 2571 Wallingford Dr, Beverly Hills, CA 90210
# 85000000
# 38000
# 5.2
# -1
# ---------------------------------------------------------------------------
# 1369 Londonderry Pl, Los Angeles, CA 90069
# 37995000
# 14000
# 0.4288
# -1
# ---------------------------------------------------------------------------
# 101 S Larchmont Blvd, Los Angeles, CA 90004
# 4195000
# 3180
# 6926.04
# -1
# ---------------------------------------------------------------------------
# 1714 Stone Canyon Rd, Los Angeles, CA 90077
# 20800000
# 17415
# 4.7716
# -1
# ---------------------------------------------------------------------------
# 1120 Angelo Dr, Beverly Hills, CA 90210
# 5500000
# 5138
# 0.322
# -1
# ---------------------------------------------------------------------------
# 1420 Davies Dr, Beverly Hills, CA 90210
# 87000000
# 21800
# 7.8
# -1
# ---------------------------------------------------------------------------
# 10250 W Sunset Blvd, Los Angeles, CA 90077
# 75000000
# 30000
# 2.8137
# -1
# ---------------------------------------------------------------------------
# 643 Radcliffe Ave, Pacific Palisades, CA 90272
# 5395000
# 3677
# 0.2706
# -1
# ---------------------------------------------------------------------------
# 5531 Red Oak Dr, Los Angeles, CA 90068
# 4599000
# 3960
# 7278.876
# -1
# ---------------------------------------------------------------------------
# 10771 Bellagio Rd, Los Angeles, CA 90077
# 65000000
# 19721
# 1.1949
# -1
# ---------------------------------------------------------------------------
# 16366 Sloan Dr, Los Angeles, CA 90049
# 5199000
# 4600
# 0.3489
# -1
# ---------------------------------------------------------------------------
# 1945 Linda Flora Dr, Los Angeles, CA 90077
# 10999988
# 7640
# 0.3973
# -1
# ---------------------------------------------------------------------------
# 315 S Hudson Ave, Los Angeles, CA 90020
# 21950000
# 13240
# 0.696
# -1
# ---------------------------------------------------------------------------
# 846 S Longwood Ave, Los Angeles, CA 90005
# 5999000
# 4508
# 0.335
# -1
# ---------------------------------------------------------------------------
# 1640 Stradella Rd, Los Angeles, CA 90077
# 14995000
# 9246
# 0.9821
# -1
# ---------------------------------------------------------------------------
# 15321 Kingswood Ln, Sherman Oaks, CA 91403
# 8995000
# 9075
# 0.47288797061524
# -1
# ---------------------------------------------------------------------------
# 9650 Cedarbrook Dr, Beverly Hills, CA 90210
# 250000000
# 78000
# 36.7309
# -1
# ---------------------------------------------------------------------------
# 271 S Mapleton Dr, Los Angeles, CA 90024
# 64950000
# 31450
# 1.4021
# -1
# ---------------------------------------------------------------------------
# 15000 Corona Del Mar, Pacific Palisades, CA 90272
# 29995000
# 6673
# 0.7758
# -1
# ---------------------------------------------------------------------------
# 19200 Rosita St, Tarzana, CA 91356
# 5880000
# 5289
# 0.4549
# -1
# ---------------------------------------------------------------------------
# 4048 Sunnyslope Ave, Sherman Oaks, CA 91423
# 5499000
# 5405
# 0.2935
# -1
# ---------------------------------------------------------------------------
# 4453 Balboa Ave, Encino, CA 91316
# 6795000
# 7500
# 1.0116
# -1
# ---------------------------------------------------------------------------
# 746 S Westholme Ave, Los Angeles, CA 90024
# 6750000
# 4504
# 9356.688
# -1
# ---------------------------------------------------------------------------
# 4651 Louise Ave, Encino, CA 91316
# 6298500
# 6114
# 0.42371441689624
# -1
# ---------------------------------------------------------------------------
# 9814 Curwood Pl, Beverly Hills, CA 90210
# 12868000
# 9500
# 0.7725
# -1
# ---------------------------------------------------------------------------
# 9726 Hensal Rd, Beverly Hills, CA 90210
# 6495000
# 4768
# 0.292
# -1
# ---------------------------------------------------------------------------
# 16041 Woodvale Rd, Encino, CA 91436
# 26000000
# 19500
# 1.265
# -1
# ---------------------------------------------------------------------------
# 19333 Rosita St, Tarzana, CA 91356
# 7495000
# 9738
# 0.67063820018365
# -1
# ---------------------------------------------------------------------------
# Page: 2
# Search string: los angeles, ca
# 10480 W Sunset Blvd, Los Angeles, CA 90077
# 19995000
# 13000
# 0.4592
# -1
# ---------------------------------------------------------------------------
# 14984 Corona Del Mar, Pacific Palisades, CA 90272
# 37500000
# 9380
# 0.7314
# -1
# ---------------------------------------------------------------------------
# 4509 Noeline Ave, Encino, CA 91436
# 11995000
# 10278
# 0.72745638200184
# -1
# ---------------------------------------------------------------------------
# 161 Ashdale Pl, Los Angeles, CA 90049
# 11950000
# 6545
# 0.48553719008264
# -1
# ---------------------------------------------------------------------------
# 4546 White Oak Ave, Encino, CA 91316
# 7995000
# 8689
# 0.8604
# -1
# ---------------------------------------------------------------------------
# 300 Stone Canyon Rd, Los Angeles, CA 90077
# 59000000
# 17600
# 1.9704
# -1
# ---------------------------------------------------------------------------
# 17647 Belinda St, Encino, CA 91316
# 5685000
# 8134
# 0.4899
# -1
# ---------------------------------------------------------------------------
# 1 Bode Dr, Los Angeles, CA 90069
# 19990000
# 10000
# 0.9917
# -1
# ---------------------------------------------------------------------------
# 2189 Sunset Plaza Dr, Los Angeles, CA 90069
# 11000000
# 5332
# 8376.588
# -1
# ---------------------------------------------------------------------------
# 1251 Tower Grove Dr, Beverly Hills, CA 90210
# 58000000
# 14500
# 1.1119
# -1
# ---------------------------------------------------------------------------
# 1871 N Stanley Ave, Los Angeles, CA 90046
# 24995000
# 10365
# 0.691
# -1
# ---------------------------------------------------------------------------
# 307 Mount Holyoke Ave, Pacific Palisades, CA 90272
# 7950000
# 4336
# 0.2716
# -1
# ---------------------------------------------------------------------------
# 1756 Clear View Dr, Beverly Hills, CA 90210
# 8989000
# 5556
# 0.71829660238751
# -1
# ---------------------------------------------------------------------------
# 2358 Kimridge Rd, Beverly Hills, CA 90210
# 7495000
# 6646
# 0.31593204775023
# -1
# ---------------------------------------------------------------------------
# 2505 Summitridge Dr, Beverly Hills, CA 90210
# 29900000
# 12860
# 7.58
# -1
# ---------------------------------------------------------------------------
# 1699 Woods Dr, Los Angeles, CA 90069
# 5995000
# 3102
# 0.938
# -1
# ---------------------------------------------------------------------------
# 1877 Rising Glen Rd, Los Angeles, CA 90069
# 18500000
# 8339
# 0.53014233241506
# -1
# ---------------------------------------------------------------------------
# 1853 Sunset Plaza Dr, Los Angeles, CA 90069
# 6699000
# 5817
# 0.6602
# -1
# ---------------------------------------------------------------------------
# 1380 Mockingbird Pl, Los Angeles, CA 90069
# 44950000
# 14000
# 1.5407
# -1
# ---------------------------------------------------------------------------
# 357 Lorraine Blvd, Los Angeles, CA 90020
# 15000000
# 12565
# 0.6191
# -1
# ---------------------------------------------------------------------------
# 2321 Castilian Dr, Los Angeles, CA 90068
# 10995000
# 9000
# 10084.14
# -1
# ---------------------------------------------------------------------------
# 2401 Ocean Front Walk, Venice, CA 90291
# 7350000
# 3815
# 2522.124
# -1
# ---------------------------------------------------------------------------
# 12094 Summit Cir, Beverly Hills, CA 90210
# 6699000
# 7453
# 0.36919191919192
# -1
# ---------------------------------------------------------------------------
# 1422 Lachman Ln, Pacific Palisades, CA 90272
# 6995000
# 8552
# 0.4379
# -1
# ---------------------------------------------------------------------------
# 1550 Amalfi Dr, Pacific Palisades, CA 90272
# 46500000
# 16773
# 1.322
# -1
# ---------------------------------------------------------------------------
# 8029 Willow Glen Rd, Los Angeles, CA 90046
# 4345000
# 3713
# 0.3158
# -1
# ---------------------------------------------------------------------------
# 11400 Sunshine Ter, Studio City, CA 91604
# 12000000
# 7600
# 3.17
# -1
# ---------------------------------------------------------------------------
# 111 N Mapleton Dr, Los Angeles, CA 90077
# 43750000
# 14259
# 1.3174
# -1
# ---------------------------------------------------------------------------
# 1324 Stradella Rd, Los Angeles, CA 90077
# 11995000
# 8656
# 0.4552
# -1
# ---------------------------------------------------------------------------
# 1352 Palms Blvd, Venice, CA 90291
# 4200000
# 4476
# 0.25006887052342
# -1
# ---------------------------------------------------------------------------
# 133 S Mapleton Dr, Los Angeles, CA 90024
# 65000000
# 30000
# 1.104
# -1
# ---------------------------------------------------------------------------
# 11492 Thurston Cir, Los Angeles, CA 90049
# 4195000
# 2950
# 0.2938
# -1
# ---------------------------------------------------------------------------
# 15216 Antelo Pl, Los Angeles, CA 90077
# 14900000
# 9395
# 2.5132
# -1
# ---------------------------------------------------------------------------
# 2310 N Catalina St, Los Angeles, CA 90027
# 7479000
# 5200
# 0.6022
# -1
# ---------------------------------------------------------------------------
# 670 Perugia Way, Los Angeles, CA 90077
# 38500000
# 14282
# 1.2494
# -1
# ---------------------------------------------------------------------------
# 1615 Blue Jay Way, Los Angeles, CA 90069
# 23995000
# 11500
# 0.5791
# -1
# ---------------------------------------------------------------------------
# 1078 Villa Grove Dr, Pacific Palisades, CA 90272
# 4195000
# 2283
# 0.2632
# -1
# ---------------------------------------------------------------------------
# 5415 Amestoy Ave, Encino, CA 91316
# 5995000
# 5734
# 0.5066
# -1
# ---------------------------------------------------------------------------
# 2669 Harlesden Ct, Los Angeles, CA 90046
# 4998000
# 4311
# 0.34
# -1
# ---------------------------------------------------------------------------
# 8509 Hollywood Blvd, Los Angeles, CA 90069
# 4400000
# 2036
# 0.2626
# -1
# ---------------------------------------------------------------------------
# Page: 3
# Search string: los angeles, ca
# 10829 Winnetka Ave, Chatsworth, CA 91311
# 5495000
# 13619
# 2.2734
# -1
# ---------------------------------------------------------------------------
# 2401 Ocean Front Walk, Venice, CA 90291
# 7350000
# 3815
# 2522.124
# -1
# ---------------------------------------------------------------------------
# 15216 Antelo Pl, Los Angeles, CA 90077
# 14900000
# 9395
# 2.5132
# -1
# ---------------------------------------------------------------------------
# 10040 Toluca Lake Ave, Toluca Lake, CA 91602
# 5995000
# 4239
# 10254.024
# -1
# ---------------------------------------------------------------------------
# 9014 Alto Cedro Dr, Beverly Hills, CA 90210
# 9995000
# 5500
# 0.5018
# -1
# ---------------------------------------------------------------------------
# 11492 Thurston Cir, Los Angeles, CA 90049
# 4195000
# 2950
# 0.2938
# -1
# ---------------------------------------------------------------------------
# 1380 Mockingbird Pl, Los Angeles, CA 90069
# 44950000
# 14000
# 1.5407
# -1
# ---------------------------------------------------------------------------
# 10509 Vestone Way, Los Angeles, CA 90077
# 11900000
# 11251
# 1.5257
# -1
# ---------------------------------------------------------------------------
# 5415 Amestoy Ave, Encino, CA 91316
# 5995000
# 5734
# 0.5066
# -1
# ---------------------------------------------------------------------------
# 419 Rialto Ave, Venice, CA 90291
# 4995000
# 1617
# 2221.56
# -1
# ---------------------------------------------------------------------------
# 807 N Ogden Dr, Los Angeles, CA 90046
# 4495000
# 5121
# 6499.152
# -1
# ---------------------------------------------------------------------------
# 17528 Jayden Ln, Encino, CA 91316
# 12495000
# 11173
# 0.7815
# -1
# ---------------------------------------------------------------------------
# 524 Rialto Ave, Venice, CA 90291
# 5600000
# 3400
# 2552.616
# -1
# ---------------------------------------------------------------------------
# 1539 Courtney Ave, Los Angeles, CA 90046
# 4499000
# 4495
# 6751.8
# -1
# ---------------------------------------------------------------------------
# 4421 Haskell Ave, Encino, CA 91436
# 7900000
# 9864
# 0.4326
# -1
# ---------------------------------------------------------------------------
# 814 Toulon Dr, Pacific Palisades, CA 90272
# 23995000
# 8008
# 0.4271
# -1
# ---------------------------------------------------------------------------
# 1338 Bella Oceana Vis, Pacific Palisades, CA 90272
# 12950000
# 6230
# 0.9466
# -1
# ---------------------------------------------------------------------------
# 11375 Gladwin St, Los Angeles, CA 90049
# 5995000
# 5000
# 8184.924
# -1
# ---------------------------------------------------------------------------
# 1260 Bel Air Rd, Los Angeles, CA 90077
# 18750000
# 9000
# 1.7671
# -1
# ---------------------------------------------------------------------------
# 266 Quadro Vecchio Dr, Pacific Palisades, CA 90272
# 9995000
# 5950
# 9029.988
# -1
# ---------------------------------------------------------------------------
# 5370 Los Feliz Blvd, Los Angeles, CA 90027
# 5300000
# 6106
# 0.3473
# -1
# ---------------------------------------------------------------------------
# 2333 Mandeville Canyon Rd, Los Angeles, CA 90049
# 14250000
# 10600
# 0.6149
# -1
# ---------------------------------------------------------------------------
# 4775 Yarmouth Ave, Encino, CA 91316
# 6295000
# 5800
# 0.3728
# -1
# ---------------------------------------------------------------------------
# 2200 Summitridge Dr, Beverly Hills, CA 90210
# 13995000
# 8000
# 10174
# -1
# ---------------------------------------------------------------------------
# 637 S Lucerne Blvd, Los Angeles, CA 90005
# 7995000
# 13098
# 0.4339
# -1
# ---------------------------------------------------------------------------
# 156 S Bristol Ave, Los Angeles, CA 90049
# 18995000
# 9487
# 0.448
# -1
# ---------------------------------------------------------------------------
# 10102 Angelo View Dr, Beverly Hills, CA 90210
# 25495000
# 7000
# 0.3403
# -1
# ---------------------------------------------------------------------------
# 3918 Oakfield Dr, Sherman Oaks, CA 91423
# 4999999
# 6357
# 0.39947199265381
# -1
# ---------------------------------------------------------------------------
# 2576 Aberdeen Ave, Los Angeles, CA 90027
# 7199000
# 6136
# 0.4199
# -1
# ---------------------------------------------------------------------------
# 1615 Blue Jay Way, Los Angeles, CA 90069
# 23995000
# 11500
# 0.5791
# -1
# ---------------------------------------------------------------------------
# 14035 Aubrey Rd, Beverly Hills, CA 90210
# 20995000
# 16134
# 1.3564
# -1
# ---------------------------------------------------------------------------
# 317 S Windsor Blvd, Los Angeles, CA 90020
# 12999000
# 10821
# 0.41342975206612
# -1
# ---------------------------------------------------------------------------
# 1222 Hilldale Ave, Los Angeles, CA 90069
# 6495000
# 4639
# 6159.384
# -1
# ---------------------------------------------------------------------------
# 671 Latimer Rd, Santa Monica, CA 90402
# 18000000
# 5655
# 0.6067
# -1
# ---------------------------------------------------------------------------
# 414 S Cliffwood Ave, Los Angeles, CA 90049
# 21000000
# 6859
# 0.5971
# -1
# ---------------------------------------------------------------------------
# 1911 Sunset Plaza Dr, Los Angeles, CA 90069
# 6750000
# 4800
# 0.3481
# -1
# ---------------------------------------------------------------------------
# 1352 Palms Blvd, Venice, CA 90291
# 4200000
# 4476
# 0.25006887052342
# -1
# ---------------------------------------------------------------------------
# 10950 Bellagio Rd, Los Angeles, CA 90077
# 15200000
# 7830
# 0.7676
# -1
# ---------------------------------------------------------------------------
# 9330 Hazen Dr, Beverly Hills, CA 90210
# 14900000
# 8802
# 1.2205
# -1
# ---------------------------------------------------------------------------
# 314 N Barrington Ave, Los Angeles, CA 90049
# 15900000
# 8497
# 0.8312
# -1
# ---------------------------------------------------------------------------
# Page: 4
# Search string: los angeles, ca
# 4775 Yarmouth Ave, Encino, CA 91316
# 6295000
# 5800
# 0.3728
# -1
# ---------------------------------------------------------------------------
# 1911 Sunset Plaza Dr, Los Angeles, CA 90069
# 6750000
# 4800
# 0.3481
# -1
# ---------------------------------------------------------------------------
# 4915 Winnetka Ave, Woodland Hills, CA 91364
# 4995000
# 6124
# 1.4051
# -1
# ---------------------------------------------------------------------------
# 526 N Plymouth Blvd, Los Angeles, CA 90004
# 4500000
# 4273
# 6751
# -1
# ---------------------------------------------------------------------------
# 5370 Los Feliz Blvd, Los Angeles, CA 90027
# 5300000
# 6106
# 0.3473
# -1
# ---------------------------------------------------------------------------
# 791 Radcliffe Ave, Pacific Palisades, CA 90272
# 7300000
# 6000
# 10285
# -1
# ---------------------------------------------------------------------------
# 637 S Lucerne Blvd, Los Angeles, CA 90005
# 7995000
# 13098
# 0.4339
# -1
# ---------------------------------------------------------------------------
# 401 N Martel Ave, Los Angeles, CA 90036
# 4195000
# 4450
# 5832.684
# -1
# ---------------------------------------------------------------------------
# 419 Rialto Ave, Venice, CA 90291
# 4995000
# 1617
# 2221.56
# -1
# ---------------------------------------------------------------------------
# 15105 Mulholland Dr, Los Angeles, CA 90077
# 8500000
# 10463
# None
# -1
# ---------------------------------------------------------------------------
# 9330 Hazen Dr, Beverly Hills, CA 90210
# 14900000
# 8802
# 1.2205
# -1
# ---------------------------------------------------------------------------
# 9165 Cordell Dr, Los Angeles, CA 90069
# 16500000
# 7441
# 0.31
# -1
# ---------------------------------------------------------------------------
# 1899 Rising Glen Rd, Los Angeles, CA 90069
# 6900000
# 4630
# 0.9995
# -1
# ---------------------------------------------------------------------------
# 3007 Ocean Front Walk, Venice, CA 90291
# 6570000
# 3650
# 3650
# -1
# ---------------------------------------------------------------------------
# 960 Stradella Rd, Los Angeles, CA 90077
# 8195000
# 4320
# 2.0689
# -1
# ---------------------------------------------------------------------------
# 1404 Dawnridge Dr, Beverly Hills, CA 90210
# 7950000
# 8679
# 0.4009
# -1
# ---------------------------------------------------------------------------
# 317 S Windsor Blvd, Los Angeles, CA 90020
# 12999000
# 10821
# 0.41342975206612
# -1
# ---------------------------------------------------------------------------
# 7868 Electra Dr, Los Angeles, CA 90046
# 4999999
# 4173
# 10593.792
# -1
# ---------------------------------------------------------------------------
# 671 Latimer Rd, Santa Monica, CA 90402
# 18000000
# 5655
# 0.6067
# -1
# ---------------------------------------------------------------------------
# 314 N Barrington Ave, Los Angeles, CA 90049
# 15900000
# 8497
# 0.8312
# -1
# ---------------------------------------------------------------------------
# 2425 Mount Olympus Dr, Los Angeles, CA 90046
# 12990000
# 7062
# 6.0789
# -1
# ---------------------------------------------------------------------------
# 1288 Angelo Dr, Beverly Hills, CA 90210
# 15950000
# 5541
# 0.36730945821855
# -1
# ---------------------------------------------------------------------------
# 1514 Sorrento Dr, Pacific Palisades, CA 90272
# 12225000
# 5500
# 0.3912
# -1
# ---------------------------------------------------------------------------
# 9014 Alto Cedro Dr, Beverly Hills, CA 90210
# 9995000
# 5500
# 0.5018
# -1
# ---------------------------------------------------------------------------
# 14979 La Cumbre Dr, Pacific Palisades, CA 90272
# 7950000
# 5700
# 0.2808
# -1
# ---------------------------------------------------------------------------
# 1455 Robmar Dr, Beverly Hills, CA 90210
# 7390000
# 8675
# 0.5907
# -1
# ---------------------------------------------------------------------------
# 1414 Seabright Pl, Beverly Hills, CA 90210
# 21995000
# 10610
# 1.2549
# -1
# ---------------------------------------------------------------------------
# 1853 Noel Pl, Beverly Hills, CA 90210
# 4299000
# 3862
# 9094
# -1
# ---------------------------------------------------------------------------
# 929 Marco Pl, Venice, CA 90291
# 4895000
# 2650
# 3598
# -1
# ---------------------------------------------------------------------------
# 1601 San Remo Dr, Pacific Palisades, CA 90272
# 15195000
# 8981
# 0.6162
# -1
# ---------------------------------------------------------------------------
# 2457 Solar Dr, Los Angeles, CA 90046
# 4195000
# 4200
# 10166.904
# -1
# ---------------------------------------------------------------------------
# 1643 Stone Canyon Rd, Los Angeles, CA 90077
# 5925000
# 5436
# 0.36597796143251
# -1
# ---------------------------------------------------------------------------
# 736 N Vista St, Los Angeles, CA 90046
# 4399000
# 5900
# 7000.092
# -1
# ---------------------------------------------------------------------------
# 1365 Shadybrook Dr, Beverly Hills, CA 90210
# 8495000
# 7402
# 0.4273
# -1
# ---------------------------------------------------------------------------
# 10101 W Sunset Blvd, Los Angeles, CA 90077
# 13800000
# 8182
# 0.5553
# -1
# ---------------------------------------------------------------------------
# 1707 1/2 Rising Glen Rd, West Hollywood, CA 90069
# 9675000
# 4011
# 0.27056932966024
# -1
# ---------------------------------------------------------------------------
# 456 S Bundy Dr, Los Angeles, CA 90049
# 4595000
# 4297
# 0.2895
# -1
# ---------------------------------------------------------------------------
# 591 Paseo Miramar, Pacific Palisades, CA 90272
# 4195000
# 2847
# 0.4776
# -1
# ---------------------------------------------------------------------------
# 1580 Stone Canyon Rd, Los Angeles, CA 90077
# 18000000
# 9391
# 0.892
# -1
# ---------------------------------------------------------------------------
# 1750 Viewmont Dr, Los Angeles, CA 90069
# 5999000
# 5000
# 5601.816
# -1
# ---------------------------------------------------------------------------
# Page: 5
# Search string: los angeles, ca
# 3072 N Deep Canyon Dr, Beverly Hills, CA 90210
# 5680000
# 3918
# 1.1862
# -1
# ---------------------------------------------------------------------------
# 22751 Plummer St, Chatsworth, CA 91311
# 4295000
# 7786
# 1.3154
# -1
# ---------------------------------------------------------------------------
# 120 N Glenroy Ave, Los Angeles, CA 90049
# 24995000
# 14543
# 0.4935
# -1
# ---------------------------------------------------------------------------
# 405 Sherman Canal, Venice, CA 90291
# 4250000
# 3936
# 2848.824
# -1
# ---------------------------------------------------------------------------
# 1551 Benedict Canyon Dr, Beverly Hills, CA 90210
# 4950000
# 3126
# 8921.088
# -1
# ---------------------------------------------------------------------------
# 854 N Orlando Ave, Los Angeles, CA 90069
# 5495000
# 4204
# 0.2854
# -1
# ---------------------------------------------------------------------------
# 1444 Lachman Ln, Pacific Palisades, CA 90272
# 6495000
# 3472
# 0.5066
# -1
# ---------------------------------------------------------------------------
# 3551 Glenridge Dr, Sherman Oaks, CA 91423
# 4295000
# 5307
# 0.42465564738292
# -1
# ---------------------------------------------------------------------------
# 3140 Coldwater Canyon Ave, Studio City, CA 91604
# 6995000
# 2988
# 4.2259
# -1
# ---------------------------------------------------------------------------
# 948 N Orlando Ave, Los Angeles, CA 90069
# 17995000
# 8993
# 0.61
# -1
# ---------------------------------------------------------------------------
# 9368 Flicker Way, Los Angeles, CA 90069
# 10900000
# 6000
# 0.28436639118457
# -1
# ---------------------------------------------------------------------------
# 11550 Dilling St, Studio City, CA 91604
# 7250000
# 6604
# 0.37943067033976
# -1
# ---------------------------------------------------------------------------
# 10926 Cartwright Dr, Chatsworth, CA 91311
# 4299999
# 8130
# 0.52754820936639
# -1
# ---------------------------------------------------------------------------
# 4544 Woodley Ave, Encino, CA 91436
# 6399000
# 8020
# 0.3668
# -1
# ---------------------------------------------------------------------------
# 1111 Stradella Rd, Los Angeles, CA 90077
# 9600000
# 6771
# 1.9247
# -1
# ---------------------------------------------------------------------------
# 16865 Calle Bellevista, Pacific Palisades, CA 90272
# 12995000
# 10225
# 1.7509
# -1
# ---------------------------------------------------------------------------
# 9233 Swallow Dr, Los Angeles, CA 90069
# 13250000
# 8108
# 0.3477
# -1
# ---------------------------------------------------------------------------
# 15547 Valley Vista Blvd, Encino, CA 91436
# 6995000
# 7969
# 0.4419
# -1
# ---------------------------------------------------------------------------
# 805 Marco Pl, Venice, CA 90291
# 9450000
# 3944
# 6660.324
# -1
# ---------------------------------------------------------------------------
# 1595 Lindacrest Dr, Beverly Hills, CA 90210
# 4795000
# 5730
# 10394
# -1
# ---------------------------------------------------------------------------
# 641 Elkins Rd, Los Angeles, CA 90049
# 6995000
# 6780
# 9822.78
# -1
# ---------------------------------------------------------------------------
# 2100 Vine St, Los Angeles, CA 90068
# 6495000
# 5571
# 0.3623
# -1
# ---------------------------------------------------------------------------
# 1377 Miller Pl, Los Angeles, CA 90069
# 5695000
# 3175
# 7183.044
# -1
# ---------------------------------------------------------------------------
# 126 N Rossmore Ave, Los Angeles, CA 90004
# 4799000
# 5955
# 0.4592
# -1
# ---------------------------------------------------------------------------
# 5693 Holly Oak Dr, Los Angeles, CA 90068
# 6500000
# 3783
# 0.7562
# -1
# ---------------------------------------------------------------------------
# 3465 Mandeville Canyon Rd, Los Angeles, CA 90049
# 5000000
# 4400
# 3.3857
# -1
# ---------------------------------------------------------------------------
# 17067 Countess Pl, Encino, CA 91436
# 4395000
# 3805
# 0.5992
# -1
# ---------------------------------------------------------------------------
# 1814 Marcheeta Pl, Los Angeles, CA 90069
# 12995000
# 9800
# 0.299
# -1
# ---------------------------------------------------------------------------
# 2719 Benedict Canyon Dr, Beverly Hills, CA 90210
# 14995000
# 8023
# 1.5376
# -1
# ---------------------------------------------------------------------------
# 10530 Rochester Ave, Los Angeles, CA 90024
# 4195000
# 3895
# 6764.868
# -1
# ---------------------------------------------------------------------------
# 1195 Tower Grove Dr, Beverly Hills, CA 90210
# 12995000
# 5745
# 0.5259
# -1
# ---------------------------------------------------------------------------
# 633 N Crescent Heights Blvd, Los Angeles, CA 90048
# 5850000
# 6000
# 6246.504
# -1
# ---------------------------------------------------------------------------
# 3001 Benedict Canyon Dr, Beverly Hills, CA 90210
# 13400000
# 7100
# 1.5258
# -1
# ---------------------------------------------------------------------------
# 4619 Roma Ct, Marina Del Rey, CA 90292
# 8150000
# 6539
# 4634
# -1
# ---------------------------------------------------------------------------
# 619 S June St, Los Angeles, CA 90005
# 11900000
# 11059
# 0.7037
# -1
# ---------------------------------------------------------------------------
# 694 N Tigertail Rd, Los Angeles, CA 90049
# 5300000
# 4011
# 0.3898
# -1
# ---------------------------------------------------------------------------
# 1489 Stebbins Ter, Los Angeles, CA 90069
# 6200000
# 3564
# 6973.956
# -1
# ---------------------------------------------------------------------------
# 9000 Thrasher Ave, Los Angeles, CA 90069
# 14950000
# 5911
# 0.4089
# -1
# ---------------------------------------------------------------------------
# 1938 Fairburn Ave, Los Angeles, CA 90025
# 5700000
# 5700
# 6664.68
# -1
# ---------------------------------------------------------------------------
# 1234 Stradella Rd, Los Angeles, CA 90077
# 4500000
# 3131
# 1.3103
# -1
# ---------------------------------------------------------------------------
# Page: 6
# Search string: los angeles, ca
# 8661 Hillside Ave, Los Angeles, CA 90069
# 6295000
# 4668
# 8942.868
# -1
# ---------------------------------------------------------------------------
# 13023 W Sunset Blvd, Los Angeles, CA 90049
# 22999000
# 11616
# 0.4348
# -1
# ---------------------------------------------------------------------------
# 450 Sherman Canal, Venice, CA 90291
# 5500000
# 3771
# 2848.824
# -1
# ---------------------------------------------------------------------------
# 9233 Swallow Dr, Los Angeles, CA 90069
# 13250000
# 8108
# 0.3477
# -1
# ---------------------------------------------------------------------------
# 1571 Tower Grove Dr, Beverly Hills, CA 90210
# 8250000
# 7490
# 0.3127
# -1
# ---------------------------------------------------------------------------
# 1111 Stradella Rd, Los Angeles, CA 90077
# 9600000
# 6771
# 1.9247
# -1
# ---------------------------------------------------------------------------
# 694 N Tigertail Rd, Los Angeles, CA 90049
# 5300000
# 4011
# 0.3898
# -1
# ---------------------------------------------------------------------------
# 175 N McCadden Pl, Los Angeles, CA 90004
# 6499000
# 6900
# 0.25316804407714
# -1
# ---------------------------------------------------------------------------
# 2100 Vine St, Los Angeles, CA 90068
# 6495000
# 5571
# 0.3623
# -1
# ---------------------------------------------------------------------------
# 1195 Tower Grove Dr, Beverly Hills, CA 90210
# 12995000
# 5745
# 0.5259
# -1
# ---------------------------------------------------------------------------
# 1750 Viewmont Dr, Los Angeles, CA 90069
# 5999000
# 5000
# 5601.816
# -1
# ---------------------------------------------------------------------------
# 8494 Cole Crest Dr, Los Angeles, CA 90046
# 5500000
# 4080
# 1.374
# -1
# ---------------------------------------------------------------------------
# 11997 Foxboro Dr, Los Angeles, CA 90049
# 5950000
# 4463
# 8877.528
# -1
# ---------------------------------------------------------------------------
# 12119 Travis St, Los Angeles, CA 90049
# 9895000
# 7075
# 8062.956
# -1
# ---------------------------------------------------------------------------
# 1237 Villa Woods Dr, Pacific Palisades, CA 90272
# 6995000
# 8426
# 0.556
# -1
# ---------------------------------------------------------------------------
# 120 N Glenroy Ave, Los Angeles, CA 90049
# 24995000
# 14543
# 0.4935
# -1
# ---------------------------------------------------------------------------
# 218 Carroll Canal, Venice, CA 90291
# 5495000
# 3151
# 2851
# -1
# ---------------------------------------------------------------------------
# 2705 Ocean Front Walk, Venice, CA 90291
# 9695000
# 3849
# 2522.124
# -1
# ---------------------------------------------------------------------------
# 4619 Roma Ct, Marina Del Rey, CA 90292
# 8150000
# 6539
# 4634
# -1
# ---------------------------------------------------------------------------
# 3348 Clerendon Rd, Beverly Hills, CA 90210
# 7999000
# 7407
# 0.5319
# -1
# ---------------------------------------------------------------------------
# 880 Vista Pacifica, Pacific Palisades, CA 90272
# 26000000
# 8500
# 1.8825
# -1
# ---------------------------------------------------------------------------
# 4140 Dundee Dr, Los Angeles, CA 90027
# 6995000
# 5297
# 0.5405
# -1
# ---------------------------------------------------------------------------
# 1580 Stone Canyon Rd, Los Angeles, CA 90077
# 18000000
# 9391
# 0.892
# -1
# ---------------------------------------------------------------------------
# 9696 Antelope Rd, Beverly Hills, CA 90210
# 7900000
# 7400
# 0.94081726354454
# -1
# ---------------------------------------------------------------------------
# 1357 Miller Dr, Los Angeles, CA 90069
# 5499000
# 3629
# 10149
# -1
# ---------------------------------------------------------------------------
# 4705 Sophia Ave, Encino, CA 91436
# 4995000
# 2313
# 1
# -1
# ---------------------------------------------------------------------------
# 2331 Abbot Kinney Blvd, Venice, CA 90291
# 5795000
# 4134
# 3275.712
# -1
# ---------------------------------------------------------------------------
# 1410 Stradella Rd, Los Angeles, CA 90077
# 4900000
# 3271
# 0.7059
# -1
# ---------------------------------------------------------------------------
# 14979 La Cumbre Dr, Pacific Palisades, CA 90272
# 7950000
# 5700
# 0.2808
# -1
# ---------------------------------------------------------------------------
# 108 N Edinburgh Ave, Los Angeles, CA 90048
# 4295000
# 3504
# 6608.052
# -1
# ---------------------------------------------------------------------------
# 249 S Westgate Ave, Los Angeles, CA 90049
# 8950000
# 9501
# 0.2682
# -1
# ---------------------------------------------------------------------------
# 13106 Pontoon P L, Los Angeles, CA 90049
# 4800000
# 5190
# 9456.876
# -1
# ---------------------------------------------------------------------------
# 948 Bel Air Rd, Los Angeles, CA 90077
# 19995000
# 17000
# 1.0039
# -1
# ---------------------------------------------------------------------------
# 1140 Brooklawn Dr, Los Angeles, CA 90077
# 7850000
# 5278
# 0.35466023875115
# -1
# ---------------------------------------------------------------------------
# 8527 Hedges Way, Los Angeles, CA 90069
# 9990000
# 5055
# 0.5579
# -1
# ---------------------------------------------------------------------------
# 12063 Crest Ct, Beverly Hills, CA 90210
# 13995000
# 8140
# 0.529
# -1
# ---------------------------------------------------------------------------
# 540 N Beverly Glen Blvd, Los Angeles, CA 90077
# 10750000
# 4095
# 0.9028
# -1
# ---------------------------------------------------------------------------
# 2791 Ellison Dr, Beverly Hills, CA 90210
# 9850000
# 5806
# 1.0544
# -1
# ---------------------------------------------------------------------------
# 1145 Stradella Rd, Los Angeles, CA 90077
# 12000000
# 5580
# 1.1376
# -1
# ---------------------------------------------------------------------------
# 415 N Cliffwood Ave, Los Angeles, CA 90049
# 9750000
# 5559
# 0.3768
# -1
# ---------------------------------------------------------------------------
# Page: 7
# Search string: los angeles, ca
# 3348 Clerendon Rd, Beverly Hills, CA 90210
# 7999000
# 7407
# 0.5319
# -1
# ---------------------------------------------------------------------------
# 1145 Stradella Rd, Los Angeles, CA 90077
# 12000000
# 5580
# 1.1376
# -1
# ---------------------------------------------------------------------------
# 8555 Hollywood Blvd, West Hollywood, CA 90069
# 7199000
# 4706
# 0.354
# -1
# ---------------------------------------------------------------------------
# 1357 Miller Dr, Los Angeles, CA 90069
# 5499000
# 3629
# 10149
# -1
# ---------------------------------------------------------------------------
# 17605 Embassy Dr, Encino, CA 91316
# 4500000
# 4412
# 0.3663
# -1
# ---------------------------------------------------------------------------
# 2331 Abbot Kinney Blvd, Venice, CA 90291
# 5795000
# 4134
# 3275.712
# -1
# ---------------------------------------------------------------------------
# 1211 Linda Flora Dr, Los Angeles, CA 90049
# 7950000
# 8631
# 2.7493
# -1
# ---------------------------------------------------------------------------
# 10200 Lilac Ln, Simi Valley, CA 93063
# 4325000
# 4067
# 21.2312
# -1
# ---------------------------------------------------------------------------
# 883 Linda Flora Dr, Los Angeles, CA 90049
# 10850000
# 11388
# 1.0753
# -1
# ---------------------------------------------------------------------------
# 1212 Abbot Kinney Blvd STE C, Venice, CA 90291
# 6995000
# 4300
# 5244.624
# -1
# ---------------------------------------------------------------------------
# 1610 Viewmont Dr, Los Angeles, CA 90069
# 5395000
# 4339
# 6181.164
# -1
# ---------------------------------------------------------------------------
# 12007 Crest Ct, Beverly Hills, CA 90210
# 10900000
# 5649
# 0.3096
# -1
# ---------------------------------------------------------------------------
# 2791 Ellison Dr, Beverly Hills, CA 90210
# 9850000
# 5806
# 1.0544
# -1
# ---------------------------------------------------------------------------
# 11947 Iredell St, Studio City, CA 91604
# 8250000
# 7843
# 0.8774334251607
# -1
# ---------------------------------------------------------------------------
# 540 N Beverly Glen Blvd, Los Angeles, CA 90077
# 10750000
# 4095
# 0.9028
# -1
# ---------------------------------------------------------------------------
# 1140 Brooklawn Dr, Los Angeles, CA 90077
# 7850000
# 5278
# 0.35466023875115
# -1
# ---------------------------------------------------------------------------
# 735 N Bonhill Rd, Los Angeles, CA 90049
# 21995000
# 8500
# 2.3544
# -1
# ---------------------------------------------------------------------------
# 1250 Angelo Dr, Beverly Hills, CA 90210
# 11945000
# 7390
# 0.35247933884298
# -1
# ---------------------------------------------------------------------------
# 9696 Antelope Rd, Beverly Hills, CA 90210
# 7900000
# 7400
# 0.94081726354454
# -1
# ---------------------------------------------------------------------------
# 1227 N Tigertail Rd, Los Angeles, CA 90049
# 8850000
# 6407
# 0.356
# -1
# ---------------------------------------------------------------------------
# 732 Vernon Ave, Venice, CA 90291
# 4137000
# 3591
# 4800.312
# -1
# ---------------------------------------------------------------------------
# 16479 Royal Hills Dr, Encino, CA 91436
# 8995000
# 6750
# 0.4029
# -1
# ---------------------------------------------------------------------------
# 4701 S Ocean Front Walk, Marina Del Rey, CA 90292
# 9999999
# 4043
# 3801
# -1
# ---------------------------------------------------------------------------
# 2399 Mandeville Canyon Rd, Los Angeles, CA 90049
# 15900000
# 5081
# 1.0456
# -1
# ---------------------------------------------------------------------------
# 175 N McCadden Pl, Los Angeles, CA 90004
# 6499000
# 6900
# 0.25316804407714
# -1
# ---------------------------------------------------------------------------
# 645 Alma Real Dr, Pacific Palisades, CA 90272
# 10000000
# 2367
# 0.3933
# -1
# ---------------------------------------------------------------------------
# 12221 Benmore Ter, Los Angeles, CA 90049
# 5950000
# 5134
# 0.9496
# -1
# ---------------------------------------------------------------------------
# 7200 La Presa Dr, Los Angeles, CA 90068
# 4795000
# 3085
# 0.9696
# -1
# ---------------------------------------------------------------------------
# 145 Channel Pointe Mall, Marina Del Rey, CA 90292
# 6595000
# 4767
# 3741.804
# -1
# ---------------------------------------------------------------------------
# 100 S Edinburgh Ave, Los Angeles, CA 90048
# 4950000
# 3089
# 6560.136
# -1
# ---------------------------------------------------------------------------
# 31 Oakmont Dr, Los Angeles, CA 90049
# 10500000
# 5355
# 0.469
# -1
# ---------------------------------------------------------------------------
# 357 N Formosa Ave, Los Angeles, CA 90036
# 4400000
# 5000
# 7697.052
# -1
# ---------------------------------------------------------------------------
# 765 N Tigertail Rd, Los Angeles, CA 90049
# 8995000
# 2468
# 1.0317
# -1
# ---------------------------------------------------------------------------
# 441 N Rockingham Ave, Los Angeles, CA 90049
# 13250000
# 7445
# 0.75711662075298
# -1
# ---------------------------------------------------------------------------
# 9100 Hazen Dr, Beverly Hills, CA 90210
# 8395000
# 8428
# 0.7554
# -1
# ---------------------------------------------------------------------------
# 9376 Claircrest Dr, Beverly Hills, CA 90210
# 10500000
# 8129
# 0.5535
# -1
# ---------------------------------------------------------------------------
# 8673 Hollywood Blvd, Los Angeles, CA 90069
# 4000000
# 4462
# 0.2676
# -1
# ---------------------------------------------------------------------------
# 5003 Roma Ct, Marina Del Rey, CA 90292
# 4500000
# 4449
# 3750.516
# -1
# ---------------------------------------------------------------------------
# 12642 Woodgreen St, Los Angeles, CA 90066
# 4250000
# 4000
# 6250.86
# -1
# ---------------------------------------------------------------------------
# 123 W Via Mari, Marina Del Rey, CA 90292
# 7200000
# 5200
# 3149.388
# -1
# ---------------------------------------------------------------------------
# Page: 8
# Search string: los angeles, ca
# 441 N Rockingham Ave, Los Angeles, CA 90049
# 13250000
# 7445
# 0.75711662075298
# -1
# ---------------------------------------------------------------------------
# 2870 Royston Pl, Beverly Hills, CA 90210
# 4999000
# 4102
# 0.652
# -1
# ---------------------------------------------------------------------------
# 8673 Hollywood Blvd, Los Angeles, CA 90069
# 4000000
# 4462
# 0.2676
# -1
# ---------------------------------------------------------------------------
# 4833 Morella Ave, Valley Village, CA 91607
# 6498000
# 7500
# 0.5654
# -1
# ---------------------------------------------------------------------------
# 466 Downes Rd, Los Angeles, CA 90049
# 6250000
# 3823
# 0.3917
# -1
# ---------------------------------------------------------------------------
# 2071 N Beverly Dr, Beverly Hills, CA 90210
# 8000000
# 7160
# 0.8887
# -1
# ---------------------------------------------------------------------------
# 645 Alma Real Dr, Pacific Palisades, CA 90272
# 10000000
# 2367
# 0.3933
# -1
# ---------------------------------------------------------------------------
# 1817 Blue Heights Dr, Los Angeles, CA 90069
# 4295000
# 4421
# 0.3328
# -1
# ---------------------------------------------------------------------------
# 123 W Via Mari, Marina Del Rey, CA 90292
# 7200000
# 5200
# 3149.388
# -1
# ---------------------------------------------------------------------------
# 3701 Eureka Dr, Studio City, CA 91604
# 5995000
# 3875
# 1.2466
# -1
# ---------------------------------------------------------------------------
# 9314 Sierra Mar Dr, Los Angeles, CA 90069
# 4450000
# 3929
# 5998.212
# -1
# ---------------------------------------------------------------------------
# 1 Apollo Dr, Los Angeles, CA 90046
# 4999999
# 2854
# 0.3142
# -1
# ---------------------------------------------------------------------------
# 2317 Oakwood Ave, Venice, CA 90291
# 5995000
# 14700
# 5000.688
# -1
# ---------------------------------------------------------------------------
# 984 Bel Air Rd, Los Angeles, CA 90077
# 4500000
# 3821
# 1.4835
# -1
# ---------------------------------------------------------------------------
# 1014 Myra Ave, Los Angeles, CA 90029
# 5400000
# 4402
# 0.3853
# -1
# ---------------------------------------------------------------------------
# Page: 9
# Search string: los angeles, ca
# 10979 Chalon Rd, Los Angeles, CA 90077
# 68500000
# 32000000
# 1.0293
# -1
# ---------------------------------------------------------------------------
# 594 S Mapleton Dr, Los Angeles, CA 90024
# 165000000
# 56500
# 4.6017
# -1
# ---------------------------------------------------------------------------
# 4565 Encino Ave, Encino, CA 91316
# 12995000
# 12300
# 0.50955004591368
# -1
# ---------------------------------------------------------------------------
# 9570 Hidden Valley Rd, Beverly Hills, CA 90210
# 19475000
# 5427
# 1.1639
# -1
# ---------------------------------------------------------------------------
# 9650 Cedarbrook Dr, Beverly Hills, CA 90210
# 250000000
# 78000
# 36.7309
# -1
# ---------------------------------------------------------------------------
# 5531 Red Oak Dr, Los Angeles, CA 90068
# 4599000
# 3960
# 7278.876
# -1
# ---------------------------------------------------------------------------
# 441 N Bristol Ave, Los Angeles, CA 90049
# 23500000
# 9385
# 0.4496
# -1
# ---------------------------------------------------------------------------
# 4050 Contera Rd, Encino, CA 91436
# 6479000
# 6297
# 0.33434343434343
# -1
# ---------------------------------------------------------------------------
# 2571 Wallingford Dr, Beverly Hills, CA 90210
# 85000000
# 38000
# 5.2
# -1
# ---------------------------------------------------------------------------
# 746 S Westholme Ave, Los Angeles, CA 90024
# 6750000
# 4504
# 9356.688
# -1
# ---------------------------------------------------------------------------
# 1332 Laurel Way, Beverly Hills, CA 90210
# 28950000
# 11220
# 0.4001
# -1
# ---------------------------------------------------------------------------
# 9332 Hazen Dr, Beverly Hills, CA 90210
# 5995000
# 5183
# 9909.9
# -1
# ---------------------------------------------------------------------------
# 101 S Larchmont Blvd, Los Angeles, CA 90004
# 4195000
# 3180
# 6926.04
# -1
# ---------------------------------------------------------------------------
# 10066 Cielo Dr, Beverly Hills, CA 90210
# 85000000
# 21000
# 3.6007
# -1
# ---------------------------------------------------------------------------
# 1369 Londonderry Pl, Los Angeles, CA 90069
# 37995000
# 14000
# 0.4288
# -1
# ---------------------------------------------------------------------------
# 16366 Sloan Dr, Los Angeles, CA 90049
# 5199000
# 4600
# 0.3489
# -1
# ---------------------------------------------------------------------------
# 2235 Hercules Dr, Los Angeles, CA 90046
# 7995000
# 6162
# 0.3163
# -1
# ---------------------------------------------------------------------------
# 4838 Calderon Rd, Woodland Hills, CA 91364
# 12999000
# 13379
# 0.6344
# -1
# ---------------------------------------------------------------------------
# 10250 W Sunset Blvd, Los Angeles, CA 90077
# 75000000
# 30000
# 2.8137
# -1
# ---------------------------------------------------------------------------
# 1420 Davies Dr, Beverly Hills, CA 90210
# 87000000
# 21800
# 7.8
# -1
# ---------------------------------------------------------------------------
# 643 Radcliffe Ave, Pacific Palisades, CA 90272
# 5395000
# 3677
# 0.2706
# -1
# ---------------------------------------------------------------------------
# 1640 Stradella Rd, Los Angeles, CA 90077
# 14995000
# 9246
# 0.9821
# -1
# ---------------------------------------------------------------------------
# 10480 W Sunset Blvd, Los Angeles, CA 90077
# 19995000
# 13000
# 0.4592
# -1
# ---------------------------------------------------------------------------
# 19333 Rosita St, Tarzana, CA 91356
# 7495000
# 9738
# 0.67063820018365
# -1
# ---------------------------------------------------------------------------
# 1714 Stone Canyon Rd, Los Angeles, CA 90077
# 20800000
# 17415
# 4.7716
# -1
# ---------------------------------------------------------------------------
# 4453 Balboa Ave, Encino, CA 91316
# 6795000
# 7500
# 1.0116
# -1
# ---------------------------------------------------------------------------
# 315 S Hudson Ave, Los Angeles, CA 90020
# 21950000
# 13240
# 0.696
# -1
# ---------------------------------------------------------------------------
# 1945 Linda Flora Dr, Los Angeles, CA 90077
# 10999988
# 7640
# 0.3973
# -1
# ---------------------------------------------------------------------------
# 15000 Corona Del Mar, Pacific Palisades, CA 90272
# 29995000
# 6673
# 0.7758
# -1
# ---------------------------------------------------------------------------
# 10771 Bellagio Rd, Los Angeles, CA 90077
# 65000000
# 19721
# 1.1949
# -1
# ---------------------------------------------------------------------------
# 15321 Kingswood Ln, Sherman Oaks, CA 91403
# 8995000
# 9075
# 0.47288797061524
# -1
# ---------------------------------------------------------------------------
# 9814 Curwood Pl, Beverly Hills, CA 90210
# 12868000
# 9500
# 0.7725
# -1
# ---------------------------------------------------------------------------
# 2189 Sunset Plaza Dr, Los Angeles, CA 90069
# 11000000
# 5332
# 8376.588
# -1
# ---------------------------------------------------------------------------
# 846 S Longwood Ave, Los Angeles, CA 90005
# 5999000
# 4508
# 0.335
# -1
# ---------------------------------------------------------------------------
# 16041 Woodvale Rd, Encino, CA 91436
# 26000000
# 19500
# 1.265
# -1
# ---------------------------------------------------------------------------
# 4546 White Oak Ave, Encino, CA 91316
# 7995000
# 8689
# 0.8604
# -1
# ---------------------------------------------------------------------------
# 2358 Kimridge Rd, Beverly Hills, CA 90210
# 7495000
# 6646
# 0.31593204775023
# -1
# ---------------------------------------------------------------------------
# 1699 Woods Dr, Los Angeles, CA 90069
# 5995000
# 3102
# 0.938
# -1
# ---------------------------------------------------------------------------
# 4048 Sunnyslope Ave, Sherman Oaks, CA 91423
# 5499000
# 5405
# 0.2935
# -1
# ---------------------------------------------------------------------------
# 161 Ashdale Pl, Los Angeles, CA 90049
# 11950000
# 6545
# 0.48553719008264
# -1
# ---------------------------------------------------------------------------
# Page: 10
# ...
# 10066 Cielo Dr, Beverly Hills, CA 90210
# 85000000
# 21000
# 3.6007
# -1
# ---------------------------------------------------------------------------
# 4430 Hayvenhurst Ave, Encino, CA 91436
# 9480000
# 7829
# 0.7187
# -1
# ---------------------------------------------------------------------------
# 2235 Hercules Dr, Los Angeles, CA 90046
# 7995000
# 6162
# 0.3163
# -1
# ---------------------------------------------------------------------------
# 4838 Calderon Rd, Woodland Hills, CA 91364
# 12999000
# 13379
# 0.6344
# -1
# ---------------------------------------------------------------------------
# 2571 Wallingford Dr, Beverly Hills, CA 90210
# 85000000
# 38000
# 5.2
# -1
# ---------------------------------------------------------------------------
# 1369 Londonderry Pl, Los Angeles, CA 90069
# 37995000
# 14000
# 0.4288
# -1
# ---------------------------------------------------------------------------
# 101 S Larchmont Blvd, Los Angeles, CA 90004
# 4195000
# 3180
# 6926.04
# -1
# ---------------------------------------------------------------------------
# 1714 Stone Canyon Rd, Los Angeles, CA 90077
# 20800000
# 17415
# 4.7716
# -1
# ---------------------------------------------------------------------------
# 1120 Angelo Dr, Beverly Hills, CA 90210
# 5500000
# 5138
# 0.322
# -1
# ---------------------------------------------------------------------------
# 1420 Davies Dr, Beverly Hills, CA 90210
# 87000000
# 21800
# 7.8
# -1
# ---------------------------------------------------------------------------
# 10250 W Sunset Blvd, Los Angeles, CA 90077
# 75000000
# 30000
# 2.8137
# -1
# ---------------------------------------------------------------------------
# 643 Radcliffe Ave, Pacific Palisades, CA 90272
# 5395000
# 3677
# 0.2706
# -1
# ---------------------------------------------------------------------------
# 5531 Red Oak Dr, Los Angeles, CA 90068
# 4599000
# 3960
# 7278.876
# -1
# ---------------------------------------------------------------------------
# 10771 Bellagio Rd, Los Angeles, CA 90077
# 65000000
# 19721
# 1.1949
# -1
# ---------------------------------------------------------------------------
# 16366 Sloan Dr, Los Angeles, CA 90049
# 5199000
# 4600
# 0.3489
# -1
# ---------------------------------------------------------------------------
# 1945 Linda Flora Dr, Los Angeles, CA 90077
# 10999988
# 7640
# 0.3973
# -1
# ---------------------------------------------------------------------------
# 315 S Hudson Ave, Los Angeles, CA 90020
# 21950000
# 13240
# 0.696
# -1
# ---------------------------------------------------------------------------
# 846 S Longwood Ave, Los Angeles, CA 90005
# 5999000
# 4508
# 0.335
# -1
# ---------------------------------------------------------------------------
# 1640 Stradella Rd, Los Angeles, CA 90077
# 14995000
# 9246
# 0.9821
# -1
# ---------------------------------------------------------------------------
# 15321 Kingswood Ln, Sherman Oaks, CA 91403
# 8995000
# 9075
# 0.47288797061524
# -1
# ---------------------------------------------------------------------------
# 9650 Cedarbrook Dr, Beverly Hills, CA 90210
# 250000000
# 78000
# 36.7309
# -1
# ---------------------------------------------------------------------------
# 271 S Mapleton Dr, Los Angeles, CA 90024
# 64950000
# 31450
# 1.4021
# -1
# ---------------------------------------------------------------------------
# 15000 Corona Del Mar, Pacific Palisades, CA 90272
# 29995000
# 6673
# 0.7758
# -1
# ---------------------------------------------------------------------------
# 19200 Rosita St, Tarzana, CA 91356
# 5880000
# 5289
# 0.4549
# -1
# ---------------------------------------------------------------------------
# 4048 Sunnyslope Ave, Sherman Oaks, CA 91423
# 5499000
# 5405
# 0.2935
# -1
# ---------------------------------------------------------------------------
# 4453 Balboa Ave, Encino, CA 91316
# 6795000
# 7500
# 1.0116
# -1
# ---------------------------------------------------------------------------
# 746 S Westholme Ave, Los Angeles, CA 90024
# 6750000
# 4504
# 9356.688
# -1
# ---------------------------------------------------------------------------
# 4651 Louise Ave, Encino, CA 91316
# 6298500
# 6114
# 0.42371441689624
# -1
# ---------------------------------------------------------------------------
# 9814 Curwood Pl, Beverly Hills, CA 90210
# 12868000
# 9500
# 0.7725
# -1
# ---------------------------------------------------------------------------
# 9726 Hensal Rd, Beverly Hills, CA 90210
# 6495000
# 4768
# 0.292
# -1
# ---------------------------------------------------------------------------
# 16041 Woodvale Rd, Encino, CA 91436
# 26000000
# 19500
# 1.265
# -1
# ---------------------------------------------------------------------------
# 19333 Rosita St, Tarzana, CA 91356
# 7495000
# 9738
# 0.67063820018365
# -1
# ---------------------------------------------------------------------------
# Page: 19
# Search string: los angeles, ca
# 10979 Chalon Rd, Los Angeles, CA 90077
# 68500000
# 32000000
# 1.0293
# -1
# ---------------------------------------------------------------------------
# 594 S Mapleton Dr, Los Angeles, CA 90024
# 165000000
# 56500
# 4.6017
# -1
# ---------------------------------------------------------------------------
# 4565 Encino Ave, Encino, CA 91316
# 12995000
# 12300
# 0.50955004591368
# -1
# ---------------------------------------------------------------------------
# 9570 Hidden Valley Rd, Beverly Hills, CA 90210
# 19475000
# 5427
# 1.1639
# -1
# ---------------------------------------------------------------------------
# 9650 Cedarbrook Dr, Beverly Hills, CA 90210
# 250000000
# 78000
# 36.7309
# -1
# ---------------------------------------------------------------------------
# 5531 Red Oak Dr, Los Angeles, CA 90068
# 4599000
# 3960
# 7278.876
# -1
# ---------------------------------------------------------------------------
# 441 N Bristol Ave, Los Angeles, CA 90049
# 23500000
# 9385
# 0.4496
# -1
# ---------------------------------------------------------------------------
# 4050 Contera Rd, Encino, CA 91436
# 6479000
# 6297
# 0.33434343434343
# -1
# ---------------------------------------------------------------------------
# 2571 Wallingford Dr, Beverly Hills, CA 90210
# 85000000
# 38000
# 5.2
# -1
# ---------------------------------------------------------------------------
# 746 S Westholme Ave, Los Angeles, CA 90024
# 6750000
# 4504
# 9356.688
# -1
# ---------------------------------------------------------------------------
# 1332 Laurel Way, Beverly Hills, CA 90210
# 28950000
# 11220
# 0.4001
# -1
# ---------------------------------------------------------------------------
# 9332 Hazen Dr, Beverly Hills, CA 90210
# 5995000
# 5183
# 9909.9
# -1
# ---------------------------------------------------------------------------
# 101 S Larchmont Blvd, Los Angeles, CA 90004
# 4195000
# 3180
# 6926.04
# -1
# ---------------------------------------------------------------------------
# 10066 Cielo Dr, Beverly Hills, CA 90210
# 85000000
# 21000
# 3.6007
# -1
# ---------------------------------------------------------------------------
# 1369 Londonderry Pl, Los Angeles, CA 90069
# 37995000
# 14000
# 0.4288
# -1
# ---------------------------------------------------------------------------
# 16366 Sloan Dr, Los Angeles, CA 90049
# 5199000
# 4600
# 0.3489
# -1
# ---------------------------------------------------------------------------
# 2235 Hercules Dr, Los Angeles, CA 90046
# 7995000
# 6162
# 0.3163
# -1
# ---------------------------------------------------------------------------
# 4838 Calderon Rd, Woodland Hills, CA 91364
# 12999000
# 13379
# 0.6344
# -1
# ---------------------------------------------------------------------------
# 10250 W Sunset Blvd, Los Angeles, CA 90077
# 75000000
# 30000
# 2.8137
# -1
# ---------------------------------------------------------------------------
# 1420 Davies Dr, Beverly Hills, CA 90210
# 87000000
# 21800
# 7.8
# -1
# ---------------------------------------------------------------------------
# 643 Radcliffe Ave, Pacific Palisades, CA 90272
# 5395000
# 3677
# 0.2706
# -1
# ---------------------------------------------------------------------------
# 1640 Stradella Rd, Los Angeles, CA 90077
# 14995000
# 9246
# 0.9821
# -1
# ---------------------------------------------------------------------------
# 10480 W Sunset Blvd, Los Angeles, CA 90077
# 19995000
# 13000
# 0.4592
# -1
# ---------------------------------------------------------------------------
# 19333 Rosita St, Tarzana, CA 91356
# 7495000
# 9738
# 0.67063820018365
# -1
# ---------------------------------------------------------------------------
# 1714 Stone Canyon Rd, Los Angeles, CA 90077
# 20800000
# 17415
# 4.7716
# -1
# ---------------------------------------------------------------------------
# 4453 Balboa Ave, Encino, CA 91316
# 6795000
# 7500
# 1.0116
# -1
# ---------------------------------------------------------------------------
# 315 S Hudson Ave, Los Angeles, CA 90020
# 21950000
# 13240
# 0.696
# -1
# ---------------------------------------------------------------------------
# 1945 Linda Flora Dr, Los Angeles, CA 90077
# 10999988
# 7640
# 0.3973
# -1
# ---------------------------------------------------------------------------
# 15000 Corona Del Mar, Pacific Palisades, CA 90272
# 29995000
# 6673
# 0.7758
# -1
# ---------------------------------------------------------------------------
# 10771 Bellagio Rd, Los Angeles, CA 90077
# 65000000
# 19721
# 1.1949
# -1
# ---------------------------------------------------------------------------
# 15321 Kingswood Ln, Sherman Oaks, CA 91403
# 8995000
# 9075
# 0.47288797061524
# -1
# ---------------------------------------------------------------------------
# 9814 Curwood Pl, Beverly Hills, CA 90210
# 12868000
# 9500
# 0.7725
# -1
# ---------------------------------------------------------------------------
# 2189 Sunset Plaza Dr, Los Angeles, CA 90069
# 11000000
# 5332
# 8376.588
# -1
# ---------------------------------------------------------------------------
# 846 S Longwood Ave, Los Angeles, CA 90005
# 5999000
# 4508
# 0.335
# -1
# ---------------------------------------------------------------------------
# 16041 Woodvale Rd, Encino, CA 91436
# 26000000
# 19500
# 1.265
# -1
# ---------------------------------------------------------------------------
# 4546 White Oak Ave, Encino, CA 91316
# 7995000
# 8689
# 0.8604
# -1
# ---------------------------------------------------------------------------
# 2358 Kimridge Rd, Beverly Hills, CA 90210
# 7495000
# 6646
# 0.31593204775023
# -1
# ---------------------------------------------------------------------------
# 1699 Woods Dr, Los Angeles, CA 90069
# 5995000
# 3102
# 0.938
# -1
# ---------------------------------------------------------------------------
# 4048 Sunnyslope Ave, Sherman Oaks, CA 91423
# 5499000
# 5405
# 0.2935
# -1
# ---------------------------------------------------------------------------
# 161 Ashdale Pl, Los Angeles, CA 90049
# 11950000
# 6545
# 0.48553719008264
# -1
# ---------------------------------------------------------------------------
# Page: 20
# Search string: los angeles, ca
# 594 S Mapleton Dr, Los Angeles, CA 90024
# 165000000
# 56500
# 4.6017
# -1
# ---------------------------------------------------------------------------
# 4050 Contera Rd, Encino, CA 91436
# 6479000
# 6297
# 0.33434343434343
# -1
# ---------------------------------------------------------------------------
# 9570 Hidden Valley Rd, Beverly Hills, CA 90210
# 19475000
# 5427
# 1.1639
# -1
# ---------------------------------------------------------------------------
# 1332 Laurel Way, Beverly Hills, CA 90210
# 28950000
# 11220
# 0.4001
# -1
# ---------------------------------------------------------------------------
# 10979 Chalon Rd, Los Angeles, CA 90077
# 68500000
# 32000000
# 1.0293
# -1
# ---------------------------------------------------------------------------
# 4565 Encino Ave, Encino, CA 91316
# 12995000
# 12300
# 0.50955004591368
# -1
# ---------------------------------------------------------------------------
# 9332 Hazen Dr, Beverly Hills, CA 90210
# 5995000
# 5183
# 9909.9
# -1
# ---------------------------------------------------------------------------
# 441 N Bristol Ave, Los Angeles, CA 90049
# 23500000
# 9385
# 0.4496
# -1
# ---------------------------------------------------------------------------
# 10066 Cielo Dr, Beverly Hills, CA 90210
# 85000000
# 21000
# 3.6007
# -1
# ---------------------------------------------------------------------------
# 4430 Hayvenhurst Ave, Encino, CA 91436
# 9480000
# 7829
# 0.7187
# -1
# ---------------------------------------------------------------------------
# 2235 Hercules Dr, Los Angeles, CA 90046
# 7995000
# 6162
# 0.3163
# -1
# ---------------------------------------------------------------------------
# 4838 Calderon Rd, Woodland Hills, CA 91364
# 12999000
# 13379
# 0.6344
# -1
# ---------------------------------------------------------------------------
# 2571 Wallingford Dr, Beverly Hills, CA 90210
# 85000000
# 38000
# 5.2
# -1
# ---------------------------------------------------------------------------
# 1369 Londonderry Pl, Los Angeles, CA 90069
# 37995000
# 14000
# 0.4288
# -1
# ---------------------------------------------------------------------------
# 101 S Larchmont Blvd, Los Angeles, CA 90004
# 4195000
# 3180
# 6926.04
# -1
# ---------------------------------------------------------------------------
# 1714 Stone Canyon Rd, Los Angeles, CA 90077
# 20800000
# 17415
# 4.7716
# -1
# ---------------------------------------------------------------------------
# 1120 Angelo Dr, Beverly Hills, CA 90210
# 5500000
# 5138
# 0.322
# -1
# ---------------------------------------------------------------------------
# 1420 Davies Dr, Beverly Hills, CA 90210
# 87000000
# 21800
# 7.8
# -1
# ---------------------------------------------------------------------------
# 10250 W Sunset Blvd, Los Angeles, CA 90077
# 75000000
# 30000
# 2.8137
# -1
# ---------------------------------------------------------------------------
# 643 Radcliffe Ave, Pacific Palisades, CA 90272
# 5395000
# 3677
# 0.2706
# -1
# ---------------------------------------------------------------------------
# 5531 Red Oak Dr, Los Angeles, CA 90068
# 4599000
# 3960
# 7278.876
# -1
# ---------------------------------------------------------------------------
# 10771 Bellagio Rd, Los Angeles, CA 90077
# 65000000
# 19721
# 1.1949
# -1
# ---------------------------------------------------------------------------
# 16366 Sloan Dr, Los Angeles, CA 90049
# 5199000
# 4600
# 0.3489
# -1
# ---------------------------------------------------------------------------
# 1945 Linda Flora Dr, Los Angeles, CA 90077
# 10999988
# 7640
# 0.3973
# -1
# ---------------------------------------------------------------------------
# 315 S Hudson Ave, Los Angeles, CA 90020
# 21950000
# 13240
# 0.696
# -1
# ---------------------------------------------------------------------------
# 846 S Longwood Ave, Los Angeles, CA 90005
# 5999000
# 4508
# 0.335
# -1
# ---------------------------------------------------------------------------
# 1640 Stradella Rd, Los Angeles, CA 90077
# 14995000
# 9246
# 0.9821
# -1
# ---------------------------------------------------------------------------
# 15321 Kingswood Ln, Sherman Oaks, CA 91403
# 8995000
# 9075
# 0.47288797061524
# -1
# ---------------------------------------------------------------------------
# 9650 Cedarbrook Dr, Beverly Hills, CA 90210
# 250000000
# 78000
# 36.7309
# -1
# ---------------------------------------------------------------------------
# 271 S Mapleton Dr, Los Angeles, CA 90024
# 64950000
# 31450
# 1.4021
# -1
# ---------------------------------------------------------------------------
# 15000 Corona Del Mar, Pacific Palisades, CA 90272
# 29995000
# 6673
# 0.7758
# -1
# ---------------------------------------------------------------------------
# 19200 Rosita St, Tarzana, CA 91356
# 5880000
# 5289
# 0.4549
# -1
# ---------------------------------------------------------------------------
# 4048 Sunnyslope Ave, Sherman Oaks, CA 91423
# 5499000
# 5405
# 0.2935
# -1
# ---------------------------------------------------------------------------
# 4453 Balboa Ave, Encino, CA 91316
# 6795000
# 7500
# 1.0116
# -1
# ---------------------------------------------------------------------------
# 746 S Westholme Ave, Los Angeles, CA 90024
# 6750000
# 4504
# 9356.688
# -1
# ---------------------------------------------------------------------------
# 4651 Louise Ave, Encino, CA 91316
# 6298500
# 6114
# 0.42371441689624
# -1
# ---------------------------------------------------------------------------
# 9814 Curwood Pl, Beverly Hills, CA 90210
# 12868000
# 9500
# 0.7725
# -1
# ---------------------------------------------------------------------------
# 9726 Hensal Rd, Beverly Hills, CA 90210
# 6495000
# 4768
# 0.292
# -1
# ---------------------------------------------------------------------------
# 16041 Woodvale Rd, Encino, CA 91436
# 26000000
# 19500
# 1.265
# -1
# ---------------------------------------------------------------------------
# 19333 Rosita St, Tarzana, CA 91356
# 7495000
# 9738
# 0.67063820018365
# -1
# ---------------------------------------------------------------------------
