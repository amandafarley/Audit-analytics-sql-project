# %%
# %load_ext sql

# %% [markdown]
# Connect to the sql_project database on AWS RDS

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE

# %% [markdown]
# # Exploratory Queries

# %% [markdown]
# #1 Data quality check.
# Theoretically if the account is in the trial balance listing, it should have an ending balance for this year. The account would not appear unless action happened within this year

# %%
# %%sql
# SELECT
#     account_name,
#     t.account_number,
#     entry_number,
#     balance_forward,
#     ytd_debits,
#     ytd_credits,
#     ending_balance,
#     PY_ytd_balance
# FROM trial_balance t
# JOIN account_names a
#     ON t.account_number = a.account_number
# WHERE ending_balance IS NULL;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('Burden', '4540', 9454, 0, 7069, 4045, None, None)]

# %% [markdown]
# Found there is an account that has no ending balance either last year or this year but has debits and credits that happened this year. The debits and credits are also not even/balanced which is suspicious. This account could be fradulent or the data could be inaccurate.

# %% [markdown]
# #1 continued for Zillow. Data quality checks

# %%
# %%sql
# SELECT
#     zpid,
#     address,
#     price,
#     sqft
# FROM zillow
# WHERE price IS NULL;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %% [markdown]
# No nulls found, the zillow data is complete. Makes sense since I pulled it from an API and not from the internet

# %% [markdown]
# #2 check if the trial balance is balancing by summing the credits and debits. Also summing the this year ending balance and last year ending balance to see how they compare.

# %%
# %%sql
# SELECT
#     SUM(ytd_debits) AS sum_debits,
#     SUM(ytd_credits) AS sum_credits,
#     SUM(ending_balance) AS sum_ending_balance,
#     SUM(PY_ytd_balance) AS prior_year_sum_ending_balance
# FROM trial_balance;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(Decimal('3427452698'), Decimal('3373152343'), Decimal('-25310524'), Decimal('-23292879'))]

# %% [markdown]
# The debits and credits do not balance so there must be some errors within the data or trial balance and auditors would need to investigate that. Comparing last year to this year is another common procedure auditors do to make sure this year's number does not look abnormally large (depending on what has changed in the business environment too). The ending balance comparison looks reasonable since they are both around 23-25 million.

# %% [markdown]
# #3 Comparing the relationship and checking Accounts receivable and Allowance for uncollectible accounts is important since these two accounts are directly related. Allowance for uncollectible accounts should be reasonably proportionate to accounts receivable.

# %%
# %%sql
# SELECT
#     t.account_number,
#     account_name,
#     balance_forward,
#     ytd_debits,
#     ytd_credits,
#     ending_balance,
#     PY_ytd_balance
# FROM trial_balance t
# JOIN account_names a
#     ON t.account_number = a.account_number
# WHERE t.account_number IN (2218, 2219)
# GROUP BY t.account_number;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 2 rows affected.
# [('2218', 'Accounts Receivable', 873964, 6093882, 4337829, 2630017, 1446972),
#  ('2219', 'Allowance For Uncoll Accts', -397234, 0, 0, -397234, -152642)]

# %% [markdown]
# This verifies the relationship between A/R and Allowance for uncollectible accounts is reasonable. Allowance for doubtful accounts roughly doubled but A/R also increased. We could further investigate why it seems they wrote off more uncollectibles this year than last if we felt we needed to.

# %% [markdown]
# #4 Using Min and Max to examine certain accounts and entries. Using this on accounts payable to see small/large entries for owing people money at the end of the year.

# %%
# %%sql
# SELECT
#     t.account_number,
#     account_name,
#     PY_ytd_balance,
#     MIN(ending_balance),
#     MAX(ending_balance)
# FROM trial_balance t
# JOIN account_names a
#     ON t.account_number = a.account_number
# WHERE t.account_number = 4001;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('4001', 'Accounts Payable', 0, -401604, 180)]

# %% [markdown]
# This shows 401604 is a very large number to have as an ending balance in the liability account so we might want to examine this specific entry and what department it goes to. 180 on the other hand is also odd for a liabilty account to be positive but it could be an entry paying off liability so could look into but not much worry.

# %% [markdown]
# #4 for zillow. Finding the min and max could be interesting to get a range and make sure there are not any outliers to investigate.

# %%
# %%sql
# SELECT
#     MIN(price) AS MinPrice,
#     MAX(price) AS MaxPrice
# FROM zillow;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('10000000', '9999999')]

# %% [markdown]
# The max and min prices are very similar which shows its a tight market but also that there are no outliers or weird data in the set. You could also do this on specific zipcodes if you wanted.

# %% [markdown]
# #5 Looking at depreciation relationships. There should be a relationship between depreciation and a contra asset account like accumulated depreciation. This finds our depreciation accounts for us.

# %%
# %%sql
# SELECT
#     t.account_number,
#     account_name,
#     balance_forward,
#     ytd_debits,
#     ytd_credits,
#     ending_balance,
#     PY_ytd_balance
# FROM trial_balance t
# JOIN account_names a
#     ON t.account_number = a.account_number
# WHERE account_name LIKE '%depreciation%';
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 96 rows affected.
# [('2423', 'Fleet Depreciation', 0, 0, 0, 0, 3392),
#  ('2423', 'Fleet Depreciation', 0, 0, 0, 0, 5168),
#  ('2423', 'Fleet Depreciation', 0, 25392, 0, 25392, 61080),
#  ('2423', 'Fleet Depreciation', 0, 2768, 0, 2768, 3688),
#  ('2423', 'Fleet Depreciation', 0, 146704, 0, 146704, 31000),
#  ('2423', 'Fleet Depreciation', 0, 8128, 0, 8128, 9752),
#  ('2423', 'Fleet Depreciation', 0, 8864, 0, 8864, 0),
#  ('2423', 'Fleet Depreciation', 0, 1088, 0, 1088, 0),
#  ('2423', 'Fleet Depreciation', 0, 26376, 0, 26376, 19552),
#  ('2423', 'Fleet Depreciation', 0, 19128, 0, 19128, 11496),
#  ('2423', 'Fleet Depreciation', 0, 211696, 0, 211696, 83624),
#  ('2423', 'Fleet Depreciation', 0, 3880, 0, 3880, 3232),
#  ('2423', 'Fleet Depreciation', 0, 3088, 0, 3088, 3088),
#  ('2423', 'Fleet Depreciation', 0, 11392, 0, 11392, 11392),
#  ('2423', 'Fleet Depreciation', 0, 102040, 0, 102040, 105064),
#  ('2423', 'Fleet Depreciation', 0, 52016, 0, 52016, 19960),
#  ('2423', 'Fleet Depreciation', 0, 1296, 0, 1296, 768),
#  ('2423', 'Fleet Depreciation', 0, 7480, 0, 7480, 7792),
#  ('2423', 'Fleet Depreciation', 0, 9776, 0, 9776, 9776),
#  ('2423', 'Fleet Depreciation', 0, 12024, 0, 12024, 7720),
#  ('2423', 'Fleet Depreciation', 0, 19936, 0, 19936, 19936),
#  ('2423', 'Fleet Depreciation', 0, 56856, 0, 56856, 47752),
#  ('2423', 'Fleet Depreciation', 0, 18016, 0, 18016, 9928),
#  ('2423', 'Fleet Depreciation', 0, 344, 0, 344, 344),
#  ('4100', 'Depreciation', 0, 1314, 0, 1314, 1502),
#  ('2423', 'Fleet Depreciation', 0, 10488, 0, 10488, 5760),
#  ('4100', 'Depreciation', 0, 1351424, 0, 1351424, 1611859),
#  ('4100', 'Depreciation', 0, 105044, 0, 105044, 113144),
#  ('2423', 'Fleet Depreciation', 0, 73056, 0, 73056, 71777),
#  ('2423', 'Fleet Depreciation', 0, 148208, 0, 148208, 4896),
#  ('2423', 'Fleet Depreciation', 0, 15256, 0, 15256, 15256),
#  ('2423', 'Fleet Depreciation', 0, 2400, 0, 2400, 2400),
#  ('2423', 'Fleet Depreciation', 0, 2184, 0, 2184, 2184),
#  ('2423', 'Fleet Depreciation', 0, 4832, 0, 4832, 4832),
#  ('2423', 'Fleet Depreciation', 0, 328, 0, 328, 328),
#  ('2423', 'Fleet Depreciation', 0, 1944, 0, 1944, 1944),
#  ('2423', 'Fleet Depreciation', 0, 1968, 0, 1968, 1968),
#  ('2423', 'Fleet Depreciation', 0, 14672, 0, 14672, 7207),
#  ('2423', 'Fleet Depreciation', 0, 212392, 0, 212392, 204384),
#  ('2423', 'Fleet Depreciation', 0, 30936, 0, 30936, 30936),
#  ('2423', 'Fleet Depreciation', 0, 8776, 0, 8776, 8776),
#  ('2423', 'Fleet Depreciation', 0, 18768, 0, 18768, 17216),
#  ('2423', 'Fleet Depreciation', 0, 120616, 0, 120616, 120616),
#  ('2423', 'Fleet Depreciation', 0, 9632, 0, 9632, 5600),
#  ('2423', 'Fleet Depreciation', 0, 18816, 0, 18816, 17808),
#  ('2423', 'Fleet Depreciation', 0, 53096, 0, 53096, 20384),
#  ('2423', 'Fleet Depreciation', 0, 544, 0, 544, 544),
#  ('2423', 'Fleet Depreciation', 0, 3720, 0, 3720, 3720),
#  ('2423', 'Fleet Depreciation', 0, 61584, 0, 61584, 68416),
#  ('2423', 'Fleet Depreciation', 0, 69688, 0, 69688, 64536),
#  ('2423', 'Fleet Depreciation', 0, 3928, 0, 3928, 3928),
#  ('2423', 'Fleet Depreciation', 0, 59048, 0, 59048, 29528),
#  ('4100', 'Depreciation', 0, 305146, 0, 305146, 347879),
#  ('2423', 'Fleet Depreciation', 0, 24976, 0, 24976, 24288),
#  ('4100', 'Depreciation', 0, 2955617, 0, 2955617, 2877756),
#  ('2423', 'Fleet Depreciation', 0, 2752, 0, 2752, 21912),
#  ('2423', 'Fleet Depreciation', 0, 40256, 0, 40256, 29824),
#  ('2423', 'Fleet Depreciation', 0, 21744, 0, 21744, 15136),
#  ('2423', 'Fleet Depreciation', 0, 10880, 0, 10880, 9864),
#  ('2423', 'Fleet Depreciation', 0, 68312, 0, 68312, 19608),
#  ('2423', 'Fleet Depreciation', 0, 0, 0, 0, 1016),
#  ('2423', 'Fleet Depreciation', 0, 28696, 0, 28696, 9656),
#  ('2423', 'Fleet Depreciation', 0, 3432, 0, 3432, 2032),
#  ('4100', 'Depreciation', 0, 4495773, 0, 4495773, 4948914),
#  ('4100', 'Depreciation', 0, 984570, 0, 984570, 1125224),
#  ('4100', 'Depreciation', 0, 41337, 0, 41337, 47540),
#  ('2423', 'Fleet Depreciation', 0, 5968, 0, 5968, 2144),
#  ('2423', 'Fleet Depreciation', 0, 9416, 0, 9416, 9416),
#  ('4100', 'Depreciation', 0, 13404, 0, 13404, 13036),
#  ('2423', 'Fleet Depreciation', 0, 4248, 0, 4248, 4248),
#  ('2423', 'Fleet Depreciation', 0, 4480, 0, 4480, 0),
#  ('4100', 'Depreciation', 0, 6913, 0, 6913, 7901),
#  ('2423', 'Fleet Depreciation', 0, 2184, 0, 2184, 2184),
#  ('2423', 'Fleet Depreciation', 0, 2536, 0, 2536, 2536),
#  ('2423', 'Fleet Depreciation', 0, 1056, 0, 1056, 1056),
#  ('2423', 'Fleet Depreciation', 0, 42296, 0, 42296, 27736),
#  ('2423', 'Fleet Depreciation', 0, 5160, 0, 5160, 4128),
#  ('2423', 'Fleet Depreciation', 0, 240, 0, 240, 240),
#  ('2423', 'Fleet Depreciation', 0, 70520, 0, 70520, 75888),
#  ('4100', 'Depreciation', 0, 499162, 0, 499162, 513206),
#  ('2423', 'Fleet Depreciation', 0, 61840, 0, 61840, 70648),
#  ('2423', 'Fleet Depreciation', 0, 75544, 0, 75544, 58272),
#  ('2423', 'Fleet Depreciation', 0, 34520, 0, 34520, 34520),
#  ('2423', 'Fleet Depreciation', 0, 27976, 0, 27976, 27440),
#  ('2423', 'Fleet Depreciation', 0, 10616, 0, 10616, 9336),
#  ('2423', 'Fleet Depreciation', 0, 3056, 0, 3056, 3056),
#  ('2423', 'Fleet Depreciation', 0, 0, 0, 0, 624),
#  ('2423', 'Fleet Depreciation', 0, 10520, 0, 10520, 9144),
#  ('2423', 'Fleet Depreciation', 0, 624, 0, 624, 0),
#  ('2423', 'Fleet Depreciation', 0, 5208, 0, 5208, 5208),
#  ('2423', 'Fleet Depreciation', 0, 16888, 0, 16888, 16888),
#  ('2423', 'Fleet Depreciation', 0, 0, 0, 0, 8200),
#  ('2423', 'Fleet Depreciation', 0, 429840, 0, 429840, 332736),
#  ('2423', 'Fleet Depreciation', 0, 10816, 0, 10816, 12096),
#  ('2423', 'Fleet Depreciation', 0, 27944, 0, 27944, 27944),
#  ('4100', 'Depreciation', 0, 550767, 0, 550767, 557362)]

# %% [markdown]
# This is concerning there is no credit account account associated with the debit depreciation account. There should be a credit to accumulated depreciation so it balances. We would need to look into where these credits are going like if they are going directly off the equipment rather than a contra asset account or if the data is incomplete.

# %% [markdown]
# # Business Question Queries

# %% [markdown]
# Directions: To answer your 3 questions of the data (1 primary and 2 related to the primary), you must use all 7 of the SQL features below. Features can be combined into a single query.
#
# 1.	GROUP BY
# 2.	JOIN
# 3.	CASE
# 4.	VIEW
# 5.	Common table expression (CTE)
# 6.	Subquery
# 7.	Window function
#
# In a Markdown cell above each SQL statement, provide the question, the business justification, and the SQL feature(s) used. In a Markdown cell below the SQL query's results, give the recommendation based on the results.

# %% [markdown]
# VIEW Syntax
# CREATE [OR REPLACE] VIEW view_name AS
#     SELECT columns
#     FROM tables
#     [WHERE conditions];
#
# Window function can use a rank or LAG

# %% [markdown]
# # 1) Primary business question: From an auditing perspective, are the valuations of the Trial Balance accounts (or for zillow the houses) what we expect?

# %% [markdown]
# In accounting we have multiple valuation methods depending on what guidelines you follow and other factors, historical cost or market valuation. Historical cost is valuing a buidling/asset at the cost it was purchased for (often years ago) while market valuation is what you could sell the asset for right now. If we had a house or building on our financial statements, the auditor could inspect zillow data to see the market price for similar buildings in the area.
#
# For this example, assuming we have a building in the 90077 zipcode around 15,000 sqft.
#
# This uses a subquery to extract addresses that are under these qualifications. It also uses a group by to be able to make sure it only shows one entry per address.

# %%
# %%sql
# SELECT
#     address,
#     sqft,
#     price
# FROM zillow
# WHERE address IN
#     (SELECT address
#      FROM zillow
#      WHERE sqft BETWEEN 13000 AND 17000
#         AND address LIKE '%90077')
# GROUP BY address
# ORDER BY price;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 4 rows affected.
# [('10480 W Sunset Blvd, Los Angeles, CA 90077', '13000', '19995000'),
#  ('948 Bel Air Rd, Los Angeles, CA 90077', '17000', '19995000'),
#  ('670 Perugia Way, Los Angeles, CA 90077', '14282', '38500000'),
#  ('111 N Mapleton Dr, Los Angeles, CA 90077', '14259', '43750000')]

# %% [markdown]
# This gives the market prices of comparable buildings in the 90077 area. From this you can see a building can be the same price even at 4,000 gap in square footage. The recommendation from here would be to compare your building on the financial statement to the price of these buildings to see if it is comparable. Also might have to look into other real estate factors for the valuation of the building but this is a great starting point.

# %% [markdown]
# # 2) Are the zillow listing comparable to each other? To use in valuation analysis

# %% [markdown]
# For the houses around 15,000 square footage in the 90077 area that we found in the above query, we could look at the max, min, and average price of them compared to each property to see what a better estimate of value would be. Some houses might be over or undervalued and not a good basis of our valuation.
#
# This uses a window function to be able to display the average home price, min and max home price, next to each home entry and price.

# %%
# %%sql
# SELECT
#     address,
#     price,
#     AVG(price) OVER () AS avg_price_for_houses,
#     price < AVG(price) OVER () AS price_less_than_avg_price_for_houses,
#     MIN(price) OVER () AS min_price_for_houses,
#     MAX(price) OVER () AS max_price_for_houses
# FROM zillow
# WHERE address LIKE '%90077'
#     AND sqft BETWEEN 13000 AND 17000
# GROUP BY address;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 4 rows affected.
# [('10480 W Sunset Blvd, Los Angeles, CA 90077', '19995000', 30560000.0, 1, '19995000', '43750000'),
#  ('111 N Mapleton Dr, Los Angeles, CA 90077', '43750000', 30560000.0, 0, '19995000', '43750000'),
#  ('670 Perugia Way, Los Angeles, CA 90077', '38500000', 30560000.0, 0, '19995000', '43750000'),
#  ('948 Bel Air Rd, Los Angeles, CA 90077', '19995000', 30560000.0, 1, '19995000', '43750000')]

# %% [markdown]
# This query shows there is a range of prices in the houses in the zip code and two of the houses are a lot more expensive than the average price. I would recommend we take the two houses priced at $19995000 out of the data we use for valuation because it will skew it.

# %% [markdown]
# When looking at comparability, we need to make sure the zillow listings are active. If the house has been on the market for too long and just sitting on zillow then it might not be a good data point to use in valuation. In this case, we are going to look at listings that have been on there for a day.
#
# This uses the VIEW function to be able to create this view for active listings.

# %%
# %%sql
# CREATE OR REPLACE VIEW active_zillow_listing AS
#     SELECT *
#     FROM zillow
#     WHERE days_on_zillow = -1;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM active_zillow_listing;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 1095 rows affected.
# [(1, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (2, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (3, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (4, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (5, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (6, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (7, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (8, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (9, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (10, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (11, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (12, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (13, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (14, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (15, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (16, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (17, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (18, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (19, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (20, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (21, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (22, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (23, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (24, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (25, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (26, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (27, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (28, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (29, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (30, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (31, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (32, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (33, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (34, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (35, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (36, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (37, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (38, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (39, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (40, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (41, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (42, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (43, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (44, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (45, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (46, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (47, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (48, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (49, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (50, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (51, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (52, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (53, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (54, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (55, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (56, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (57, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (58, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (59, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (60, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (61, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (62, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (63, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (64, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (65, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (66, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (67, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (68, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (69, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (70, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (71, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (72, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (73, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (74, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (75, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (76, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (77, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (78, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (79, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (80, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (81, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (82, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (83, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (84, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (85, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (86, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (87, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (88, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (89, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (90, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (91, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (92, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (93, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (94, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (95, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (96, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (97, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (98, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (99, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (100, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (101, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (102, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (103, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (104, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (105, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (106, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (107, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (108, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (109, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (110, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (111, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (112, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (113, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (114, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (115, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (116, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (117, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (118, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (119, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (120, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (121, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (122, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (123, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (124, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (125, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (126, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (127, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (128, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (129, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (130, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (131, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (132, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (133, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (134, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (135, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (136, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (137, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (138, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (139, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (140, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (141, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (142, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (143, '10480 W Sunset Blvd, Los Angeles, CA 90077', '19995000', '13000', '0.4592', '-1'),
#  (144, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (145, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (146, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (147, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (148, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (149, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (150, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (151, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (152, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (153, '2189 Sunset Plaza Dr, Los Angeles, CA 90069', '11000000', '5332', '8376.588', '-1'),
#  (154, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (155, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (156, '4546 White Oak Ave, Encino, CA 91316', '7995000', '8689', '0.8604', '-1'),
#  (157, '2358 Kimridge Rd, Beverly Hills, CA 90210', '7495000', '6646', '0.31593204775023', '-1'),
#  (158, '1699 Woods Dr, Los Angeles, CA 90069', '5995000', '3102', '0.938', '-1'),
#  (159, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (160, '161 Ashdale Pl, Los Angeles, CA 90049', '11950000', '6545', '0.48553719008264', '-1'),
#  (161, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (162, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (163, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (164, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (165, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (166, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (167, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (168, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (169, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (170, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (171, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (172, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (173, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (174, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (175, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (176, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (177, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (178, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (179, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (180, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (181, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (182, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (183, '10480 W Sunset Blvd, Los Angeles, CA 90077', '19995000', '13000', '0.4592', '-1'),
#  (184, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (185, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (186, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (187, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (188, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (189, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (190, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (191, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (192, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (193, '2189 Sunset Plaza Dr, Los Angeles, CA 90069', '11000000', '5332', '8376.588', '-1'),
#  (194, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (195, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (196, '4546 White Oak Ave, Encino, CA 91316', '7995000', '8689', '0.8604', '-1'),
#  (197, '2358 Kimridge Rd, Beverly Hills, CA 90210', '7495000', '6646', '0.31593204775023', '-1'),
#  (198, '1699 Woods Dr, Los Angeles, CA 90069', '5995000', '3102', '0.938', '-1'),
#  (199, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (200, '161 Ashdale Pl, Los Angeles, CA 90049', '11950000', '6545', '0.48553719008264', '-1'),
#  (201, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (202, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (203, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (204, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (205, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (206, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (207, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (208, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (209, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (210, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (211, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (212, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (213, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (214, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (215, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (216, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (217, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (218, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (219, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (220, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (221, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (222, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (223, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (224, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (225, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (226, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (227, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (228, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (229, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (230, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (231, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (232, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (233, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (234, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (235, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (236, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (237, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (238, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (239, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (240, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (241, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (242, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (243, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (244, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (245, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (246, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (247, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (248, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (249, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (250, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (251, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (252, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (253, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (254, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (255, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (256, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (257, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (258, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (259, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (260, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (261, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (262, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (263, '10480 W Sunset Blvd, Los Angeles, CA 90077', '19995000', '13000', '0.4592', '-1'),
#  (264, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (265, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (266, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (267, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (268, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (269, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (270, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (271, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (272, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (273, '2189 Sunset Plaza Dr, Los Angeles, CA 90069', '11000000', '5332', '8376.588', '-1'),
#  (274, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (275, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (276, '4546 White Oak Ave, Encino, CA 91316', '7995000', '8689', '0.8604', '-1'),
#  (277, '2358 Kimridge Rd, Beverly Hills, CA 90210', '7495000', '6646', '0.31593204775023', '-1'),
#  (278, '1699 Woods Dr, Los Angeles, CA 90069', '5995000', '3102', '0.938', '-1'),
#  (279, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (280, '161 Ashdale Pl, Los Angeles, CA 90049', '11950000', '6545', '0.48553719008264', '-1'),
#  (281, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (282, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (283, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (284, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (285, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (286, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (287, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (288, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (289, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (290, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (291, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (292, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (293, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (294, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (295, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (296, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (297, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (298, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (299, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (300, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (301, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (302, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (303, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (304, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (305, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (306, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (307, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (308, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (309, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (310, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (311, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (312, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (313, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (314, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (315, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (316, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (317, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (318, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (319, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (320, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (321, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (322, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (323, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (324, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (325, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (326, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (327, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (328, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (329, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (330, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (331, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (332, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (333, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (334, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (335, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (336, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (337, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (338, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (339, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (340, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (341, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (342, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (343, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (344, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (345, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (346, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (347, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (348, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (349, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (350, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (351, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (352, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (353, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (354, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (355, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (356, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (357, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (358, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (359, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (360, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (361, '10480 W Sunset Blvd, Los Angeles, CA 90077', '19995000', '13000', '0.4592', '-1'),
#  (362, '14984 Corona Del Mar, Pacific Palisades, CA 90272', '37500000', '9380', '0.7314', '-1'),
#  (363, '4509 Noeline Ave, Encino, CA 91436', '11995000', '10278', '0.72745638200184', '-1'),
#  (364, '161 Ashdale Pl, Los Angeles, CA 90049', '11950000', '6545', '0.48553719008264', '-1'),
#  (365, '4546 White Oak Ave, Encino, CA 91316', '7995000', '8689', '0.8604', '-1'),
#  (366, '300 Stone Canyon Rd, Los Angeles, CA 90077', '59000000', '17600', '1.9704', '-1'),
#  (367, '17647 Belinda St, Encino, CA 91316', '5685000', '8134', '0.4899', '-1'),
#  (368, '1 Bode Dr, Los Angeles, CA 90069', '19990000', '10000', '0.9917', '-1'),
#  (369, '2189 Sunset Plaza Dr, Los Angeles, CA 90069', '11000000', '5332', '8376.588', '-1'),
#  (370, '1251 Tower Grove Dr, Beverly Hills, CA 90210', '58000000', '14500', '1.1119', '-1'),
#  (371, '1871 N Stanley Ave, Los Angeles, CA 90046', '24995000', '10365', '0.691', '-1'),
#  (372, '307 Mount Holyoke Ave, Pacific Palisades, CA 90272', '7950000', '4336', '0.2716', '-1'),
#  (373, '1756 Clear View Dr, Beverly Hills, CA 90210', '8989000', '5556', '0.71829660238751', '-1'),
#  (374, '2358 Kimridge Rd, Beverly Hills, CA 90210', '7495000', '6646', '0.31593204775023', '-1'),
#  (375, '2505 Summitridge Dr, Beverly Hills, CA 90210', '29900000', '12860', '7.58', '-1'),
#  (376, '1699 Woods Dr, Los Angeles, CA 90069', '5995000', '3102', '0.938', '-1'),
#  (377, '1877 Rising Glen Rd, Los Angeles, CA 90069', '18500000', '8339', '0.53014233241506', '-1'),
#  (378, '1853 Sunset Plaza Dr, Los Angeles, CA 90069', '6699000', '5817', '0.6602', '-1'),
#  (379, '1380 Mockingbird Pl, Los Angeles, CA 90069', '44950000', '14000', '1.5407', '-1'),
#  (380, '357 Lorraine Blvd, Los Angeles, CA 90020', '15000000', '12565', '0.6191', '-1'),
#  (381, '2321 Castilian Dr, Los Angeles, CA 90068', '10995000', '9000', '10084.14', '-1'),
#  (382, '2401 Ocean Front Walk, Venice, CA 90291', '7350000', '3815', '2522.124', '-1'),
#  (383, '12094 Summit Cir, Beverly Hills, CA 90210', '6699000', '7453', '0.36919191919192', '-1'),
#  (384, '1422 Lachman Ln, Pacific Palisades, CA 90272', '6995000', '8552', '0.4379', '-1'),
#  (385, '1550 Amalfi Dr, Pacific Palisades, CA 90272', '46500000', '16773', '1.322', '-1'),
#  (386, '8029 Willow Glen Rd, Los Angeles, CA 90046', '4345000', '3713', '0.3158', '-1'),
#  (387, '11400 Sunshine Ter, Studio City, CA 91604', '12000000', '7600', '3.17', '-1'),
#  (388, '111 N Mapleton Dr, Los Angeles, CA 90077', '43750000', '14259', '1.3174', '-1'),
#  (389, '1324 Stradella Rd, Los Angeles, CA 90077', '11995000', '8656', '0.4552', '-1'),
#  (390, '1352 Palms Blvd, Venice, CA 90291', '4200000', '4476', '0.25006887052342', '-1'),
#  (391, '133 S Mapleton Dr, Los Angeles, CA 90024', '65000000', '30000', '1.104', '-1'),
#  (392, '11492 Thurston Cir, Los Angeles, CA 90049', '4195000', '2950', '0.2938', '-1'),
#  (393, '15216 Antelo Pl, Los Angeles, CA 90077', '14900000', '9395', '2.5132', '-1'),
#  (394, '2310 N Catalina St, Los Angeles, CA 90027', '7479000', '5200', '0.6022', '-1'),
#  (395, '670 Perugia Way, Los Angeles, CA 90077', '38500000', '14282', '1.2494', '-1'),
#  (396, '1615 Blue Jay Way, Los Angeles, CA 90069', '23995000', '11500', '0.5791', '-1'),
#  (397, '1078 Villa Grove Dr, Pacific Palisades, CA 90272', '4195000', '2283', '0.2632', '-1'),
#  (398, '5415 Amestoy Ave, Encino, CA 91316', '5995000', '5734', '0.5066', '-1'),
#  (399, '2669 Harlesden Ct, Los Angeles, CA 90046', '4998000', '4311', '0.34', '-1'),
#  (400, '8509 Hollywood Blvd, Los Angeles, CA 90069', '4400000', '2036', '0.2626', '-1'),
#  (401, '10829 Winnetka Ave, Chatsworth, CA 91311', '5495000', '13619', '2.2734', '-1'),
#  (402, '2401 Ocean Front Walk, Venice, CA 90291', '7350000', '3815', '2522.124', '-1'),
#  (403, '15216 Antelo Pl, Los Angeles, CA 90077', '14900000', '9395', '2.5132', '-1'),
#  (404, '10040 Toluca Lake Ave, Toluca Lake, CA 91602', '5995000', '4239', '10254.024', '-1'),
#  (405, '9014 Alto Cedro Dr, Beverly Hills, CA 90210', '9995000', '5500', '0.5018', '-1'),
#  (406, '11492 Thurston Cir, Los Angeles, CA 90049', '4195000', '2950', '0.2938', '-1'),
#  (407, '1380 Mockingbird Pl, Los Angeles, CA 90069', '44950000', '14000', '1.5407', '-1'),
#  (408, '10509 Vestone Way, Los Angeles, CA 90077', '11900000', '11251', '1.5257', '-1'),
#  (409, '5415 Amestoy Ave, Encino, CA 91316', '5995000', '5734', '0.5066', '-1'),
#  (410, '419 Rialto Ave, Venice, CA 90291', '4995000', '1617', '2221.56', '-1'),
#  (411, '807 N Ogden Dr, Los Angeles, CA 90046', '4495000', '5121', '6499.152', '-1'),
#  (412, '17528 Jayden Ln, Encino, CA 91316', '12495000', '11173', '0.7815', '-1'),
#  (413, '524 Rialto Ave, Venice, CA 90291', '5600000', '3400', '2552.616', '-1'),
#  (414, '1539 Courtney Ave, Los Angeles, CA 90046', '4499000', '4495', '6751.8', '-1'),
#  (415, '4421 Haskell Ave, Encino, CA 91436', '7900000', '9864', '0.4326', '-1'),
#  (416, '814 Toulon Dr, Pacific Palisades, CA 90272', '23995000', '8008', '0.4271', '-1'),
#  (417, '1338 Bella Oceana Vis, Pacific Palisades, CA 90272', '12950000', '6230', '0.9466', '-1'),
#  (418, '11375 Gladwin St, Los Angeles, CA 90049', '5995000', '5000', '8184.924', '-1'),
#  (419, '1260 Bel Air Rd, Los Angeles, CA 90077', '18750000', '9000', '1.7671', '-1'),
#  (420, '266 Quadro Vecchio Dr, Pacific Palisades, CA 90272', '9995000', '5950', '9029.988', '-1'),
#  (421, '5370 Los Feliz Blvd, Los Angeles, CA 90027', '5300000', '6106', '0.3473', '-1'),
#  (422, '2333 Mandeville Canyon Rd, Los Angeles, CA 90049', '14250000', '10600', '0.6149', '-1'),
#  (423, '4775 Yarmouth Ave, Encino, CA 91316', '6295000', '5800', '0.3728', '-1'),
#  (424, '2200 Summitridge Dr, Beverly Hills, CA 90210', '13995000', '8000', '10174', '-1'),
#  (425, '637 S Lucerne Blvd, Los Angeles, CA 90005', '7995000', '13098', '0.4339', '-1'),
#  (426, '156 S Bristol Ave, Los Angeles, CA 90049', '18995000', '9487', '0.448', '-1'),
#  (427, '10102 Angelo View Dr, Beverly Hills, CA 90210', '25495000', '7000', '0.3403', '-1'),
#  (428, '3918 Oakfield Dr, Sherman Oaks, CA 91423', '4999999', '6357', '0.39947199265381', '-1'),
#  (429, '2576 Aberdeen Ave, Los Angeles, CA 90027', '7199000', '6136', '0.4199', '-1'),
#  (430, '1615 Blue Jay Way, Los Angeles, CA 90069', '23995000', '11500', '0.5791', '-1'),
#  (431, '14035 Aubrey Rd, Beverly Hills, CA 90210', '20995000', '16134', '1.3564', '-1'),
#  (432, '317 S Windsor Blvd, Los Angeles, CA 90020', '12999000', '10821', '0.41342975206612', '-1'),
#  (433, '1222 Hilldale Ave, Los Angeles, CA 90069', '6495000', '4639', '6159.384', '-1'),
#  (434, '671 Latimer Rd, Santa Monica, CA 90402', '18000000', '5655', '0.6067', '-1'),
#  (435, '414 S Cliffwood Ave, Los Angeles, CA 90049', '21000000', '6859', '0.5971', '-1'),
#  (436, '1911 Sunset Plaza Dr, Los Angeles, CA 90069', '6750000', '4800', '0.3481', '-1'),
#  (437, '1352 Palms Blvd, Venice, CA 90291', '4200000', '4476', '0.25006887052342', '-1'),
#  (438, '10950 Bellagio Rd, Los Angeles, CA 90077', '15200000', '7830', '0.7676', '-1'),
#  (439, '9330 Hazen Dr, Beverly Hills, CA 90210', '14900000', '8802', '1.2205', '-1'),
#  (440, '314 N Barrington Ave, Los Angeles, CA 90049', '15900000', '8497', '0.8312', '-1'),
#  (441, '4775 Yarmouth Ave, Encino, CA 91316', '6295000', '5800', '0.3728', '-1'),
#  (442, '1911 Sunset Plaza Dr, Los Angeles, CA 90069', '6750000', '4800', '0.3481', '-1'),
#  (443, '4915 Winnetka Ave, Woodland Hills, CA 91364', '4995000', '6124', '1.4051', '-1'),
#  (444, '526 N Plymouth Blvd, Los Angeles, CA 90004', '4500000', '4273', '6751', '-1'),
#  (445, '5370 Los Feliz Blvd, Los Angeles, CA 90027', '5300000', '6106', '0.3473', '-1'),
#  (446, '791 Radcliffe Ave, Pacific Palisades, CA 90272', '7300000', '6000', '10285', '-1'),
#  (447, '637 S Lucerne Blvd, Los Angeles, CA 90005', '7995000', '13098', '0.4339', '-1'),
#  (448, '401 N Martel Ave, Los Angeles, CA 90036', '4195000', '4450', '5832.684', '-1'),
#  (449, '419 Rialto Ave, Venice, CA 90291', '4995000', '1617', '2221.56', '-1'),
#  (450, '15105 Mulholland Dr, Los Angeles, CA 90077', '8500000', '10463', None, '-1'),
#  (451, '9330 Hazen Dr, Beverly Hills, CA 90210', '14900000', '8802', '1.2205', '-1'),
#  (452, '9165 Cordell Dr, Los Angeles, CA 90069', '16500000', '7441', '0.31', '-1'),
#  (453, '1899 Rising Glen Rd, Los Angeles, CA 90069', '6900000', '4630', '0.9995', '-1'),
#  (454, '3007 Ocean Front Walk, Venice, CA 90291', '6570000', '3650', '3650', '-1'),
#  (455, '960 Stradella Rd, Los Angeles, CA 90077', '8195000', '4320', '2.0689', '-1'),
#  (456, '1404 Dawnridge Dr, Beverly Hills, CA 90210', '7950000', '8679', '0.4009', '-1'),
#  (457, '317 S Windsor Blvd, Los Angeles, CA 90020', '12999000', '10821', '0.41342975206612', '-1'),
#  (458, '7868 Electra Dr, Los Angeles, CA 90046', '4999999', '4173', '10593.792', '-1'),
#  (459, '671 Latimer Rd, Santa Monica, CA 90402', '18000000', '5655', '0.6067', '-1'),
#  (460, '314 N Barrington Ave, Los Angeles, CA 90049', '15900000', '8497', '0.8312', '-1'),
#  (461, '2425 Mount Olympus Dr, Los Angeles, CA 90046', '12990000', '7062', '6.0789', '-1'),
#  (462, '1288 Angelo Dr, Beverly Hills, CA 90210', '15950000', '5541', '0.36730945821855', '-1'),
#  (463, '1514 Sorrento Dr, Pacific Palisades, CA 90272', '12225000', '5500', '0.3912', '-1'),
#  (464, '9014 Alto Cedro Dr, Beverly Hills, CA 90210', '9995000', '5500', '0.5018', '-1'),
#  (465, '14979 La Cumbre Dr, Pacific Palisades, CA 90272', '7950000', '5700', '0.2808', '-1'),
#  (466, '1455 Robmar Dr, Beverly Hills, CA 90210', '7390000', '8675', '0.5907', '-1'),
#  (467, '1414 Seabright Pl, Beverly Hills, CA 90210', '21995000', '10610', '1.2549', '-1'),
#  (468, '1853 Noel Pl, Beverly Hills, CA 90210', '4299000', '3862', '9094', '-1'),
#  (469, '929 Marco Pl, Venice, CA 90291', '4895000', '2650', '3598', '-1'),
#  (470, '1601 San Remo Dr, Pacific Palisades, CA 90272', '15195000', '8981', '0.6162', '-1'),
#  (471, '2457 Solar Dr, Los Angeles, CA 90046', '4195000', '4200', '10166.904', '-1'),
#  (472, '1643 Stone Canyon Rd, Los Angeles, CA 90077', '5925000', '5436', '0.36597796143251', '-1'),
#  (473, '736 N Vista St, Los Angeles, CA 90046', '4399000', '5900', '7000.092', '-1'),
#  (474, '1365 Shadybrook Dr, Beverly Hills, CA 90210', '8495000', '7402', '0.4273', '-1'),
#  (475, '10101 W Sunset Blvd, Los Angeles, CA 90077', '13800000', '8182', '0.5553', '-1'),
#  (476, '1707 1/2 Rising Glen Rd, West Hollywood, CA 90069', '9675000', '4011', '0.27056932966024', '-1'),
#  (477, '456 S Bundy Dr, Los Angeles, CA 90049', '4595000', '4297', '0.2895', '-1'),
#  (478, '591 Paseo Miramar, Pacific Palisades, CA 90272', '4195000', '2847', '0.4776', '-1'),
#  (479, '1580 Stone Canyon Rd, Los Angeles, CA 90077', '18000000', '9391', '0.892', '-1'),
#  (480, '1750 Viewmont Dr, Los Angeles, CA 90069', '5999000', '5000', '5601.816', '-1'),
#  (481, '3072 N Deep Canyon Dr, Beverly Hills, CA 90210', '5680000', '3918', '1.1862', '-1'),
#  (482, '22751 Plummer St, Chatsworth, CA 91311', '4295000', '7786', '1.3154', '-1'),
#  (483, '120 N Glenroy Ave, Los Angeles, CA 90049', '24995000', '14543', '0.4935', '-1'),
#  (484, '405 Sherman Canal, Venice, CA 90291', '4250000', '3936', '2848.824', '-1'),
#  (485, '1551 Benedict Canyon Dr, Beverly Hills, CA 90210', '4950000', '3126', '8921.088', '-1'),
#  (486, '854 N Orlando Ave, Los Angeles, CA 90069', '5495000', '4204', '0.2854', '-1'),
#  (487, '1444 Lachman Ln, Pacific Palisades, CA 90272', '6495000', '3472', '0.5066', '-1'),
#  (488, '3551 Glenridge Dr, Sherman Oaks, CA 91423', '4295000', '5307', '0.42465564738292', '-1'),
#  (489, '3140 Coldwater Canyon Ave, Studio City, CA 91604', '6995000', '2988', '4.2259', '-1'),
#  (490, '948 N Orlando Ave, Los Angeles, CA 90069', '17995000', '8993', '0.61', '-1'),
#  (491, '9368 Flicker Way, Los Angeles, CA 90069', '10900000', '6000', '0.28436639118457', '-1'),
#  (492, '11550 Dilling St, Studio City, CA 91604', '7250000', '6604', '0.37943067033976', '-1'),
#  (493, '10926 Cartwright Dr, Chatsworth, CA 91311', '4299999', '8130', '0.52754820936639', '-1'),
#  (494, '4544 Woodley Ave, Encino, CA 91436', '6399000', '8020', '0.3668', '-1'),
#  (495, '1111 Stradella Rd, Los Angeles, CA 90077', '9600000', '6771', '1.9247', '-1'),
#  (496, '16865 Calle Bellevista, Pacific Palisades, CA 90272', '12995000', '10225', '1.7509', '-1'),
#  (497, '9233 Swallow Dr, Los Angeles, CA 90069', '13250000', '8108', '0.3477', '-1'),
#  (498, '15547 Valley Vista Blvd, Encino, CA 91436', '6995000', '7969', '0.4419', '-1'),
#  (499, '805 Marco Pl, Venice, CA 90291', '9450000', '3944', '6660.324', '-1'),
#  (500, '1595 Lindacrest Dr, Beverly Hills, CA 90210', '4795000', '5730', '10394', '-1'),
#  (501, '641 Elkins Rd, Los Angeles, CA 90049', '6995000', '6780', '9822.78', '-1'),
#  (502, '2100 Vine St, Los Angeles, CA 90068', '6495000', '5571', '0.3623', '-1'),
#  (503, '1377 Miller Pl, Los Angeles, CA 90069', '5695000', '3175', '7183.044', '-1'),
#  (504, '126 N Rossmore Ave, Los Angeles, CA 90004', '4799000', '5955', '0.4592', '-1'),
#  (505, '5693 Holly Oak Dr, Los Angeles, CA 90068', '6500000', '3783', '0.7562', '-1'),
#  (506, '3465 Mandeville Canyon Rd, Los Angeles, CA 90049', '5000000', '4400', '3.3857', '-1'),
#  (507, '17067 Countess Pl, Encino, CA 91436', '4395000', '3805', '0.5992', '-1'),
#  (508, '1814 Marcheeta Pl, Los Angeles, CA 90069', '12995000', '9800', '0.299', '-1'),
#  (509, '2719 Benedict Canyon Dr, Beverly Hills, CA 90210', '14995000', '8023', '1.5376', '-1'),
#  (510, '10530 Rochester Ave, Los Angeles, CA 90024', '4195000', '3895', '6764.868', '-1'),
#  (511, '1195 Tower Grove Dr, Beverly Hills, CA 90210', '12995000', '5745', '0.5259', '-1'),
#  (512, '633 N Crescent Heights Blvd, Los Angeles, CA 90048', '5850000', '6000', '6246.504', '-1'),
#  (513, '3001 Benedict Canyon Dr, Beverly Hills, CA 90210', '13400000', '7100', '1.5258', '-1'),
#  (514, '4619 Roma Ct, Marina Del Rey, CA 90292', '8150000', '6539', '4634', '-1'),
#  (515, '619 S June St, Los Angeles, CA 90005', '11900000', '11059', '0.7037', '-1'),
#  (516, '694 N Tigertail Rd, Los Angeles, CA 90049', '5300000', '4011', '0.3898', '-1'),
#  (517, '1489 Stebbins Ter, Los Angeles, CA 90069', '6200000', '3564', '6973.956', '-1'),
#  (518, '9000 Thrasher Ave, Los Angeles, CA 90069', '14950000', '5911', '0.4089', '-1'),
#  (519, '1938 Fairburn Ave, Los Angeles, CA 90025', '5700000', '5700', '6664.68', '-1'),
#  (520, '1234 Stradella Rd, Los Angeles, CA 90077', '4500000', '3131', '1.3103', '-1'),
#  (521, '8661 Hillside Ave, Los Angeles, CA 90069', '6295000', '4668', '8942.868', '-1'),
#  (522, '13023 W Sunset Blvd, Los Angeles, CA 90049', '22999000', '11616', '0.4348', '-1'),
#  (523, '450 Sherman Canal, Venice, CA 90291', '5500000', '3771', '2848.824', '-1'),
#  (524, '9233 Swallow Dr, Los Angeles, CA 90069', '13250000', '8108', '0.3477', '-1'),
#  (525, '1571 Tower Grove Dr, Beverly Hills, CA 90210', '8250000', '7490', '0.3127', '-1'),
#  (526, '1111 Stradella Rd, Los Angeles, CA 90077', '9600000', '6771', '1.9247', '-1'),
#  (527, '694 N Tigertail Rd, Los Angeles, CA 90049', '5300000', '4011', '0.3898', '-1'),
#  (528, '175 N McCadden Pl, Los Angeles, CA 90004', '6499000', '6900', '0.25316804407714', '-1'),
#  (529, '2100 Vine St, Los Angeles, CA 90068', '6495000', '5571', '0.3623', '-1'),
#  (530, '1195 Tower Grove Dr, Beverly Hills, CA 90210', '12995000', '5745', '0.5259', '-1'),
#  (531, '1750 Viewmont Dr, Los Angeles, CA 90069', '5999000', '5000', '5601.816', '-1'),
#  (532, '8494 Cole Crest Dr, Los Angeles, CA 90046', '5500000', '4080', '1.374', '-1'),
#  (533, '11997 Foxboro Dr, Los Angeles, CA 90049', '5950000', '4463', '8877.528', '-1'),
#  (534, '12119 Travis St, Los Angeles, CA 90049', '9895000', '7075', '8062.956', '-1'),
#  (535, '1237 Villa Woods Dr, Pacific Palisades, CA 90272', '6995000', '8426', '0.556', '-1'),
#  (536, '120 N Glenroy Ave, Los Angeles, CA 90049', '24995000', '14543', '0.4935', '-1'),
#  (537, '218 Carroll Canal, Venice, CA 90291', '5495000', '3151', '2851', '-1'),
#  (538, '2705 Ocean Front Walk, Venice, CA 90291', '9695000', '3849', '2522.124', '-1'),
# ...
#  (822, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (823, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (824, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (825, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (826, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (827, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (828, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (829, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (830, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (831, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (832, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (833, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (834, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (835, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (836, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (837, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (838, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (839, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (840, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (841, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (842, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (843, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (844, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (845, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (846, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (847, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (848, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (849, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (850, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (851, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (852, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (853, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (854, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (855, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (856, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (857, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (858, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (859, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (860, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (861, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (862, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (863, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (864, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (865, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (866, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (867, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (868, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (869, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (870, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (871, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (872, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (873, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (874, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (875, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (876, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (877, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (878, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (879, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (880, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (881, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (882, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (883, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (884, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (885, '271 S Mapleton Dr, Los Angeles, CA 90024', '64950000', '31450', '1.4021', '-1'),
#  (886, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (887, '19200 Rosita St, Tarzana, CA 91356', '5880000', '5289', '0.4549', '-1'),
#  (888, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (889, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (890, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (891, '4651 Louise Ave, Encino, CA 91316', '6298500', '6114', '0.42371441689624', '-1'),
#  (892, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (893, '9726 Hensal Rd, Beverly Hills, CA 90210', '6495000', '4768', '0.292', '-1'),
#  (894, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (895, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (896, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (897, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (898, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (899, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (900, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (901, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (902, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (903, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (904, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (905, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (906, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (907, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (908, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (909, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (910, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (911, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (912, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (913, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (914, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (915, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (916, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (917, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (918, '10480 W Sunset Blvd, Los Angeles, CA 90077', '19995000', '13000', '0.4592', '-1'),
#  (919, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (920, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (921, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (922, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (923, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (924, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (925, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (926, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (927, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (928, '2189 Sunset Plaza Dr, Los Angeles, CA 90069', '11000000', '5332', '8376.588', '-1'),
#  (929, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (930, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (931, '4546 White Oak Ave, Encino, CA 91316', '7995000', '8689', '0.8604', '-1'),
#  (932, '2358 Kimridge Rd, Beverly Hills, CA 90210', '7495000', '6646', '0.31593204775023', '-1'),
#  (933, '1699 Woods Dr, Los Angeles, CA 90069', '5995000', '3102', '0.938', '-1'),
#  (934, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (935, '161 Ashdale Pl, Los Angeles, CA 90049', '11950000', '6545', '0.48553719008264', '-1'),
#  (936, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (937, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (938, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (939, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (940, '9650 Cedarbrook Dr, Beverly Hills, CA 90210', '250000000', '78000', '36.7309', '-1'),
#  (941, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (942, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (943, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (944, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (945, '746 S Westholme Ave, Los Angeles, CA 90024', '6750000', '4504', '9356.688', '-1'),
#  (946, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (947, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (948, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (949, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (950, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (951, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (952, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (953, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (954, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (955, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (956, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (957, '1640 Stradella Rd, Los Angeles, CA 90077', '14995000', '9246', '0.9821', '-1'),
#  (958, '10480 W Sunset Blvd, Los Angeles, CA 90077', '19995000', '13000', '0.4592', '-1'),
#  (959, '19333 Rosita St, Tarzana, CA 91356', '7495000', '9738', '0.67063820018365', '-1'),
#  (960, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (961, '4453 Balboa Ave, Encino, CA 91316', '6795000', '7500', '1.0116', '-1'),
#  (962, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  (963, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (964, '15000 Corona Del Mar, Pacific Palisades, CA 90272', '29995000', '6673', '0.7758', '-1'),
#  (965, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (966, '15321 Kingswood Ln, Sherman Oaks, CA 91403', '8995000', '9075', '0.47288797061524', '-1'),
#  (967, '9814 Curwood Pl, Beverly Hills, CA 90210', '12868000', '9500', '0.7725', '-1'),
#  (968, '2189 Sunset Plaza Dr, Los Angeles, CA 90069', '11000000', '5332', '8376.588', '-1'),
#  (969, '846 S Longwood Ave, Los Angeles, CA 90005', '5999000', '4508', '0.335', '-1'),
#  (970, '16041 Woodvale Rd, Encino, CA 91436', '26000000', '19500', '1.265', '-1'),
#  (971, '4546 White Oak Ave, Encino, CA 91316', '7995000', '8689', '0.8604', '-1'),
#  (972, '2358 Kimridge Rd, Beverly Hills, CA 90210', '7495000', '6646', '0.31593204775023', '-1'),
#  (973, '1699 Woods Dr, Los Angeles, CA 90069', '5995000', '3102', '0.938', '-1'),
#  (974, '4048 Sunnyslope Ave, Sherman Oaks, CA 91423', '5499000', '5405', '0.2935', '-1'),
#  (975, '161 Ashdale Pl, Los Angeles, CA 90049', '11950000', '6545', '0.48553719008264', '-1'),
#  (976, '594 S Mapleton Dr, Los Angeles, CA 90024', '165000000', '56500', '4.6017', '-1'),
#  (977, '4050 Contera Rd, Encino, CA 91436', '6479000', '6297', '0.33434343434343', '-1'),
#  (978, '9570 Hidden Valley Rd, Beverly Hills, CA 90210', '19475000', '5427', '1.1639', '-1'),
#  (979, '1332 Laurel Way, Beverly Hills, CA 90210', '28950000', '11220', '0.4001', '-1'),
#  (980, '10979 Chalon Rd, Los Angeles, CA 90077', '68500000', '32000000', '1.0293', '-1'),
#  (981, '4565 Encino Ave, Encino, CA 91316', '12995000', '12300', '0.50955004591368', '-1'),
#  (982, '9332 Hazen Dr, Beverly Hills, CA 90210', '5995000', '5183', '9909.9', '-1'),
#  (983, '441 N Bristol Ave, Los Angeles, CA 90049', '23500000', '9385', '0.4496', '-1'),
#  (984, '10066 Cielo Dr, Beverly Hills, CA 90210', '85000000', '21000', '3.6007', '-1'),
#  (985, '4430 Hayvenhurst Ave, Encino, CA 91436', '9480000', '7829', '0.7187', '-1'),
#  (986, '2235 Hercules Dr, Los Angeles, CA 90046', '7995000', '6162', '0.3163', '-1'),
#  (987, '4838 Calderon Rd, Woodland Hills, CA 91364', '12999000', '13379', '0.6344', '-1'),
#  (988, '2571 Wallingford Dr, Beverly Hills, CA 90210', '85000000', '38000', '5.2', '-1'),
#  (989, '1369 Londonderry Pl, Los Angeles, CA 90069', '37995000', '14000', '0.4288', '-1'),
#  (990, '101 S Larchmont Blvd, Los Angeles, CA 90004', '4195000', '3180', '6926.04', '-1'),
#  (991, '1714 Stone Canyon Rd, Los Angeles, CA 90077', '20800000', '17415', '4.7716', '-1'),
#  (992, '1120 Angelo Dr, Beverly Hills, CA 90210', '5500000', '5138', '0.322', '-1'),
#  (993, '1420 Davies Dr, Beverly Hills, CA 90210', '87000000', '21800', '7.8', '-1'),
#  (994, '10250 W Sunset Blvd, Los Angeles, CA 90077', '75000000', '30000', '2.8137', '-1'),
#  (995, '643 Radcliffe Ave, Pacific Palisades, CA 90272', '5395000', '3677', '0.2706', '-1'),
#  (996, '5531 Red Oak Dr, Los Angeles, CA 90068', '4599000', '3960', '7278.876', '-1'),
#  (997, '10771 Bellagio Rd, Los Angeles, CA 90077', '65000000', '19721', '1.1949', '-1'),
#  (998, '16366 Sloan Dr, Los Angeles, CA 90049', '5199000', '4600', '0.3489', '-1'),
#  (999, '1945 Linda Flora Dr, Los Angeles, CA 90077', '10999988', '7640', '0.3973', '-1'),
#  (1000, '315 S Hudson Ave, Los Angeles, CA 90020', '21950000', '13240', '0.696', '-1'),
#  ...]

# %% [markdown]
# This query shows we have 1095 entries that are active on the market. I recommend we only use these entries in our valuation calculations

# %% [markdown]
# # Primary business question of valuation applying to the trial balance account: accounts receivable and allowance for uncollectible accounts reasonable?

# %% [markdown]
# An account we can check to see if it is valued at what we would expect is the allowance for uncollectible accounts. Usually the amount of accounts receivable that becomes uncollectible is consistent year over year or is based on a percentage. For example, allowance for uncollectible accounts could be 10% of accounts receivable.
#
# This uses A CTE to be able to sum the A/R account and the uncollectible account for prior and current year and then calculate the percent change in uncollectible rate. Within the CTEs we also use a join to be able to show the account name along with the account number and a group by to sum up by account number.

# %%
# %%sql
# WITH AR_total AS (
#     SELECT
#         t.account_number,
#         account_name,
#         balance_forward,
#         ytd_debits,
#         ytd_credits,
#         ending_balance AS ending_AR,
#         PY_ytd_balance AS prior_year_AR
#     FROM trial_balance t
#     JOIN account_names a
#         ON t.account_number = a.account_number
#     WHERE t.account_number = 2218
#     GROUP BY t.account_number
# ),
# Uncollectible_total AS (
#     SELECT
#         t.account_number,
#         account_name,
#         balance_forward,
#         ytd_debits,
#         ytd_credits,
#         ending_balance AS ending_uncollectible,
#         PY_ytd_balance AS prior_year_uncollectible
#     FROM trial_balance t
#     JOIN account_names a
#         ON t.account_number = a.account_number
#     WHERE t.account_number = 2219
#     GROUP BY t.account_number
# )
# SELECT
#     (ending_uncollectible / ending_AR) AS current_year_uncollectible_rate,
#     (prior_year_uncollectible / prior_year_AR) AS prior_year_uncollectible_rate
# FROM AR_total, Uncollectible_total;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(Decimal('-0.1510'), Decimal('-0.1055'))]

# %% [markdown]
# Based on these results the auditor would want to investigate why their uncollectible rate went up a full five percentage points and overall increased by 50%. Even if the overall A/R increased, it is suspicious the overall uncollectible rate increased by 5% from year to year. They could further look into if sales increased, if a major customer went out of business and could not pay them back, and overall what customers they sold product/services to that caused the increase in uncollectible amount.

# %% [markdown]
# Often in auditing we compare the prior year balance to the current year balance to determine if the current year balance is reasonable. With using a case when, we can easily flag which account's balance are above/below the prior year balances by having a column saying so next to each account. It also uses a join so we can display the account name with the account number.

# %%
# %%sql
# SELECT
#     t.account_number,
#     account_name,
#     ending_balance,
#     PY_ytd_balance,
#     (ending_balance - PY_ytd_balance) AS difference,
#     CASE
#         WHEN ending_balance > PY_ytd_balance THEN 'Current Year Greater than Prior Year'
#         WHEN ending_balance < PY_ytd_balance THEN 'Current Year Less than Prior Year'
#         ELSE 'Equal or N/A'
#     END AS Current_Versus_Prior_Balance
# FROM trial_balance t
# JOIN account_names a
#     ON t.account_number = a.account_number
# GROUP BY t.account_number
# ORDER BY difference;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 1168 rows affected.
# [('5551.0059', 'Deferred Revenue Deferred Inflow of Pension', -62719658, -722862, -61996796, 'Current Year Less than Prior Year'),
#  ('1129', 'Taxes Collected For Other Governments', -284781289, -225842198, -58939091, 'Current Year Less than Prior Year'),
#  ('1289', 'NTAM EAFE', 20061975, 48079212, -28017237, 'Current Year Less than Prior Year'),
#  ('2256', 'Amt For Debt Svc Gen Oper', 200384879, 226950803, -26565924, 'Current Year Less than Prior Year'),
#  ('5551.0052', 'Deferred Revenue Deferred Inflow of OPEB', -28800016, -13591573, -15208443, 'Current Year Less than Prior Year'),
#  ('2400.0010', 'Equity In 0010', -65883114, -52031307, -13851807, 'Current Year Less than Prior Year'),
#  ('5553', 'Unearned Revenue', -12091315, 0, -12091315, 'Current Year Less than Prior Year'),
#  ('1297', 'Hexavest', 0, 10254983, -10254983, 'Current Year Less than Prior Year'),
#  ('2400.0042', 'Equity In 0042', -80823603, -72172389, -8651214, 'Current Year Less than Prior Year'),
#  ('1006', 'Cash Treasurer Current Tax', 2046684, 9726742, -7680058, 'Current Year Less than Prior Year'),
#  ('2400.0043', 'Equity In 0043', -64298329, -57587756, -6710573, 'Current Year Less than Prior Year'),
#  ('1346', 'Affordable Housing Levy', -6326196, 0, -6326196, 'Current Year Less than Prior Year'),
#  ('1217', 'Cash Ret (Northern Trust)', 2630945, 8377689, -5746744, 'Current Year Less than Prior Year'),
#  ('2400.0103', 'Equity In 0103', -5718313, 0, -5718313, 'Current Year Less than Prior Year'),
#  ('6682', 'Contributed Assets Capital Projects', -70627030, -65411242, -5215788, 'Current Year Less than Prior Year'),
#  ('2266.0059', 'Deferred Outflow of Resources Deferred Outflow', 5192423, 10342749, -5150326, 'Current Year Less than Prior Year'),
#  ('2160', 'Federal Emerg Mgt Agcy - Grant', -2160440, 2073565, -4234005, 'Current Year Less than Prior Year'),
#  ('1290', 'Constitution Capt’l', 152845, 3929496, -3776651, 'Current Year Less than Prior Year'),
#  ('2400.0072', 'Equity In 0072', -32754542, -29444069, -3310473, 'Current Year Less than Prior Year'),
#  ('2400.00CP', 'Equity In 00CP', -5274302, -2053539, -3220763, 'Current Year Less than Prior Year'),
#  ('2400.0062', 'Equity In 0062', -18962630, -15746634, -3215996, 'Current Year Less than Prior Year'),
#  ('1298', 'WCM', 6500000, 9500000, -3000000, 'Current Year Less than Prior Year'),
#  ('2400.0012', 'Equity In 0012', -18252657, -15621966, -2630691, 'Current Year Less than Prior Year'),
#  ('2400.0069', 'Equity In 0069', -22757952, -20173426, -2584526, 'Current Year Less than Prior Year'),
#  ('2430', 'Contracted Services', 27110, 2216804, -2189694, 'Current Year Less than Prior Year'),
#  ('7111', 'Metered Service', -19194529, -17215277, -1979252, 'Current Year Less than Prior Year'),
#  ('2292', 'Prepaid Insurance', 254597, 2106884, -1852287, 'Current Year Less than Prior Year'),
#  ('7145', 'Capital Recovery Charge', -2475648, -713185, -1762463, 'Current Year Less than Prior Year'),
#  ('2400.0021', 'Equity In 0021', -17555293, -16041087, -1514206, 'Current Year Less than Prior Year'),
#  ('1024', 'Michigan CLASS DDA Bond 2019-A', 4353478, 5856726, -1503248, 'Current Year Less than Prior Year'),
#  ('2266.0052', 'Deferred Outflow of Resources Deferred Outflow', 16737554, 18206768, -1469214, 'Current Year Less than Prior Year'),
#  ('2R00.2020', 'Taxes Rec - Real Property 2020', 0, 1356021, -1356021, 'Current Year Less than Prior Year'),
#  ('1345', 'Sidewalk Construction Levy', -1265123, 0, -1265123, 'Current Year Less than Prior Year'),
#  ('2272', 'State Shared - Constitutional', -8220969, -7009211, -1211758, 'Current Year Less than Prior Year'),
#  ('4110', 'Principal', 1009987, 2139000, -1129013, 'Current Year Less than Prior Year'),
#  ('2800.0010', 'Fringe Transfer 0010', -3957174, -2830566, -1126608, 'Current Year Less than Prior Year'),
#  ('2257', 'Amt For Debt Svc Sp Rev Fund', 11513460, 12626460, -1113000, 'Current Year Less than Prior Year'),
#  ('2400.0102', 'Equity In 0102', -1067127, 2762, -1069889, 'Current Year Less than Prior Year'),
#  ('4605.4717', 'Contract Payable 5598-01 Benz Creek', -1060000, 0, -1060000, 'Current Year Less than Prior Year'),
#  ('6793.0125', 'Equities Gain/Loss Artisan International Value Fund', -1039640, 0, -1039640, 'Current Year Less than Prior Year'),
#  ('4T00.2021', 'Undistributed Taxes 2021', -939627, 0, -939627, 'Current Year Less than Prior Year'),
#  ('2400.0022', 'Equity In 0022', -4684034, -3757603, -926431, 'Current Year Less than Prior Year'),
#  ('2400.0057', 'Equity In 0057', -12442149, -11564207, -877942, 'Current Year Less than Prior Year'),
#  ('6201', 'Interest On Pooled Investments', 1872339, 2740297, -867958, 'Current Year Less than Prior Year'),
#  ('6793.009', 'quities Gain/Loss Constitution Capt’l', -832211, 0, -832211, 'Current Year Less than Prior Year'),
#  ('2400.0071', 'Equity In 0071', -9527027, -8710000, -817027, 'Current Year Less than Prior Year'),
#  ('4605.472', 'ontract Payable 5626-01 Millers Crk-Pepper Pike', -780000, 35000, -815000, 'Current Year Less than Prior Year'),
#  ('1208', 'Constit Ironsides Co III', 2612834, 3421489, -808655, 'Current Year Less than Prior Year'),
#  ('3320', 'Vehicles', 24661890, 25468769, -806879, 'Current Year Less than Prior Year'),
#  ('1011', 'Cash Payroll', -950028, -186886, -763142, 'Current Year Less than Prior Year'),
#  ('2F00.2021', 'Taxes Rec - Tax Collect Fee 2021', -656816, 0, -656816, 'Current Year Less than Prior Year'),
#  ('5140.5435', ' Vehicles Utilities Field Equipment', 0, 624322, -624322, 'Current Year Less than Prior Year'),
#  ('8835', 'Restricted For Equipment Replacement', -12990684, -12369564, -621120, 'Current Year Less than Prior Year'),
#  ('2400.0026', 'Equity In 0026', -7517558, -6899221, -618337, 'Current Year Less than Prior Year'),
#  ('7999', 'Transfer-Grant/Loan Recipients', 633765, 1247529, -613764, 'Current Year Less than Prior Year'),
#  ('2221', 'WT/Gas Major Streets', -5929589, -5330359, -599230, 'Current Year Less than Prior Year'),
#  ('9959', 'Pension To Allocate', -1633062, -1034970, -598092, 'Current Year Less than Prior Year'),
#  ('1293', 'DRA G&I Fund IX', 1650646, 2244442, -593796, 'Current Year Less than Prior Year'),
#  ('1288', 'Summit Credit Fund II', 1444854, 2037852, -592998, 'Current Year Less than Prior Year'),
#  ('2710.0063', 'Operating Transfers 0063', -1347978, -774343, -573635, 'Current Year Less than Prior Year'),
#  ('4006', 'Accrued Sick Pay', -9295929, -8769322, -526607, 'Current Year Less than Prior Year'),
#  ('5103', 'U Of M Football', -527553, -35355, -492198, 'Current Year Less than Prior Year'),
#  ('6793.0007', 'Equities Gain/Loss TSE Capital', 0, 465739, -465739, 'Current Year Less than Prior Year'),
#  ('7113', 'Stormwater Service', -8350626, -7923571, -427055, 'Current Year Less than Prior Year'),
#  ('2400.0059', 'Equity In 0059', -733825, -316513, -417312, 'Current Year Less than Prior Year'),
#  ('5300.0001', 'Mun Svc Chg Other Community Development', -2257375, -1845827, -411548, 'Current Year Less than Prior Year'),
#  ('6796.0125', 'Equity Income Artisan International Value Fund', -411410, 0, -411410, 'Current Year Less than Prior Year'),
#  ('5540', 'Recyling Processing Credit', -676593, -268328, -408265, 'Current Year Less than Prior Year'),
#  ('2400.0100', 'Equity In 0100', -903574, -522031, -381543, 'Current Year Less than Prior Year'),
#  ('4626', 'Prescriptions', 5302259, 5676411, -374152, 'Current Year Less than Prior Year'),
#  ('4311', 'Building Permits', -2072895, -1700781, -372114, 'Current Year Less than Prior Year'),
#  ('3359', 'Work In Progress', 18650441, 19011085, -360644, 'Current Year Less than Prior Year'),
#  ('4005', 'Accrued Vacation Pay', -4574361, -4216281, -358080, 'Current Year Less than Prior Year'),
#  ('5140.565', 'Vehicles Building Cars', 0, 327790, -327790, 'Current Year Less than Prior Year'),
#  ('1120', 'Street Resurfacing Levy', -12016747, -11691469, -325278, 'Current Year Less than Prior Year'),
#  ('1114', 'Refuse Collection Levy', -14662557, -14341849, -320708, 'Current Year Less than Prior Year'),
#  ('2271', 'State Shared - Statutory', -1181717, -873189, -308528, 'Current Year Less than Prior Year'),
#  ('1115', 'Transportation (AATA) Levy', -12242287, -11943830, -298457, 'Current Year Less than Prior Year'),
#  ('2212', 'Due From Other Gov Units', -293537, 0, -293537, 'Current Year Less than Prior Year'),
#  ('2400.048L', 'Equity In 048L', 0, 291804, -291804, 'Current Year Less than Prior Year'),
#  ('1207', 'TSE Capital', 0, 286708, -286708, 'Current Year Less than Prior Year'),
#  ('2400.0084', 'Equity In 0084', -948026, -672360, -275666, 'Current Year Less than Prior Year'),
#  ('8010', 'Fleet Replacement - Fund 0010', -749832, -479432, -270400, 'Current Year Less than Prior Year'),
#  ('1285', 'DRA RE Gr & Inc Fund', 1658619, 1922214, -263595, 'Current Year Less than Prior Year'),
#  ('9931', 'Auction Sale Proceeds', -536390, -275200, -261190, 'Current Year Less than Prior Year'),
#  ('6794.0093', 'Real Estate G/L DRA G&I Fund IX', -316063, -54922, -261141, 'Current Year Less than Prior Year'),
#  ('6793.0078', 'Equities Gain/Loss Rhumbline -HEDI', -527777, -280736, -247041, 'Current Year Less than Prior Year'),
#  ('2219', 'Allowance For Uncoll Accts', -397234, -152642, -244592, 'Current Year Less than Prior Year'),
#  ('4021', 'Contingent Claims Payable', -2794290, -2558506, -235784, 'Current Year Less than Prior Year'),
#  ('2710.0043', 'Operating Transfers 0043', -232928, 0, -232928, 'Current Year Less than Prior Year'),
#  ('2400.0058', 'Equity In 0058', -705990, -478903, -227087, 'Current Year Less than Prior Year'),
#  ('1021', 'Cash Treas Curr Tax Bank Of AA', 2472, 226150, -223678, 'Current Year Less than Prior Year'),
#  ('4024', 'Due To Ann Arbor Transportation Authority', -109494, 110944, -220438, 'Current Year Less than Prior Year'),
#  ('9935', 'Undistributed Rev - Parking Violations', -221620, -6932, -214688, 'Current Year Less than Prior Year'),
#  ('2400.0036', 'Equity In 0036', -2941910, -2732124, -209786, 'Current Year Less than Prior Year'),
#  ('2400.0101', 'Equity In 0101', -746479, -537719, -208760, 'Current Year Less than Prior Year'),
#  ('2400.0034', 'Equity In 0034', -1618036, -1416045, -201991, 'Current Year Less than Prior Year'),
#  ('6987', 'Contributions & Memorials', -225700, -25200, -200500, 'Current Year Less than Prior Year'),
#  ('6793.0094', 'Equities Gain/Loss Silicon Valley Bank', -198740, 0, -198740, 'Current Year Less than Prior Year'),
#  ('6794.0009', 'Real Estate G/L Carlyle Realty VIII', -270348, -90301, -180047, 'Current Year Less than Prior Year'),
#  ('2222', 'WT/Gas Local Streets', -1660917, -1486817, -174100, 'Current Year Less than Prior Year'),
#  ('2800.0043', 'Fringe Transfer 0043', -404200, -237210, -166990, 'Current Year Less than Prior Year'),
#  ('5537', 'Front Load-Reg Pick-Ups', -2051623, -1885681, -165942, 'Current Year Less than Prior Year'),
#  ('4345', 'Plan Review Fee', -399291, -236377, -162914, 'Current Year Less than Prior Year'),
#  ('5120', 'Structures & Improvements', 0, 162609, -162609, 'Current Year Less than Prior Year'),
#  ('8021', 'Fleet Replacement - Fund 0021', -508176, -348120, -160056, 'Current Year Less than Prior Year'),
#  ('4517', 'Unamort Refund Bond - Gain/Loss', 2464583, 2620835, -156252, 'Current Year Less than Prior Year'),
#  ('2245', 'Environment, Great Lakes & Energy - Grant', -419999, -266405, -153594, 'Current Year Less than Prior Year'),
#  ('6803', 'Contrib-DDA', -150000, 0, -150000, 'Current Year Less than Prior Year'),
#  ('6793.0097', 'Equities Gain/Loss Hexavest', 0, 141397, -141397, 'Current Year Less than Prior Year'),
#  ('6793.0047', 'Equities Gain/Loss Loomis Sayles', -178800, -40167, -138633, 'Current Year Less than Prior Year'),
#  ('6796.0069', 'Equity Income DFA Emerging', -250815, -112382, -138433, 'Current Year Less than Prior Year'),
#  ('1130.1134', 'PFIT Water Bond Reserve CLASS', 2390803, 2518924, -128121, 'Current Year Less than Prior Year'),
#  ('2800.0026', 'Fringe Transfer 0026', -244004, -122048, -121956, 'Current Year Less than Prior Year'),
#  ('1125', 'Parks Maintenance & Repair', -3967300, -3850849, -116451, 'Current Year Less than Prior Year'),
#  ('5300.0002', 'Mun Svc Chg Other Public Services', -1464381, -1348700, -115681, 'Current Year Less than Prior Year'),
#  ('2P00.2020', 'Taxes Rec - Personal Property 2020', 74498, 186589, -112091, 'Current Year Less than Prior Year'),
#  ('8135', 'Salt', -280254, -169044, -111210, 'Current Year Less than Prior Year'),
#  ('4343', 'Housing Inspections', -374784, -268149, -106635, 'Current Year Less than Prior Year'),
#  ('4901', 'Utility Overpayments', -463904, -361183, -102721, 'Current Year Less than Prior Year'),
#  ('2350', 'DTE Charging Forward', -100000, 0, -100000, 'Current Year Less than Prior Year'),
#  ('6791.0015', 'Fixed Income Summit Credit III', -200747, -101787, -98960, 'Current Year Less than Prior Year'),
#  ('1128', 'County Mental Health Millage', -206882, -109549, -97333, 'Current Year Less than Prior Year'),
#  ('1522', 'Right Of Way Inspection Fee', -234158, -137542, -96616, 'Current Year Less than Prior Year'),
#  ('2800.0014', 'Fringe Transfer 0014', -419088, -324381, -94707, 'Current Year Less than Prior Year'),
#  ('2800', 'Fringe Transfer', -2880048, -2788872, -91176, 'Current Year Less than Prior Year'),
#  ('6794.0085', 'Real Estate G/L DRA RE Gr& Inc Fund', -152693, -65031, -87662, 'Current Year Less than Prior Year'),
#  ('8072', 'Fleet Replacement - Fund 0072', -493288, -405664, -87624, 'Current Year Less than Prior Year'),
#  ('8043', 'Fleet Replacement - Fund 0043', -173320, -87136, -86184, 'Current Year Less than Prior Year'),
#  ('1708', 'Pmt In Lieu Elderly Housing', -86181, 0, -86181, 'Current Year Less than Prior Year'),
#  ('1124', 'Parks Acquisition Millage', -2862045, -2776802, -85243, 'Current Year Less than Prior Year'),
#  ('2305.2303', 'Inventory Fleet Services', 396221, 480820, -84599, 'Current Year Less than Prior Year'),
#  ('5471', 'Rental-Kayak', -270749, -186591, -84158, 'Current Year Less than Prior Year'),
#  ('5447', 'Adult Hockey League', -84195, -186, -84009, 'Current Year Less than Prior Year'),
#  ('1597', 'Annual Fiber Usage Fee', -147892, -64167, -83725, 'Current Year Less than Prior Year'),
#  ('5459', 'Park Use  Fee', -74733, 5071, -79804, 'Current Year Less than Prior Year'),
#  ('5432', 'Swimming', -78304, -72, -78232, 'Current Year Less than Prior Year'),
#  ('2170', 'US Dept Of HUD - Grant', -76722, 0, -76722, 'Current Year Less than Prior Year'),
#  ('4605.4716', 'Contract Payable 5504.08 HRGI', -249508, -173320, -76188, 'Current Year Less than Prior Year'),
#  ('1033', 'Cash MNB EFT Grants', -124093, -50922, -73171, 'Current Year Less than Prior Year'),
#  ('2710.0102', 'Operating Transfers 0102', -73086, 0, -73086, 'Current Year Less than Prior Year'),
#  ('2400.0011', 'Equity In 0011', -2195383, -2122468, -72915, 'Current Year Less than Prior Year'),
#  ('1321', 'Wellington TALF Investment Fund (Cayman) LP', 4125, 76173, -72048, 'Current Year Less than Prior Year'),
#  ('1196', 'Disc On Investments', -1100137, -1028488, -71649, 'Current Year Less than Prior Year'),
#  ('4600.0059', 'Due To Other Funds 0059', -139463, -71696, -67767, 'Current Year Less than Prior Year'),
#  ('5300', 'Mun Svc Chg Other', -257551, -190213, -67338, 'Current Year Less than Prior Year'),
#  ('5102', 'U of M Basketball', -66353, 0, -66353, 'Current Year Less than Prior Year'),
#  ('2400.0041', 'Equity In 0041', -992809, -926531, -66278, 'Current Year Less than Prior Year'),
#  ('1510', 'Private Dev-Construction', -398696, -333316, -65380, 'Current Year Less than Prior Year'),
#  ('1532', 'Short Term Rental Registration Fee', -63225, 0, -63225, 'Current Year Less than Prior Year'),
#  ('6985', 'Reimbursement-Medicare Part D', -316471, -254236, -62235, 'Current Year Less than Prior Year'),
#  ('2155', 'US Dept Of Homeland Security Grant', -59515, 0, -59515, 'Current Year Less than Prior Year'),
#  ('2800.0049', 'Fringe Transfer 0049', -317648, -258758, -58890, 'Current Year Less than Prior Year'),
#  ('6814', 'Construction Reimbursement', -56000, 0, -56000, 'Current Year Less than Prior Year'),
#  ('1117', 'Smart Zone LDFA Taxes', -4713749, -4658895, -54854, 'Current Year Less than Prior Year'),
#  ('1126', 'Sidewalk Levy', -860185, -806119, -54066, 'Current Year Less than Prior Year'),
#  ('4007', 'Accrued Compensation Time', -1192875, -1138855, -54020, 'Current Year Less than Prior Year'),
#  ('2800.0021', 'Fringe Transfer 0021', -238103, -184323, -53780, 'Current Year Less than Prior Year'),
#  ('5140.532', 'Vehicles Detective Cars', 0, 52764, -52764, 'Current Year Less than Prior Year'),
#  ('6983', 'Reimbursement-Prescriptions', -1047338, -994910, -52428, 'Current Year Less than Prior Year'),
#  ('5444', 'Skating-Instructional', -76405, -24333, -52072, 'Current Year Less than Prior Year'),
#  ('2236', 'Special Assessment-Energy Improvement Loan', 83887, 135484, -51597, 'Current Year Less than Prior Year'),
#  ('2400.0099', 'Equity In Pooled cash & investments', 257435, 308970, -51535, 'Current Year Less than Prior Year'),
#  ('6795.0085', 'Real Estate Income DRA RE Gr & Inc Fund', -51015, 0, -51015, 'Current Year Less than Prior Year'),
#  ('4025', 'Due To Employees - HRA', -515469, -464497, -50972, 'Current Year Less than Prior Year'),
#  ('2693', 'Worker Comp Payments', 192722, 239164, -46442, 'Current Year Less than Prior Year'),
#  ('4113', 'Medical Marijuana Application Fee', -135000, -90000, -45000, 'Current Year Less than Prior Year'),
#  ('2180', 'US Dept Of Trans - Grant', -44750, 0, -44750, 'Current Year Less than Prior Year'),
#  ('4111.0002', 'CATV Franchise Fee AT&T', -41316, 3396, -44712, 'Current Year Less than Prior Year'),
#  ('1511', 'Civil Plan Review', -199706, -156178, -43528, 'Current Year Less than Prior Year'),
#  ('4505.4570', 'Other Debt Payable DWRF 7472-01, SERIES 2020', -3193961, -3150569, -43392, 'Current Year Less than Prior Year'),
#  ('5202', 'Fire False Alarm Fee', -115250, -72225, -43025, 'Current Year Less than Prior Year'),
#  ('4314', 'Mechanical Permits', -402409, -361732, -40677, 'Current Year Less than Prior Year'),
#  ('3109', 'Ordinance Fines & Costs', -256002, -215446, -40556, 'Current Year Less than Prior Year'),
#  ('5140.566', 'Vehicles Motor Pool Car', 0, 39772, -39772, 'Current Year Less than Prior Year'),
#  ('5109', 'BD Of Ed Spec Service', -47002, -8203, -38799, 'Current Year Less than Prior Year'),
#  ('5439', 'Swim Team', -37378, 0, -37378, 'Current Year Less than Prior Year'),
#  ('8310', 'Fleet Fuel - Fund 0010', -106202, -69815, -36387, 'Current Year Less than Prior Year'),
#  ('2800.0072', 'Fringe Transfer 0072', -154880, -118544, -36336, 'Current Year Less than Prior Year'),
#  ('2400.0070', 'Equity In 0070', -170731, -134773, -35958, 'Current Year Less than Prior Year'),
#  ('5441', 'Skating', -53780, -18216, -35564, 'Current Year Less than Prior Year'),
#  ('2165', 'Fair Food Grant', -65000, -29987, -35013, 'Current Year Less than Prior Year'),
#  ('8146', 'Non-Signals/Electrical', -34887, 0, -34887, 'Current Year Less than Prior Year'),
#  ('2400.059L', 'Equity In 059L', 33237, 66346, -33109, 'Current Year Less than Prior Year'),
#  ('8026', 'Fleet Replacement - Fund 0026', -53096, -20384, -32712, 'Current Year Less than Prior Year'),
#  ('5203', 'U of M - Fire Services', -40542, -8300, -32242, 'Current Year Less than Prior Year'),
#  ('6795.002', 'Real Estate Income DRA G&I X-Real Estate', -101009, -70426, -30583, 'Current Year Less than Prior Year'),
#  ('2710.0062', 'Operating Transfers 0062', -121976, -92040, -29936, 'Current Year Less than Prior Year'),
#  ('3830', 'Sign Supplies', 21597, 51332, -29735, 'Current Year Less than Prior Year'),
#  ('2303', 'Project Credit', -71079, -42417, -28662, 'Current Year Less than Prior Year'),
#  ('7969', 'Fleet Operation - Fund 0069', -207694, -179307, -28387, 'Current Year Less than Prior Year'),
#  ('4670', 'Dental Insurance Premiums', 383716, 411977, -28261, 'Current Year Less than Prior Year'),
#  ('6791.0088', 'Fixed Income Summit Credit Fund II', -69227, -41734, -27493, 'Current Year Less than Prior Year'),
#  ('6999', 'Miscellaneous', -36002, -9003, -26999, 'Current Year Less than Prior Year'),
#  ('2100.0097', 'Professional Services Hexavest', 0, 26972, -26972, 'Current Year Less than Prior Year'),
#  ('6796.0053', 'Equity Income Russell 1000', -328223, -301252, -26971, 'Current Year Less than Prior Year'),
#  ('2800.0069', 'Fringe Transfer 0069', -187066, -160120, -26946, 'Current Year Less than Prior Year'),
#  ('4511', 'Tax Refunds', 57925, 83600, -25675, 'Current Year Less than Prior Year'),
#  ('6740.0015', 'Fixed Gain/Loss Summit Credit III', -29363, -3826, -25537, 'Current Year Less than Prior Year'),
#  ('7922', 'Fleet Operation - Fund 0022', -154092, -128723, -25369, 'Current Year Less than Prior Year'),
#  ('4431', 'Death Benefit Payments', 0, 25000, -25000, 'Current Year Less than Prior Year'),
#  ('6795.0093', 'Real Estate Income DRA G&I Fund IX', -111397, -86771, -24626, 'Current Year Less than Prior Year'),
#  ('5479', 'Rental - Tube', -24060, -20, -24040, 'Current Year Less than Prior Year'),
#  ('3135', 'SCAO Drug Court Grant', -23633, 0, -23633, 'Current Year Less than Prior Year'),
#  ('7921', 'Fleet Operation - Fund 0021', -412052, -388596, -23456, 'Current Year Less than Prior Year'),
#  ('2402', 'Taxes Rec Delinquent Invoices', -111, 22515, -22626, 'Current Year Less than Prior Year'),
#  ('4109', 'Scooter Fees', -54800, -32600, -22200, 'Current Year Less than Prior Year'),
#  ('4040.4039', 'Deposits Util Consumers', -129530, -107667, -21863, 'Current Year Less than Prior Year'),
#  ('2800.0012', 'Fringe Transfer 0012', -86658, -66227, -20431, 'Current Year Less than Prior Year'),
#  ('2400.0017', 'Equity In 0017', -20684, -289, -20395, 'Current Year Less than Prior Year'),
#  ('6795.0020', 'Real Estate Income DRA G&I X-Real Estate', -67341, -46951, -20390, 'Current Year Less than Prior Year'),
#  ('7103', 'Merch & Jobbing-Cust Service', -20261, 0, -20261, 'Current Year Less than Prior Year'),
#  ('7215', '903 Airport Drive Lease', -58266, -38475, -19791, 'Current Year Less than Prior Year'),
#  ('2p00.2014', 'Taxes Rec - Personal Property 2014', 10196, 29866, -19670, 'Current Year Less than Prior Year'),
#  ('2710.0096', 'Operating Transfers 0096', -42620, -23319, -19301, 'Current Year Less than Prior Year'),
#  ('7101', 'Scio Twp/Govt Services/Util', -98013, -78782, -19231, 'Current Year Less than Prior Year'),
#  ('8143', 'Radio', -240592, -221696, -18896, 'Current Year Less than Prior Year'),
#  ('8069', 'Fleet Replacement - Fund 0069', -295896, -277208, -18688, 'Current Year Less than Prior Year'),
#  ('2710.0016', 'Operating Transfers 0016', -178966, -160476, -18490, 'Current Year Less than Prior Year'),
#  ('2800.0016', 'Fringe Transfer 0016', -134616, -116359, -18257, 'Current Year Less than Prior Year'),
#  ('1282', 'NTGI COLTV F/I', 30262326, 30280531, -18205, 'Current Year Less than Prior Year'),
#  ('4T00.2020', 'Undistributed Taxes 2020', -15461, 2169, -17630, 'Current Year Less than Prior Year'),
#  ('1340', 'Penalties/Delinquent Special Assessments & Taxes', -17441, 0, -17441, 'Current Year Less than Prior Year'),
#  ('2800.0103', 'Fringe Transfer 0103', -16304, 0, -16304, 'Current Year Less than Prior Year'),
#  ('7115', 'Residential Grading Permit Inspection', -40240, -24340, -15900, 'Current Year Less than Prior Year'),
#  ('5195', 'Infrastructure', -50571, -34948, -15623, 'Current Year Less than Prior Year'),
#  ('6804', 'Contrib-Housing Commission', -107468, -92216, -15252, 'Current Year Less than Prior Year'),
#  ('8141', 'Signals', -66074, -51035, -15039, 'Current Year Less than Prior Year'),
#  ('2223', 'Trunkline Maintenance', -42442, -27732, -14710, 'Current Year Less than Prior Year'),
#  ('5402', 'Livery Dam Maintenance Fee', -29569, -15279, -14290, 'Current Year Less than Prior Year'),
#  ('2800.0058', 'Fringe Transfer 0058', -15864, -1595, -14269, 'Current Year Less than Prior Year'),
#  ('7911', 'Fleet Operation - Fund 0011', -14169, -120, -14049, 'Current Year Less than Prior Year'),
#  ('2800.0037', 'Fringe Transfer 0037', -311502, -297494, -14008, 'Current Year Less than Prior Year'),
#  ('4122', 'Liquor License', -14070, -150, -13920, 'Current Year Less than Prior Year'),
#  ('5314', 'Mun Svc Chg Info Technology', -475480, -461632, -13848, 'Current Year Less than Prior Year'),
#  ('4022', 'Escrow - Preliminary Plan Review', -15000, -1400, -13600, 'Current Year Less than Prior Year'),
#  ('5343', 'Mun Svc Chg Sewage', -444944, -431984, -12960, 'Current Year Less than Prior Year'),
#  ('8369', 'Fleet Fuel - Fund 0069', -38545, -25886, -12659, 'Current Year Less than Prior Year'),
#  ('3820', 'Signal Supplies', 76399, 88653, -12254, 'Current Year Less than Prior Year'),
#  ('6300', 'Tires', 26954, 38833, -11879, 'Current Year Less than Prior Year'),
#  ('5357', 'Mun Svc Chg Insurance', -404792, -393008, -11784, 'Current Year Less than Prior Year'),
#  ('5466', 'Rental-Rink', -31526, -19983, -11543, 'Current Year Less than Prior Year'),
#  ('4040.4029', 'Deposits A20 Ambassador Training', -9750, 1500, -11250, 'Current Year Less than Prior Year'),
#  ('6740.0057', 'Fixed Gain/Loss NTQA', -47945, -36721, -11224, 'Current Year Less than Prior Year'),
#  ('2600', 'Rent', 7760, 18621, -10861, 'Current Year Less than Prior Year'),
#  ('6740.0088', 'Fixed Gain/Loss Summit Credit Fund II', -10922, -81, -10841, 'Current Year Less than Prior Year'),
#  ('2800.0003', 'Fringe Transfer 0003', -47724, -37032, -10692, 'Current Year Less than Prior Year'),
#  ('1106', 'Working In a Higher Class', 0, 10624, -10624, 'Current Year Less than Prior Year'),
#  ('2P00.2019', 'Taxes Rec - Personal Property 2019', 72622, 83198, -10576, 'Current Year Less than Prior Year'),
#  ('8133', 'Cold Patch', -20959, -10632, -10327, 'Current Year Less than Prior Year'),
#  ('8342', 'Fleet Fuel - Fund 0042', -33605, -23558, -10047, 'Current Year Less than Prior Year'),
#  ('7924', 'Refunds/Reimbursement', -10040, 0, -10040, 'Current Year Less than Prior Year'),
#  ('4325', 'Zoning Compliance Permits', -70603, -60622, -9981, 'Current Year Less than Prior Year'),
#  ('4205', 'Site Plans', -140475, -130977, -9498, 'Current Year Less than Prior Year'),
#  ('8042', 'Fleet Replacement - Fund 0042', -225696, -216328, -9368, 'Current Year Less than Prior Year'),
#  ('4040.4043', 'Deposits Vets', -25587, -16262, -9325, 'Current Year Less than Prior Year'),
#  ('5372', 'Mun Svc Chg Solid Waste', -315056, -305880, -9176, 'Current Year Less than Prior Year'),
#  ('5342', 'Mun Svc Chg Water', -310040, -301008, -9032, 'Current Year Less than Prior Year'),
#  ('2800.0059', 'Fringe Transfer 0059', -26760, -17855, -8905, 'Current Year Less than Prior Year'),
#  ('1273', 'Treasurers Tax Svgs TCF', 0, 8838, -8838, 'Current Year Less than Prior Year'),
#  ('5140.541', 'Vehicles Parks Pickups', 0, 8562, -8562, 'Current Year Less than Prior Year'),
#  ('4347', 'Fire Suppression Permit Fees', -34709, -26311, -8398, 'Current Year Less than Prior Year'),
#  ('8321', 'Fleet Fuel - Fund 0021', -36749, -28363, -8386, 'Current Year Less than Prior Year'),
#  ('2305.2283', 'Inventory St Maint', 303230, 311501, -8271, 'Current Year Less than Prior Year'),
#  ('6990', 'Drug Enforce Forfeitures', -18482, -10261, -8221, 'Current Year Less than Prior Year'),
#  ('4209', 'Brownfield Plan Review or Revision', -8200, 0, -8200, 'Current Year Less than Prior Year'),
#  ('5405', 'Classes-Resident', -7207, 753, -7960, 'Current Year Less than Prior Year'),
#  ('5449', 'Recreational Hockey', -7867, 0, -7867, 'Current Year Less than Prior Year'),
#  ('6795.0084', 'Real Estate Income AEW Capital Mgmt', -116750, -108911, -7839, 'Current Year Less than Prior Year'),
#  ('4034', 'Due To Market Vendors', -20965, -13357, -7608, 'Current Year Less than Prior Year'),
#  ('2400.0093', 'Equity In 0093', 3557035, 3564643, -7608, 'Current Year Less than Prior Year'),
#  ('4040.4060', 'Deposits Soil Erosion Inspection Escrow', -41715, -34123, -7592, 'Current Year Less than Prior Year'),
#  ('4058', 'Escrow Dep-Tree Plant', -38390, -30889, -7501, 'Current Year Less than Prior Year'),
#  ('2800.0036', 'Fringe Transfer 0036', -10675, -3177, -7498, 'Current Year Less than Prior Year'),
#  ('5437', 'Swimming-Master', -7483, 0, -7483, 'Current Year Less than Prior Year'),
#  ('5362', 'Mun Svc Chg Street Repair Mill', -256400, -248928, -7472, 'Current Year Less than Prior Year'),
#  ('2400.0025', 'Equity In 0025', -100340, -93022, -7318, 'Current Year Less than Prior Year'),
#  ('5478', 'Rental - Raft', -15852, -8614, -7238, 'Current Year Less than Prior Year'),
#  ('2281', 'Judicial Standardization', -68625, -61436, -7189, 'Current Year Less than Prior Year'),
#  ('2710.0024', 'Operating Transfers 0024', -990156, -983056, -7100, 'Current Year Less than Prior Year'),
#  ('4017', 'Overpayments', -3575, 3358, -6933, 'Current Year Less than Prior Year'),
#  ('3950', 'Salt', 54312, 61168, -6856, 'Current Year Less than Prior Year'),
#  ('5101', 'U Of M Police General', -6677, 0, -6677, 'Current Year Less than Prior Year'),
#  ('4502.4526', 'Premium/Discount - Other Bonds 2015 Open', 104026, 110627, -6601, 'Current Year Less than Prior Year'),
#  ('2640', 'Software', 0, 6600, -6600, 'Current Year Less than Prior Year'),
#  ('8022', 'Fleet Replacement - Fund 0022', -176608, -170016, -6592, 'Current Year Less than Prior Year'),
#  ('5321', 'Mun Svc Chg Major Streets', -215600, -209320, -6280, 'Current Year Less than Prior Year'),
#  ('2215.2333', 'Accrued Income AEW Capital Mgmt', 56923, 63113, -6190, 'Current Year Less than Prior Year'),
#  ('5464', 'Rental-Meeting Room', -6130, 0, -6130, 'Current Year Less than Prior Year'),
#  ('6903', 'Sponsorships', -6048, 0, -6048, 'Current Year Less than Prior Year'),
#  ('5468', 'Rental-Resident', -6026, -39, -5987, 'Current Year Less than Prior Year'),
#  ('5116', 'Donations/Police', -5926, 0, -5926, 'Current Year Less than Prior Year'),
#  ('2400.0054', 'Equity In 0054', -125976, -120097, -5879, 'Current Year Less than Prior Year'),
#  ('8343', 'Fleet Fuel - Fund 0043', -20019, -14404, -5615, 'Current Year Less than Prior Year'),
#  ('1274', 'Treasurers Tax Svgs Ann Arbor State Bank', 2504, 7939, -5435, 'Current Year Less than Prior Year'),
#  ('1525', 'Traffic Impact Study Review Fee', -6144, -725, -5419, 'Current Year Less than Prior Year'),
#  ('7313', 'Residential Parking Permits', -67854, -62543, -5311, 'Current Year Less than Prior Year'),
#  ('8216', 'Towing Fees', -9390, -4080, -5310, 'Current Year Less than Prior Year'),
#  ('2710.0075', 'Operating Transfers 0075', -123, 5173, -5296, 'Current Year Less than Prior Year'),
#  ('2100.0078', 'Professional Services Rhumbline -HEDI', 7319, 12582, -5263, 'Current Year Less than Prior Year'),
#  ('5369', 'Mun Svc Chg Stormwater', -177960, -172776, -5184, 'Current Year Less than Prior Year'),
#  ('5463', 'Rental-Paddle Boat', -10647, -5477, -5170, 'Current Year Less than Prior Year'),
#  ('1721', 'Annual Sick Leave Payout', 1974, 7086, -5112, 'Current Year Less than Prior Year'),
#  ('5536', 'Sales-Compost', -6784, -1711, -5073, 'Current Year Less than Prior Year'),
#  ('4348', 'Fire Alarm Permit Fees', -24925, -19854, -5071, 'Current Year Less than Prior Year'),
#  ('4014', 'Due To Other Governmental Units', -5060, 0, -5060, 'Current Year Less than Prior Year'),
#  ('1524', 'Site Plan Review', -10000, -5000, -5000, 'Current Year Less than Prior Year'),
#  ('2800.0062', 'Fringe Transfer 0062', -4864, 0, -4864, 'Current Year Less than Prior Year'),
#  ('4212', 'Site Plan/ Admin Amend', -17600, -12800, -4800, 'Current Year Less than Prior Year'),
#  ('6796.0047', 'Equity Income Loomis Sayles', -32549, -27780, -4769, 'Current Year Less than Prior Year'),
#  ('8012', 'Fleet Replacement - Fund 0012', -10488, -5760, -4728, 'Current Year Less than Prior Year'),
#  ('8322', 'Fleet Fuel - Fund 0022', -17409, -12742, -4667, 'Current Year Less than Prior Year'),
#  ('2710.0049', 'Operating Transfers 0049', -44640, -40040, -4600, 'Current Year Less than Prior Year'),
#  ('2800.0100', 'Fringe Transfer 0100', -25607, -21024, -4583, 'Current Year Less than Prior Year'),
#  ('4520', 'Contingency', 0, 4487, -4487, 'Current Year Less than Prior Year'),
#  ('8058', 'Fleet Replacement Fund 0058', -4480, 0, -4480, 'Current Year Less than Prior Year'),
#  ('8371', 'Fleet Fuel - Fund 0071', -18310, -14296, -4014, 'Current Year Less than Prior Year'),
#  ('5326', 'Mun Svc Chg Construction', -137360, -133360, -4000, 'Current Year Less than Prior Year'),
#  ('5461', 'Rental-Canoe', -7733, -3790, -3943, 'Current Year Less than Prior Year'),
#  ('6806', 'Refund Prior Year Expense', -3824, 0, -3824, 'Current Year Less than Prior Year'),
#  ('8048', 'Fleet Replacement - Fund 0048', -5968, -2144, -3824, 'Current Year Less than Prior Year'),
#  ('7206', 'Box Hangars', -91469, -87720, -3749, 'Current Year Less than Prior Year'),
#  ('1100', 'Permanent Time Worked', 7984, 11682, -3698, 'Current Year Less than Prior Year'),
#  ('5312', 'Mun Svc Chg Fleet', -122896, -119320, -3576, 'Current Year Less than Prior Year'),
#  ('2710.0095', 'Operating Transfers 0095', 0, 3559, -3559, 'Current Year Less than Prior Year'),
#  ('2215.2377', 'Accrued Income Short Term Core Bond', 6463, 10016, -3553, 'Current Year Less than Prior Year'),
#  ('2260', 'State of Michigan - Grant', -3500, 0, -3500, 'Current Year Less than Prior Year'),
#  ('2423', 'Fleet Depreciation', 0, 3392, -3392, 'Current Year Less than Prior Year'),
#  ('1012', 'Cash Offset For GASB #34', 100242, 103573, -3331, 'Current Year Less than Prior Year'),
#  ('4420', 'Transfer To Other Funds', 58793, 62115, -3322, 'Current Year Less than Prior Year'),
#  ('2100.0047', 'Professional Services Loomis Sayles', 8692, 11996, -3304, 'Current Year Less than Prior Year'),
#  ('2400.0037', 'Equity In 0037', -6760, -3480, -3280, 'Current Year Less than Prior Year'),
#  ('5548', 'DDA Waste Cart Collection', -100594, -97355, -3239, 'Current Year Less than Prior Year'),
#  ('5111', 'Crash Reports', -8652, -5432, -3220, 'Current Year Less than Prior Year'),
#  ('5349', 'Mun Svc Chg Project Management', -109520, -106328, -3192, 'Current Year Less than Prior Year'),
#  ('8071', 'Fleet Replacement - Fund 0071', -52792, -49600, -3192, 'Current Year Less than Prior Year'),
#  ('7703', 'Sale of Lots', -3250, -75, -3175, 'Current Year Less than Prior Year'),
#  ('2435', 'Tipping Fees', 0, 3108, -3108, 'Current Year Less than Prior Year'),
#  ('2100.0002', 'Professional Services Attorney', -740, 2266, -3006, 'Current Year Less than Prior Year'),
#  ('7124', 'Hydrant Maint Charges', -27184, -24182, -3002, 'Current Year Less than Prior Year'),
#  ('1526', 'Lane Closure Process Review Fee', -23715, -20724, -2991, 'Current Year Less than Prior Year'),
#  ('4262', 'Liability Insur Premium-Court', 3929, 6877, -2948, 'Current Year Less than Prior Year'),
#  ('2258', 'State/Jury Fee Reimb - Grant', -2938, 0, -2938, 'Current Year Less than Prior Year'),
#  ('8349', 'Fleet Fuel - Fund 0049', -6136, -3272, -2864, 'Current Year Less than Prior Year'),
#  ('7201', 'T-Hangers', -346707, -343886, -2821, 'Current Year Less than Prior Year'),
#  ('1616', 'Weed Cutting Charges', -4362, -1665, -2697, 'Current Year Less than Prior Year'),
#  ('2P00.2011', 'Taxes Rec - Personal Property 2011', 5613, 8307, -2694, 'Current Year Less than Prior Year'),
#  ('2215.2312', 'Accrued Income AA NTQA Lehman Bond', 56467, 59086, -2619, 'Current Year Less than Prior Year'),
#  ('5465', 'Rental-Pool', -2574, 0, -2574, 'Current Year Less than Prior Year'),
#  ('7405', 'Daily Rentals Paying Daily', -6290, -3720, -2570, 'Current Year Less than Prior Year'),
#  ('4T00.2015', 'Undistributed Taxes 2015', -3455, -896, -2559, 'Current Year Less than Prior Year'),
#  ('4373', 'Loss Fund', 13875, 16392, -2517, 'Current Year Less than Prior Year'),
#  ('2800.0024', 'Fringe Transfer 0024', -5777, -3274, -2503, 'Current Year Less than Prior Year'),
#  ('8137', 'Gravel', -7155, -4667, -2488, 'Current Year Less than Prior Year'),
#  ('4260', 'Insurance Premiums', 5836, 8320, -2484, 'Current Year Less than Prior Year'),
#  ('2228', 'Interest Receivable', 6947, 9414, -2467, 'Current Year Less than Prior Year'),
#  ('5550', 'Residential Cart Upgrade/Additional', -149194, -146748, -2446, 'Current Year Less than Prior Year'),
#  ('1028', 'Cash EnerGov', -2419, 0, -2419, 'Current Year Less than Prior Year'),
#  ('2305.2305', 'Inventory Leslie GC', 18743, 21086, -2343, 'Current Year Less than Prior Year'),
#  ('7210', 'Transient Parking', -2513, -205, -2308, 'Current Year Less than Prior Year'),
#  ('2336', 'U Of M Grant/Reimbursement', -2136, 0, -2136, 'Current Year Less than Prior Year'),
#  ('1113', 'Debt Service Levy', -2128, 0, -2128, 'Current Year Less than Prior Year'),
#  ('1322', 'Payden TALF 2020 Fund LLC', 0, 2105, -2105, 'Current Year Less than Prior Year'),
#  ('3311', 'All for Dep Build/Struct/Imprv', -87283, -85217, -2066, 'Current Year Less than Prior Year'),
#  ('6796.0078', 'Equity Income Rhumbline -HEDI', -334597, -332540, -2057, 'Current Year Less than Prior Year'),
#  ('4899', 'Miscellaneous Deduction Withholding Payable', 0, 2048, -2048, 'Current Year Less than Prior Year'),
#  ('2330', 'Radio Maintenance', 440, 2448, -2008, 'Current Year Less than Prior Year'),
#  ('5438', 'Swimming-instructional', -1984, 0, -1984, 'Current Year Less than Prior Year'),
#  ('2237', 'Assess Rec Prop Curb', 3957, 5892, -1935, 'Current Year Less than Prior Year'),
#  ('2P00.2018', 'Taxes Rec - Personal Property 2018', 47384, 49280, -1896, 'Current Year Less than Prior Year'),
#  ('5316', 'Mun Svc Chg Cablecasting', -64704, -62816, -1888, 'Current Year Less than Prior Year'),
#  ('4119', 'Bank Service Fees', 14807, 16552, -1745, 'Current Year Less than Prior Year'),
#  ('4123.0001', 'CATV Cap Acquisition Fee Comcast', -104288, -102549, -1739, 'Current Year Less than Prior Year'),
#  ('7202', 'Tie Downs', -1964, -248, -1716, 'Current Year Less than Prior Year'),
#  ('2P00.2012', 'Taxes Rec - Personal Property 2012', 6555, 8254, -1699, 'Current Year Less than Prior Year'),
#  ('5474', 'Dog Park Fees', -7025, -5337, -1688, 'Current Year Less than Prior Year'),
#  ('6155', 'Diesel Exhaust Fluid', 4742, 6330, -1588, 'Current Year Less than Prior Year'),
#  ('2400.0023', 'Equity In 0023', -9914, -8335, -1579, 'Current Year Less than Prior Year'),
#  ('6975', 'Contrib-Corporate Challenge', -1567, 0, -1567, 'Current Year Less than Prior Year'),
#  ('5457', 'Rec & Ed Field Fees', -12874, -11342, -1532, 'Current Year Less than Prior Year'),
#  ('2400.0064', 'Equity In 0064', -19674, -18169, -1505, 'Current Year Less than Prior Year'),
#  ('4222', 'Design Review Board', -3000, -1500, -1500, 'Current Year Less than Prior Year'),
#  ('4315', 'Sign Permits', -6000, -4500, -1500, 'Current Year Less than Prior Year'),
#  ('5322', 'Mun Svc Chg Local Streets', -50200, -48736, -1464, 'Current Year Less than Prior Year'),
#  ('2280', 'State/Mich Justice Training', -8122, -6660, -1462, 'Current Year Less than Prior Year'),
#  ('3110', 'Bond Forfeitures', -1445, 0, -1445, 'Current Year Less than Prior Year'),
#  ('2400.0081', 'Equity In 0081', 837334, 838741, -1407, 'Current Year Less than Prior Year'),
#  ('1201', 'Temporary Pay Overtime', 0, 1333, -1333, 'Current Year Less than Prior Year'),
#  ('7912', 'Fleet Operation - Fund 0012', -12675, -11342, -1333, 'Current Year Less than Prior Year'),
#  ('7948', 'Fleet Operation - Fund 0048', -11045, -9804, -1241, 'Current Year Less than Prior Year'),
#  ('2710.0048', 'Operating Transfers 0048', -7536, -6304, -1232, 'Current Year Less than Prior Year'),
#  ('6792.0048', 'Cash Equivalent Income Securities Lending', -2641, -1417, -1224, 'Current Year Less than Prior Year'),
#  ('7220', 'Office Leases', -29760, -28571, -1189, 'Current Year Less than Prior Year'),
#  ('2710.0036', 'Operating Transfers 0036', -1120, 0, -1120, 'Current Year Less than Prior Year'),
#  ('8136', 'Sand', -2171, -1056, -1115, 'Current Year Less than Prior Year'),
#  ('2100.0089', 'Professional Services NTAM EAFE', 9672, 10761, -1089, 'Current Year Less than Prior Year'),
#  ('5448', "Vet's Meeting Room", -1083, 0, -1083, 'Current Year Less than Prior Year'),
#  ('5473', 'Canoe-Instruction', -1429, -381, -1048, 'Current Year Less than Prior Year'),
#  ('2305.2304', 'Inventory Huron Hills GC', 6384, 7416, -1032, 'Current Year Less than Prior Year'),
#  ('2665', 'Technical Support', 1995, 3000, -1005, 'Current Year Less than Prior Year'),
#  ('2207', 'Due From AA Housing Comm', 0, 980, -980, 'Current Year Less than Prior Year'),
#  ('1711', 'EMT Education Bonus', 2650, 3600, -950, 'Current Year Less than Prior Year'),
#  ('8142', 'Signs', -41785, -40841, -944, 'Current Year Less than Prior Year'),
#  ('1267', 'NTGI S&P 400', 3271044, 3271977, -933, 'Current Year Less than Prior Year'),
#  ('1701', 'In Lieu - House Trailer', -1092, -162, -930, 'Current Year Less than Prior Year'),
#  ('5534', 'Food Waste', -1167, -237, -930, 'Current Year Less than Prior Year'),
#  ('7212', 'Bijan Air, Inc', -43615, -42697, -918, 'Current Year Less than Prior Year'),
#  ('2P00.2013', 'Taxes Rec - Personal Property 2013', 8625, 9536, -911, 'Current Year Less than Prior Year'),
#  ('2215.2322', 'Accrued Income Rhumbline', 5696, 6569, -873, 'Current Year Less than Prior Year'),
#  ('2800.0048', 'Fringe Transfer 0048', -7968, -7104, -864, 'Current Year Less than Prior Year'),
#  ('7407', 'Wednesday Night Market', -862, 0, -862, 'Current Year Less than Prior Year'),
#  ('4214', 'Adm Lot Division', -850, 0, -850, 'Current Year Less than Prior Year'),
#  ('2800.0011', 'Fringe Transfer 0011', -6784, -6000, -784, 'Current Year Less than Prior Year'),
#  ('4374', 'Liability Insurance Premium', 0, 756, -756, 'Current Year Less than Prior Year'),
#  ('4362', 'Appeal Housing Board', -750, 0, -750, 'Current Year Less than Prior Year'),
#  ('5443', 'Skate Shop', -1028, -281, -747, 'Current Year Less than Prior Year'),
#  ('4130', 'Paying Agent Fee', 2100, 2800, -700, 'Current Year Less than Prior Year'),
#  ('2100.0009', 'Professional Services Carlyle Realty VIII', 750, 1448, -698, 'Current Year Less than Prior Year'),
#  ('4341', 'Examination Fee', -684, 0, -684, 'Current Year Less than Prior Year'),
#  ('6600.66', 'Repair Parts Regular', 383, 1065, -682, 'Current Year Less than Prior Year'),
#  ('4115', 'FOIA Charges', -1842, -1170, -672, 'Current Year Less than Prior Year'),
#  ('6796.0064', 'Equity Income Rhumbline', -62002, -61335, -667, 'Current Year Less than Prior Year'),
#  ('5348', 'Mun Svc Chg Airport', -22568, -21904, -664, 'Current Year Less than Prior Year'),
#  ('4500', 'Miscellaneous', 0, 660, -660, 'Current Year Less than Prior Year'),
#  ('5311', 'Mun Svc Chg Central Stores', -22272, -21616, -656, 'Current Year Less than Prior Year'),
#  ('4203', 'Historic Preservation', -10205, -9575, -630, 'Current Year Less than Prior Year'),
#  ('5533', 'Dropoff-Yardwaste', -3926, -3297, -629, 'Current Year Less than Prior Year'),
#  ('5408', 'Season Pass-Resident', -608, 0, -608, 'Current Year Less than Prior Year'),
#  ('6150', 'Diesel Fuel', 3145, 3746, -601, 'Current Year Less than Prior Year'),
#  ('1840', 'Food Allowance', 66, 666, -600, 'Current Year Less than Prior Year'),
#  ('4231', 'ACA Health Care', 0, 588, -588, 'Current Year Less than Prior Year'),
#  ('2100.0007', 'Professional Services TSE Capital', 0, 579, -579, 'Current Year Less than Prior Year'),
#  ('4319', 'Grading Permits', -560, 0, -560, 'Current Year Less than Prior Year'),
#  ('2242', 'Assess Rec Watermains', 0, 544, -544, 'Current Year Less than Prior Year'),
#  ('2220', 'Electricity', 163, 701, -538, 'Current Year Less than Prior Year'),
#  ('4225', 'Childcare Reimbursement', 5, 515, -510, 'Current Year Less than Prior Year'),
#  ('2215.2261', 'Accrued Income Contributions', 0, 505, -505, 'Current Year Less than Prior Year'),
#  ('5358', 'Mun Svc Chg Wheeler', -17160, -16656, -504, 'Current Year Less than Prior Year'),
#  ('5426', 'Concession', -495, 0, -495, 'Current Year Less than Prior Year'),
#  ('6793.0067', 'Equities Gain/Loss S & P 400', -1141, -659, -482, 'Current Year Less than Prior Year'),
#  ('2690', 'Non-Employee Travel', 0, 460, -460, 'Current Year Less than Prior Year'),
#  ('2247', 'Improvement Charges Township', 0, 457, -457, 'Current Year Less than Prior Year'),
#  ('3400', 'Materials & Supplies', 522, 976, -454, 'Current Year Less than Prior Year'),
#  ('2p00.2017', 'Taxes Rec - Personal Property 2017', 28565, 28986, -421, 'Current Year Less than Prior Year'),
#  ('8348', 'Fleet Fuel - Fund 0048', -623, -208, -415, 'Current Year Less than Prior Year'),
#  ('2P00.2010', 'Taxes Rec - Personal Property 2010', 3305, 3719, -414, 'Current Year Less than Prior Year'),
#  ('5336', 'Mun Svc Chg Metro Expansion', -13800, -13400, -400, 'Current Year Less than Prior Year'),
#  ('7116', 'Site Compliance', -2370, -1981, -389, 'Current Year Less than Prior Year'),
#  ('6199', 'Other Rentals', -4500, -4120, -380, 'Current Year Less than Prior Year'),
#  ('2305.2306', 'Inventory Vets Pool Rink', 597, 957, -360, 'Current Year Less than Prior Year'),
#  ('2240', 'Telecommunications', 21, 376, -355, 'Current Year Less than Prior Year'),
#  ('4T00.2014', 'Undistributed Taxes 2014', -1545, -1195, -350, 'Current Year Less than Prior Year'),
#  ('6110', 'Gas/Compressed Natural Gas', 2134, 2477, -343, 'Current Year Less than Prior Year'),
#  ('2150', 'Legal Expenses', 0, 340, -340, 'Current Year Less than Prior Year'),
#  ('2840', 'Towing Service', 0, 329, -329, 'Current Year Less than Prior Year'),
#  ('2610', 'Equipment Leasing', 0, 324, -324, 'Current Year Less than Prior Year'),
#  ('2P00.2015', 'Taxes Rec - Personal Property 2015', 29818, 30134, -316, 'Current Year Less than Prior Year'),
#  ('1518', 'Inspection', -1870, -1555, -315, 'Current Year Less than Prior Year'),
#  ('8311', 'Fleet Fuel - Fund 0011', -530, -223, -307, 'Current Year Less than Prior Year'),
#  ('2P00.2008', 'Taxes Rec - Personal Property 2008', 601, 904, -303, 'Current Year Less than Prior Year'),
#  ('2p00.2016', 'Taxes Rec - Personal Property 2016', 43032, 43332, -300, 'Current Year Less than Prior Year'),
#  ('4423', 'Transfer To IT Fund', 5816, 6104, -288, 'Current Year Less than Prior Year'),
#  ('1102', 'Other Paid Time Off', 32, 317, -285, 'Current Year Less than Prior Year'),
#  ('5361', 'Mun Svc Chg Alternative Transportation', -8976, -8712, -264, 'Current Year Less than Prior Year'),
#  ('3420', 'Flowers', 0, 260, -260, 'Current Year Less than Prior Year'),
#  ('4250', 'Social Security-Employer', 784, 1025, -241, 'Current Year Less than Prior Year'),
#  ('2700', 'Conference Training & Travel', 0, 215, -215, 'Current Year Less than Prior Year'),
#  ('2232', 'Sewage Disposal Costs', 28, 238, -210, 'Current Year Less than Prior Year'),
#  ('1194', 'Disc US Treasury Notes', -7661, -7462, -199, 'Current Year Less than Prior Year'),
#  ('7957', 'Fleet Operation - Fund 0057', -991, -795, -196, 'Current Year Less than Prior Year'),
#  ('1022', 'Cash Utilities ACH', -196, 0, -196, 'Current Year Less than Prior Year'),
#  ('4100', 'Depreciation', 1314, 1502, -188, 'Current Year Less than Prior Year'),
#  ('8312', 'Fleet Fuel - Fund 0012', -1305, -1117, -188, 'Current Year Less than Prior Year'),
#  ('2100.0064', 'Professional Services Rhumbline', 1771, 1957, -186, 'Current Year Less than Prior Year'),
#  ('2100.0099', 'Professional Services Northern Trust', 248, 430, -182, 'Current Year Less than Prior Year'),
#  ('6700.6730', 'Garage Repairs Engine', 0, 177, -177, 'Current Year Less than Prior Year'),
#  ('4023', 'Tolerance For Taxes', -185, -21, -164, 'Current Year Less than Prior Year'),
#  ('1161', 'Holiday', 650, 807, -157, 'Current Year Less than Prior Year'),
#  ('2710.0012', 'Operating Transfers 0012', -627354, -627201, -153, 'Current Year Less than Prior Year'),
#  ('2800.0022', 'Fringe Transfer 0022', -152, 0, -152, 'Current Year Less than Prior Year'),
#  ('5483', 'Merchandise', -147, 0, -147, 'Current Year Less than Prior Year'),
#  ('4108', 'Pedal Car Permits', -145, 0, -145, 'Current Year Less than Prior Year'),
#  ('5302', 'Mun Svc Chg Energy', -4864, -4720, -144, 'Current Year Less than Prior Year'),
#  ('6909', 'Tree Planting', -135, 0, -135, 'Current Year Less than Prior Year'),
#  ('2230', 'Water', 44, 178, -134, 'Current Year Less than Prior Year'),
#  ('2422', 'Fleet Fuel', 0, 131, -131, 'Current Year Less than Prior Year'),
# ...
#  ('3932', 'Hot Mix', 46933, 44133, 2800, 'Current Year Greater than Prior Year'),
#  ('2100.0006', 'Professional Services 36 South Funds', 3433, 579, 2854, 'Current Year Greater than Prior Year'),
#  ('4502.4578', 'Premium/Discount - Other Bonds 2012 MTF', -6687, -9875, 3188, 'Current Year Greater than Prior Year'),
#  ('7203', 'Fuel Flowage Fees', -15279, -18510, 3231, 'Current Year Greater than Prior Year'),
#  ('2215.2394', 'Accrued Income Silicon Valley Bank', 3280, 0, 3280, 'Current Year Greater than Prior Year'),
#  ('5030', 'Contrib Capital - Shared Costs', 3284, 0, 3284, 'Current Year Greater than Prior Year'),
#  ('2710.0021', 'Operating Transfers 0021', -408967, -412259, 3292, 'Current Year Greater than Prior Year'),
#  ('2710.0002', 'Operating Transfers 0002', -58793, -62115, 3322, 'Current Year Greater than Prior Year'),
#  ('4322', 'Fence Permits', -8700, -12024, 3324, 'Current Year Greater than Prior Year'),
#  ('6997', 'Contrib-AAAF Donations', -10844, -14235, 3391, 'Current Year Greater than Prior Year'),
#  ('1521', 'Right Of Way Permit Review Fee', 0, -3450, 3450, 'Current Year Greater than Prior Year'),
#  ('5552', '3rd Party Disposal Credit', -15306, -18798, 3492, 'Current Year Greater than Prior Year'),
#  ('4213', 'Land Division', -3000, -6550, 3550, 'Current Year Greater than Prior Year'),
#  ('2305.2282', 'Inventory Radio Shop', 49655, 46072, 3583, 'Current Year Greater than Prior Year'),
#  ('6800', 'Towing Charges', 9677, 6045, 3632, 'Current Year Greater than Prior Year'),
#  ('2100.0005', 'Professional Services Consulting Physicians', 5750, 2050, 3700, 'Current Year Greater than Prior Year'),
#  ('4170', 'Dog License', -6816, -10536, 3720, 'Current Year Greater than Prior Year'),
#  ('7112', 'Forfeited Discounts', -159124, -163006, 3882, 'Current Year Greater than Prior Year'),
#  ('7592', 'Golf Lessons', -4744, -8790, 4046, 'Current Year Greater than Prior Year'),
#  ('2680', 'Parking Space Rent', 42666, 38487, 4179, 'Current Year Greater than Prior Year'),
#  ('2951', 'Employee Recognition', 4423, 0, 4423, 'Current Year Greater than Prior Year'),
#  ('2800.0071', 'Fringe Transfer 0071', -132760, -137272, 4512, 'Current Year Greater than Prior Year'),
#  ('7590', 'Golf Tournaments', -18646, -23230, 4584, 'Current Year Greater than Prior Year'),
#  ('4508', 'Bonds Payable - Discount/Premium', -4869, -9544, 4675, 'Current Year Greater than Prior Year'),
#  ('4346', 'Special Inspections', -9516, -14230, 4714, 'Current Year Greater than Prior Year'),
#  ('2331', 'Radio System Service Charge', 75552, 70560, 4992, 'Current Year Greater than Prior Year'),
#  ('4605.4693', 'Contract Payable Mallets E Stadium Bridge 5505-', -107209, -112209, 5000, 'Current Year Greater than Prior Year'),
#  ('4605.4694', 'Contract Payable Allen Creek Willard St 5511-01', -76319, -81319, 5000, 'Current Year Greater than Prior Year'),
#  ('4605.4697', 'Contract Payable Allen Crk Cistern Trees 5470-01', -95746, -100746, 5000, 'Current Year Greater than Prior Year'),
#  ('4605.4699', 'Contract Payable 2013 SRFTree Planting 5504-01', -124967, -129967, 5000, 'Current Year Greater than Prior Year'),
#  ('2274', 'Liquor Retail License', -112921, -118072, 5151, 'Current Year Greater than Prior Year'),
#  ('2400.0038', 'Equity In 0038', -13547, -18726, 5179, 'Current Year Greater than Prior Year'),
#  ('4502.4507', 'Premium/Discount - Other Bonds 2013 Tax', -68593, -73814, 5221, 'Current Year Greater than Prior Year'),
#  ('4680', 'Optical Insurance Premiums', 60124, 54702, 5422, 'Current Year Greater than Prior Year'),
#  ('8217', 'Claim Recoveries', 0, -5445, 5445, 'Current Year Greater than Prior Year'),
#  ('6600.6650', 'Repair Parts Outside Repairs', 6825, 1289, 5536, 'Current Year Greater than Prior Year'),
#  ('1002', 'Cash General', -45461, -51123, 5662, 'Current Year Greater than Prior Year'),
#  ('2710.0042', 'Operating Transfers 0042', -171672, -177336, 5664, 'Current Year Greater than Prior Year'),
#  ('4502.4580', 'Premium/Discount - Other Bonds 2016 Parking', -38086, -43810, 5724, 'Current Year Greater than Prior Year'),
#  ('8218', 'Accident Recovery', -20778, -26715, 5937, 'Current Year Greater than Prior Year'),
#  ('5423', 'Day Camps', 6168, 230, 5938, 'Current Year Greater than Prior Year'),
#  ('4T00.2018', 'Undistributed Taxes 2018', 0, -5976, 5976, 'Current Year Greater than Prior Year'),
#  ('4T00.2017', 'Undistributed Taxes 2017', 28, -6042, 6070, 'Current Year Greater than Prior Year'),
#  ('4504.4580', 'Premium/Discount - Revenue Bonds Premium', -19445, -25879, 6434, 'Current Year Greater than Prior Year'),
#  ('4206', 'Zoning Fees', -6025, -12475, 6450, 'Current Year Greater than Prior Year'),
#  ('2800.0057', 'Fringe Transfer 0057', -26569, -33080, 6511, 'Current Year Greater than Prior Year'),
#  ('2215.2255', 'Accrued Income Russel 1000', 54248, 47393, 6855, 'Current Year Greater than Prior Year'),
#  ('6700.6710', 'Garage Repairs Hydraulics', 11080, 4220, 6860, 'Current Year Greater than Prior Year'),
#  ('6988', 'Developer Contributions', 0, -6875, 6875, 'Current Year Greater than Prior Year'),
#  ('5112', 'Pol Rprts Reproduction', -4620, -11599, 6979, 'Current Year Greater than Prior Year'),
#  ('5541', 'Methane Recovery Reimb', -1000, -8000, 7000, 'Current Year Greater than Prior Year'),
#  ('3800', 'Tree Purchases', 8400, 1265, 7135, 'Current Year Greater than Prior Year'),
#  ('4312', 'Plumbing Permits', -394560, -401885, 7325, 'Current Year Greater than Prior Year'),
#  ('7971', 'Fleet Operation - Fund 0071', -57270, -64745, 7475, 'Current Year Greater than Prior Year'),
#  ('2215.2278', 'Accrued Income Rhumbline -HEDI', 31499, 23748, 7751, 'Current Year Greater than Prior Year'),
#  ('7406', 'Parking Fees', -1310, -9255, 7945, 'Current Year Greater than Prior Year'),
#  ('1527', 'Preliminary Plan Review', 0, -8037, 8037, 'Current Year Greater than Prior Year'),
#  ('2800.0042', 'Fringe Transfer 0042', -590242, -598424, 8182, 'Current Year Greater than Prior Year'),
#  ('3970', 'Gravel', 22659, 14433, 8226, 'Current Year Greater than Prior Year'),
#  ('1193', 'Premium USTN', 49876, 41587, 8289, 'Current Year Greater than Prior Year'),
#  ('2800.0009', 'Fringe Transfer 0009', 0, -8320, 8320, 'Current Year Greater than Prior Year'),
#  ('6700.6720', 'Garage Repairs Transmissions', 11749, 2993, 8756, 'Current Year Greater than Prior Year'),
#  ('4605.4696', 'Contract Payable Traver Crk Cistern Trees 5472-01', -109651, -118472, 8821, 'Current Year Greater than Prior Year'),
#  ('7119', 'Developer Offset Mitigation Fee', 0, -9250, 9250, 'Current Year Greater than Prior Year'),
#  ('2100.0001', 'Professional Services Actuary', 29600, 19750, 9850, 'Current Year Greater than Prior Year'),
#  ('5190', 'Construction', 10000, 0, 10000, 'Current Year Greater than Prior Year'),
#  ('4605.4687', 'Contract Payable Allen Creek-Stadium Blvd 5337-', -80000, -90000, 10000, 'Current Year Greater than Prior Year'),
#  ('4605.4703', 'Contract Payable Allen Creek Fourth Ave 5510-01', -120163, -130163, 10000, 'Current Year Greater than Prior Year'),
#  ('4605.4704', 'Contract Payable Allen Creek 5512-01', -131099, -141099, 10000, 'Current Year Greater than Prior Year'),
#  ('4605.4705', 'Contract Payable 5504.03', -148295, -158295, 10000, 'Current Year Greater than Prior Year'),
#  ('4605.471', 'ontract Payable HRGI Tree Planting 2015', -153503, -163503, 10000, 'Current Year Greater than Prior Year'),
#  ('4605.4713', 'Contract Payable HRGI Tree Planting 2016', -155801, -165801, 10000, 'Current Year Greater than Prior Year'),
#  ('4605.4714', 'Contract Payable HRGI Tree Planting 2017', -252220, -262220, 10000, 'Current Year Greater than Prior Year'),
#  ('2830', 'Jury & Witness Expenses', 10083, 34, 10049, 'Current Year Greater than Prior Year'),
#  ('4321', 'Sidewalk Occupancy/Portable Sign Permit', -10499, -20809, 10310, 'Current Year Greater than Prior Year'),
#  ('7141', 'Tap Fees', -41146, -52396, 11250, 'Current Year Greater than Prior Year'),
#  ('7403', 'Daily Rentals Paying Yearly', -2350, -13669, 11319, 'Current Year Greater than Prior Year'),
#  ('3118', 'Jury Demand Fees', -139400, -150760, 11360, 'Current Year Greater than Prior Year'),
#  ('6791.0077', 'Fixed Income Short Term Core Bond', -38159, -49623, 11464, 'Current Year Greater than Prior Year'),
#  ('7106', 'Merch & Jobbing-Field', -4070, -15582, 11512, 'Current Year Greater than Prior Year'),
#  ('8147', 'Hot Mix', -32299, -44133, 11834, 'Current Year Greater than Prior Year'),
#  ('6795.0087', 'Real Estate Income Vanguard RE', -134896, -146857, 11961, 'Current Year Greater than Prior Year'),
#  ('6796.0096', 'Equity Income First Eagle', -35398, -47398, 12000, 'Current Year Greater than Prior Year'),
#  ('4215', 'Deferred Comp Contributions', 27500, 15015, 12485, 'Current Year Greater than Prior Year'),
#  ('5499', 'Miscellaneous-Parks', 0, -12510, 12510, 'Current Year Greater than Prior Year'),
#  ('2140', 'US Dept Of Justice - Grant', 0, -12890, 12890, 'Current Year Greater than Prior Year'),
#  ('2100', 'Professional Services', 13000, 0, 13000, 'Current Year Greater than Prior Year'),
#  ('8372', 'Fleet Fuel - Fund 0072', -116850, -130684, 13834, 'Current Year Greater than Prior Year'),
#  ('4421', 'Transfer To Other Agencies', 67500, 53332, 14168, 'Current Year Greater than Prior Year'),
#  ('6143', 'Street Tree Recovery', -2826, -17056, 14230, 'Current Year Greater than Prior Year'),
#  ('6160', 'Oil', 38192, 23903, 14289, 'Current Year Greater than Prior Year'),
#  ('4605.4692', 'Contract Payable County Farm Streambank 5469-', -212199, -227199, 15000, 'Current Year Greater than Prior Year'),
#  ('4605.4706', 'Contract Payable Springwater 5508-01', -227602, -242602, 15000, 'Current Year Greater than Prior Year'),
#  ('4605.4708', 'Contract Payable HRGI 5504.02', -213379, -228379, 15000, 'Current Year Greater than Prior Year'),
#  ('4605.4715', 'Contract Payable 5504.07', -242921, -257921, 15000, 'Current Year Greater than Prior Year'),
#  ('6794.0020', 'Real Estate G/L DRA G&I X-Real Estate', 0, -15521, 15521, 'Current Year Greater than Prior Year'),
#  ('1294', 'Silicon Valley Bank', 1610641, 1594181, 16460, 'Current Year Greater than Prior Year'),
#  ('1085', 'Certificate of Deposit', 793814, 777196, 16618, 'Current Year Greater than Prior Year'),
#  ('1998', 'Personnel Expenses Reimbursed to the General', 64966, 47706, 17260, 'Current Year Greater than Prior Year'),
#  ('4504.4597', 'Premium/Discount - Revenue Bonds 2016 Sewer', -201855, -219455, 17600, 'Current Year Greater than Prior Year'),
#  ('7535', 'Rental - Carts', -124602, -143027, 18425, 'Current Year Greater than Prior Year'),
#  ('2429.0104', 'LDFA Contracted Services Bus. Software Access for', 18679, 0, 18679, 'Current Year Greater than Prior Year'),
#  ('6310', 'Recapped Tires', 50313, 31626, 18687, 'Current Year Greater than Prior Year'),
#  ('2400.0052', 'Equity In 0052', 168154, 149400, 18754, 'Current Year Greater than Prior Year'),
#  ('3206', 'UM Defaults Owed To City', -25255, -44255, 19000, 'Current Year Greater than Prior Year'),
#  ('4605.4690', 'Contract Payable Allen Creek-Sylvan Ave 5435-01', -210000, -230000, 20000, 'Current Year Greater than Prior Year'),
#  ('4622', 'Blue Cross-Administrative Fee', 813037, 792773, 20264, 'Current Year Greater than Prior Year'),
#  ('1206', '36 South Funds', 4300138, 4279374, 20764, 'Current Year Greater than Prior Year'),
#  ('5196', 'MDOT/Fed Participating Costs', 21111, 0, 21111, 'Current Year Greater than Prior Year'),
#  ('6791.0057', 'Fixed Income NTQA', -336671, -357854, 21183, 'Current Year Greater than Prior Year'),
#  ('7926', 'Fleet Operation - Fund 0026', -14946, -36234, 21288, 'Current Year Greater than Prior Year'),
#  ('4660', 'Excess Workers Comp Premiums', 91265, 69893, 21372, 'Current Year Greater than Prior Year'),
#  ('6802', 'Contributions-Retirees', -102392, -123804, 21412, 'Current Year Greater than Prior Year'),
#  ('2244', 'Improvement Chgs Receivable', 168289, 146409, 21880, 'Current Year Greater than Prior Year'),
#  ('4040.4062', 'Deposits Civil Plan Review', -47375, -69928, 22553, 'Current Year Greater than Prior Year'),
#  ('4502.4504', 'Premium/Discount - Other Bonds 2017', -406153, -429293, 23140, 'Current Year Greater than Prior Year'),
#  ('6794.002', 'Real Estate G/L DRA G&I X-Real Estate', 0, -23282, 23282, 'Current Year Greater than Prior Year'),
#  ('4625', 'HRA', 42705, 19135, 23570, 'Current Year Greater than Prior Year'),
#  ('2305.2284', 'Inventory Signs Signals', 308836, 285001, 23835, 'Current Year Greater than Prior Year'),
#  ('1512', 'As-Builts', -3265, -27241, 23976, 'Current Year Greater than Prior Year'),
#  ('2429.0012', 'LDFA Contracted Services Bootcamp', 25000, 0, 25000, 'Current Year Greater than Prior Year'),
#  ('4124', 'Interest/County', 212085, 186923, 25162, 'Current Year Greater than Prior Year'),
#  ('6801', 'RHRA-Retirees', 0, -25419, 25419, 'Current Year Greater than Prior Year'),
#  ('5460', 'Rental', -45696, -71371, 25675, 'Current Year Greater than Prior Year'),
#  ('2604', 'Training', 25769, 0, 25769, 'Current Year Greater than Prior Year'),
#  ('2400.0055', 'Equity In 0055', -158562, -185469, 26907, 'Current Year Greater than Prior Year'),
#  ('2699', 'Allow For Uncoll Persnl Pr Tax', -325415, -353264, 27849, 'Current Year Greater than Prior Year'),
#  ('2400.0035', 'Equity In 0035', -625973, -653948, 27975, 'Current Year Greater than Prior Year'),
#  ('4219', 'Planned Unit Development', -7560, -37500, 29940, 'Current Year Greater than Prior Year'),
#  ('4505.4549', 'Other Debt Payable DWRF 7325-01', -308271, -338271, 30000, 'Current Year Greater than Prior Year'),
#  ('4505.4556', 'Other Debt Payable Water Series 04-A DWRF', -92950, -122950, 30000, 'Current Year Greater than Prior Year'),
#  ('4605.4712', 'Contract Payable Springwater 5508-02', -544553, -574553, 30000, 'Current Year Greater than Prior Year'),
#  ('6700.6705', 'Garage Repairs Glass/Body', 49131, 18819, 30312, 'Current Year Greater than Prior Year'),
#  ('4502.4579', 'Premium/Discount - Other Bonds Premium 2015', -269882, -300313, 30431, 'Current Year Greater than Prior Year'),
#  ('4504.4594', 'Premium/Discount - Revenue Bonds 2016 Water', -197845, -228766, 30921, 'Current Year Greater than Prior Year'),
#  ('3102', 'City Ordinance Fines', -114295, -145249, 30954, 'Current Year Greater than Prior Year'),
#  ('6216', 'Inter (Svc Chgs) Dem Dep Accts', 90, -30947, 31037, 'Current Year Greater than Prior Year'),
#  ('2800.0063', 'Fringe Transfer 0063', 0, -31539, 31539, 'Current Year Greater than Prior Year'),
#  ('4605.47', 'Contract Payable Leslie Park GC Strm Imp 5516-01', -429182, -460833, 31651, 'Current Year Greater than Prior Year'),
#  ('4504.4513', 'Premium/Discount - Revenue Bonds Sewer', -136682, -168792, 32110, 'Current Year Greater than Prior Year'),
#  ('1003', 'Cash Claims', 32412, 0, 32412, 'Current Year Greater than Prior Year'),
#  ('6600.6600', 'Repair Parts Regular', 384911, 352459, 32452, 'Current Year Greater than Prior Year'),
#  ('1214', 'Const Ironsides Direct V', 853192, 819775, 33417, 'Current Year Greater than Prior Year'),
#  ('4605.4711', 'Contract Payable Allen Creek Drainage 5509.01', -727872, -762872, 35000, 'Current Year Greater than Prior Year'),
#  ('1296', 'First Eagle', 2084211, 2049188, 35023, 'Current Year Greater than Prior Year'),
#  ('4012', 'Due To U/M Parking Violations', -36252, -71525, 35273, 'Current Year Greater than Prior Year'),
#  ('3122', 'Probation Oversight Fee', -54962, -90414, 35452, 'Current Year Greater than Prior Year'),
#  ('2710.0057', 'Operating Transfers 0057', 0, -36213, 36213, 'Current Year Greater than Prior Year'),
#  ('4700', 'Accrued Interest Payable', -190903, -227873, 36970, 'Current Year Greater than Prior Year'),
#  ('5140.514', 'Vehicles Vehicles', 37353, 0, 37353, 'Current Year Greater than Prior Year'),
#  ('2400.00MG', 'Equity In 00MG', 1840737, 1802542, 38195, 'Current Year Greater than Prior Year'),
#  ('4505.4562', 'Other Debt Payable Sewer SWQIF 3010-04', -566703, -606703, 40000, 'Current Year Greater than Prior Year'),
#  ('4605.4701', 'Contract Payable Allen Creek Miller Ave 5436-01', -521373, -561373, 40000, 'Current Year Greater than Prior Year'),
#  ...]

# %% [markdown]
# The query orders by which accounts have the greatest difference so I would look into those with a material difference that we find alarming from this query. For revenues we would find it more concerning if it was greater than prior year while liabilities if they are less than prior year. We can use this query to detect if we think accounts are not accurate or complete.

# %% [markdown]
# # 3) Is the company's payroll accurate? Is the contracted payroll accurate?

# %% [markdown]
# Since payroll is often the biggest expense for companies, it is key to look at when auditing to make sure it is complete and accurate. They often confirm timesheets and other documents to confirm the accuracy of payroll expense.
# We can look at the relationships between the different types of payroll the company offers: permanent vs temporary vs contracted services. From an auditing perspective we could look into why things are contracted and if these contracts are accurate.
#
# This just uses a join and group by to specify which account numbers we want the totals for.

# %%
# %%sql
# SELECT
#     t.account_number,
#     account_name,
#     balance_forward,
#     ytd_debits,
#     ytd_credits,
#     ending_balance,
#     PY_ytd_balance
# FROM trial_balance t
# JOIN account_names a
#     ON t.account_number = a.account_number
# WHERE t.account_number IN (1100, 1200, 2430, 2431)
# GROUP BY t.account_number
# ORDER BY ending_balance DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.cgyzxqt5pvu5.us-east-1.rds.amazonaws.com/sql_project
# 4 rows affected.
# [('2430', 'Contracted Services', 0, 44110, 17000, 27110, 2216804),
#  ('1100', 'Permanent Time Worked', 0, 8582, 597, 7984, 11682),
#  ('2431', 'Contracted Temp Empl Services', 0, 2103, 0, 2103, 0),
#  ('1200', 'Temporary Pay', 0, 0, 0, 0, 13)]

# %% [markdown]
# Found that the entity contracts majority of their services which is interesting and something to look into why they have so much more contracted services. We should confirm the amounts with the actual contracts and confirm the normal payroll with timesheets.
